# %%
# Cell 1: Imports and Setup
# All necessary imports and API key setup
import os
import yaml
import anthropic
import time
from datetime import datetime
from pathlib import Path
from typing import Dict, List, Tuple, Optional
from lucideIconList import icons
from config import ANTHROPIC_API_KEY

print(f"Anthropic version: {anthropic.__version__}")

# API Key Setup
os.environ['ANTHROPIC_API_KEY'] = ANTHROPIC_API_KEY

# Directory paths
INPUT_DIR = "/Users/kemi/Documents/GitHub/vocab/src/content/articles"
OUTPUT_DIR = "/Users/kemi/Documents/GitHub/vocab/src/components/articles/2-adjust"
CHECK0_DIR = "/Users/kemi/Documents/GitHub/vocab/src/components/articles/0"
CHECK1_DIR = "/Users/kemi/Documents/GitHub/vocab/src/components/articles/1-ok"

# Constants for Claude API
#MODEL_NAME = "claude-3-5-sonnet-20240620" 
MODEL_NAME = "claude-3-5-sonnet-20241022"
MAX_TOKENS1 = 2000
MAX_TOKENS2 = 6000
TEMPERATURE = 0.7

LUCIDEICONS = icons

# Print setup confirmation
print("🔧 Environment setup complete")
print(f"📁 Input directory: {INPUT_DIR}")
print(f"📁 Output directory: {OUTPUT_DIR}")
# Out:
# Anthropic version: 0.37.1
# 🔧 Environment setup complete
# 📁 Input directory: /Users/kemi/Documents/GitHub/vocab/src/content/articles
# 📁 Output directory: /Users/kemi/Documents/GitHub/vocab/src/components/articles/2-adjust

# %%
# Cell 2 - User Prompts

def create_concept_prompt(title: str, summary: str) -> str:
    """
    Creates the first-shot prompt focusing on conceptual understanding and metaphors.
    
    Args:
        title (str): The concept title
        summary (str): Brief summary of the concept
        
    Returns:
        str: Formatted conceptual prompt
    """
    prompt = f'''
help me explain the following AI concept in a didactic react component which helps someone learn about it, either with interaction or animation. keep it simple. use lucide icons where possible. don't use shadcn only tailwind. make it intuitive. user shouldn't have to type anything. an animation can suffice if it's illustrative of the concept in the context of AI. The interactions might include, but not limited to, moving objects, selecting objects given a criteria, sliding objects, Scroll or Pinch-to-zoom, Swipe navigation, Drag and Drop Operations, Scroll-Based Interactions, Drawing, Music notes. Use humor and relatable situations when appropriate. aim for beautiful and artistic animations. 

CONCEPT BREAKDOWN:
1. Name of the concept: {title}
2. Core Principle: {summary}

'''
    return prompt

def create_implementation_prompt(title: str, summary: str, concept_response: str) -> str:
    """
    Creates the second-shot prompt for component implementation.
    
    Args:
        title (str): The concept title
        summary (str): Brief summary of the concept
        concept_response (str): Claude's response from the first shot
        
    Returns:
        str: Formatted implementation prompt
    """
    prompt = f'''
The execution of the react component is underwhelming and confusing. 
I know you can do better. 
1. More beautiful and artistic. 
2. Add short helper texts to help convey the information better.
3. Responsive Design: Implement font and element resizing from tailwind so the component is more legible in narrower smaller screens.
4. Add system-based theme switching using the prefers-color-scheme media query and Tailwind's dark mode feature.
5. Remember: "Robot", "Plant" and "PuzzlePiece" are not valid Lucide imports, you can use instead, only if necessary and relevant, "Bot", "Sprout" and "Puzzle" respectively. 
6. Don't use full viewport height (min-h-screen), adjust the component to only take the space it needs.

CONCEPT BREAKDOWN:
1. Name of the concept: {title}
2. Core Principle: {summary}
3. Claude 3.5 Sonnet's 1st try: 
{concept_response}

'''
    return prompt

# Print confirmation
print("✅ User Prompts loaded")
# Out:
# ✅ User Prompts loaded

# %%
# Cell 3 - Base Functions

def extract_frontmatter(content: str) -> Optional[Dict]:
    """
    Extract YAML frontmatter from markdown content.
    
    Args:
        content (str): Full markdown file content
        
    Returns:
        dict or None: Extracted frontmatter as dictionary, None if extraction fails
    """
    if content.startswith('---'):
        parts = content.split('---', 2)[1:]
        if len(parts) >= 1:
            try:
                return yaml.safe_load(parts[0])
            except yaml.YAMLError as e:
                print(f"  ⚠️ Error parsing YAML frontmatter: {str(e)}")
                return None
    return None

def format_time(seconds: float) -> str:
    """
    Format seconds into minutes and seconds.
    
    Args:
        seconds (float): Number of seconds
        
    Returns:
        str: Formatted string like "1m 30s"
    """
    return f"{int(seconds // 60)}m {int(seconds % 60)}s"

def get_existing_component_names_in_dir(directory: str) -> set:
    """
    Get names of existing components in a single directory.
    
    Args:
        directory (str): Path to components directory
        
    Returns:
        set: Set of component names (without .tsx extension)
    """
    existing_names = set()
    if os.path.exists(directory):
        for file in os.listdir(directory):
            if file.endswith('.tsx'):
                existing_names.add(file[:-4])
    return existing_names

def get_all_existing_component_names(directories: list[str]) -> set:
    """
    Get names of existing components across multiple directories.
    
    Args:
        directories (list[str]): List of directory paths to check
        
    Returns:
        set: Combined set of component names found in any directory
    """
    all_existing_names = set()
    
    for directory in directories:
        dir_components = get_existing_component_names_in_dir(directory)
        all_existing_names.update(dir_components)
    
    return all_existing_names

# Print confirmation
print("✅ Base functions loaded")
# Out:
# ✅ Base functions loaded

# %%
# Cell 4 - Component Generation Core

def generate_concept_understanding(client, title: str, prompt: str) -> str:
    """
    Generate conceptual understanding using Claude API (First shot).
    
    Args:
        client: Anthropic client instance
        title: The concept title
        prompt: Generated first-shot prompt
        
    Returns:
        str: concept explanation
    """
    print(f"\n  ⌛ Stage 1: Generating conceptual understanding for {title}...")
    
    system_prompt_concept = '''
    You are a creative artistic expert React developer and AI professor specializing in educational components for 15 to 18-year-old humans. 
Your components must strictly follow these technical requirements:

1. Architecture:
- "use client" directive at start (first line)
- import { useState, useEffect } from "react"; as the second line
- Only useState and useEffect hooks
- Only Lucide icons for visuals.
- Only Tailwind CSS for styling
- No external libraries/components
- File extension: .tsx

2. TypeScript Implementation:
interface ComponentProps {
    // Define if needed, empty interface required
}
// All state must use explicit types
const [state, setState] = useState<StateType>(initialValue);
// Event handlers must be typed
const handleEvent = (e: React.MouseEvent<HTMLButtonElement>) => {...};
// Constants outside component
const SCENARIOS: ScenarioType[] = [...];

3. Effects & Cleanup:
useEffect(() => {
    // Effect logic
    return () => {
    // Cleanup required
    };
}, [dependencies]);

4. Styling Standards:
- Only core Tailwind classes
- No arbitrary values (e.g., h-[500px])
- Transitions: duration-300 to duration-500
- Color scheme:
    • Blue (#3B82F6) - active/focus
    • Gray (#6B7280) - background
    • Green (#22C55E) - success
- Avoid minimalistic and underwhelming design. I know you can do better. Be more beautiful and artistic.
- Account for light and dark mode.

5. Code Organization:
- Max 200 lines per component
- Early returns with type guards
- JSDoc component documentation
- Proper hooks cleanup
- No inline styles
- No setTimeout/setInterval (use useEffect)
- Write the complete code, no comments or commented sections

Return only raw TSX code without explanations or markdown.
    '''
    
    try:
        response = client.messages.create(
            model=MODEL_NAME,
            max_tokens=MAX_TOKENS1,
            temperature=TEMPERATURE,
            system=system_prompt_concept,
            messages=[{"role": "user", "content": prompt}]
        )
        
        concept_response = response.content[0].text
        print(f"\n  💬 Stage 1 response: {concept_response}")
        
        return concept_response
        
    except Exception as e:
        print(f"  ❌ Error generating concept understanding: {str(e)}")
        return None

def generate_component_implementation(
    client,
    title: str,
    prompt: str,
    concept_response: str
) -> str:
    """
    Generate React component implementation using Claude API (Second shot).
    
    Args:
        client: Anthropic client instance
        title: The concept title
        prompt: Generated second-shot prompt
        concept_response: Response from first shot
        
    Returns:
        str: component_code
    """
    print(f"\n  ⌛ Stage 2: Generating component implementation for {title}...")
    
    system_prompt_implementation = '''
You are a creative artistic expert React developer and AI professor specializing in educational components for 15 to 18-year-old humans. 
Your components must strictly follow these technical requirements:

1. Architecture:
- "use client" directive at start (first line)
- import { useState, useEffect } from "react"; as the second line
- Only useState and useEffect hooks
- Only Lucide icons for visuals.
- Only Tailwind CSS for styling
- No external libraries/components
- File extension: .tsx

2. TypeScript Implementation:
interface ComponentProps {
    // Define if needed, empty interface required
}
// All state must use explicit types
const [state, setState] = useState<StateType>(initialValue);
// Event handlers must be typed
const handleEvent = (e: React.MouseEvent<HTMLButtonElement>) => {...};
// Constants outside component
const SCENARIOS: ScenarioType[] = [...];

3. Effects & Cleanup:
useEffect(() => {
    // Effect logic
    return () => {
    // Cleanup required
    };
}, [dependencies]);

4. Styling Standards:
- Only core Tailwind classes
- No arbitrary values (e.g., h-[500px])
- Transitions: duration-300 to duration-500
- Color scheme:
    • Blue (#3B82F6) - active/focus
    • Gray (#6B7280) - background
    • Green (#22C55E) - success
- Avoid minimalistic and underwhelming design. I know you can do better. Be more beautiful and artistic.

5. Code Organization:
- Max 200 lines per component
- Early returns with type guards
- JSDoc component documentation
- Proper hooks cleanup
- No inline styles
- No setTimeout/setInterval (use useEffect)
- Write the complete code, no comments or commented sections

Return only raw TSX code without explanations or markdown.
'''

# - Only Lucide icons for visuals. Limit yourself to these icons: ''' + str(LUCIDEICONS) + '''

    try:
        response = client.messages.create(
            model=MODEL_NAME,
            max_tokens=MAX_TOKENS2,
            temperature=TEMPERATURE,
            system=system_prompt_implementation,
            messages=[{
                "role": "user", 
                "content": f"{prompt}\n\nFirst-shot understanding:\n{concept_response}"
            }]
        )
        
        component_code = response.content[0].text
        
        # Clean up the code if it's wrapped in markdown
        if component_code.startswith('```'):
            first_newline = component_code.find('\n')
            if first_newline != -1:
                component_code = component_code[first_newline + 1:]
            if component_code.strip().endswith('```'):
                component_code = component_code.strip()[:-3]
        
        return component_code
        
    except Exception as e:
        print(f"  ❌ Error generating component implementation: {str(e)}")
        return None

def generate_component_with_refinement(
    client,
    title: str,
    summary: str
) -> Tuple[str, List[str]]:
    """
    Two-stage component generation with conceptual understanding and implementation.
    
    Args:
        client: Anthropic client instance
        title: Component title for logging
        summary: Brief summary of the concept
    
    Returns:
        tuple: (final_component_code, validation_issues)
    """
    # Stage 1: Conceptual Understanding
    concept_prompt = create_concept_prompt(title, summary)
    concept_response = generate_concept_understanding(
        client,
        title,
        concept_prompt
    )
    
    if not concept_response:
        return None, ["Concept generation failed"]
    
    # Stage 2: Implementation
    implementation_prompt = create_implementation_prompt(
        title,
        summary,
        concept_response
    )
    
    component_code = generate_component_implementation(
        client,
        title,
        implementation_prompt,
        concept_response
    )
    
    if not component_code:
        return None, ["Implementation generation failed"]
    
    # Validate the generated code
    issues = validate_component(component_code)
    
    if not issues:
        print("  ✅ Component validation passed")
    else:
        print("\n  ⚠️ Component validation issues found:")
        for issue in issues:
            print(f"    {issue}")
    
    return component_code, issues

# Print confirmation
print("✅ Component generation functions loaded")
# Out:
# ✅ Component generation functions loaded

# %%
# Cell 5 - Component Validation and Fixes

def save_tsx_file(
    content: str,
    md_filename: str,
    output_dir: str
) -> None:
    """
    Save the API response as a .tsx file with minimal validation.
    
    Args:
        content (str): The component code to save
        md_filename (str): Original markdown filename with .md extension
        output_dir (str): Directory to save the TSX file
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # Convert .md to .tsx while preserving exact filename
    tsx_filename = md_filename.replace('.md', '.tsx')
    filepath = os.path.join(output_dir, tsx_filename)
    
    # Clean the content
    cleaned_content = content
    if content.startswith('```'):
        first_newline = content.find('\n')
        if first_newline != -1:
            cleaned_content = content[first_newline + 1:]
        if cleaned_content.strip().endswith('```'):
            cleaned_content = cleaned_content.strip()[:-3]
    
    # Check and ensure "use client" directive
    cleaned_content = cleaned_content.strip()
    if not cleaned_content.startswith('"use client"'):
        cleaned_content = '"use client"\n\n' + cleaned_content
        print("  🔧 Added missing 'use client' directive")
    
    # Save the file
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(cleaned_content)
    print(f"  ✓ Saved: {tsx_filename}")

# Print confirmation
print("✅ Component save function loaded")
# Out:
# ✅ Component save function loaded

# %%
# Cell 6 - Main Execution

def get_generality_score(md_file):
    """
    Extract the highest generality score from a markdown file's frontmatter.
    
    Args:
        md_file (Path): Path object for the markdown file
        
    Returns:
        float: Highest generality score, or -1 if not found
    """
    try:
        with open(md_file, 'r', encoding='utf-8') as f:
            content = f.read()
        
        metadata = extract_frontmatter(content)
        if metadata and 'generality' in metadata:
            # Get highest score from generality list
            return max(metadata['generality'])
        return -1  # Return -1 if no generality scores found
    except Exception as e:
        print(f"  ⚠️ Error reading generality from {md_file.name}: {str(e)}")
        return -1

def process_file(client, md_file, metadata):
    """
    Process a single file to generate its component.
    
    Args:
        client: Anthropic client instance
        md_file: Path object for the markdown file
        metadata: Dictionary containing file metadata
        
    Returns:
        bool: success status
    """
    try:
        print(f"  ⌛ Creating prompts for: {metadata['title']}")
        
        # First shot - Conceptual Understanding
        concept_prompt = create_concept_prompt(metadata['title'], metadata['summary'])
        concept_response = generate_concept_understanding(
            client,
            metadata['title'],
            concept_prompt
        )
        
        if not concept_response:
            print(f"  ❌ Failed to generate concept understanding for: {md_file.name}")
            return False
            
        # Second shot - Implementation
        implementation_prompt = create_implementation_prompt(
            metadata['title'],
            metadata['summary'],
            concept_response
        )
        
        component_code = generate_component_implementation(
            client,
            metadata['title'],
            implementation_prompt,
            concept_response
        )
        
        if component_code:
            save_tsx_file(
                component_code,
                md_file.name,
                OUTPUT_DIR
            )
            return True
        else:
            print(f"  ❌ Failed to generate component for: {md_file.name}")
            return False
            
    except Exception as e:
        print(f"  ❌ Error processing file: {str(e)}")
        return False

def main():
    """Main execution function for the component generator."""
    print("\n🚀 Starting AI Component Generator...\n")
    start_time_total = time.time()
    
    try:
        # Initialize Anthropic client
        client = anthropic.Client(api_key=os.getenv('ANTHROPIC_API_KEY'))
        
        # Check directories
        print("📂 Checking directories...")
        if not os.path.exists(INPUT_DIR):
            raise Exception(f"Input directory not found: {INPUT_DIR}")
        if not os.path.exists(OUTPUT_DIR):
            os.makedirs(OUTPUT_DIR)
            print(f"  ✓ Created output directory: {OUTPUT_DIR}")
        
        # Get existing component names from all directories
        print("\n📂 Checking existing components...")
        dirs_to_check = [OUTPUT_DIR, CHECK0_DIR, CHECK1_DIR]
        existing_components = get_all_existing_component_names(dirs_to_check)
        
        if existing_components:
            print(f"  ✓ Found {len(existing_components)} existing components across all directories")
            
        # Get list of all .md files that don't have corresponding .tsx files
        all_md_files = []
        for md_file in Path(INPUT_DIR).glob('*.md'):
            if md_file.stem not in existing_components:
                all_md_files.append(md_file)
        
        total_available = len(all_md_files)
        print(f"\n📁 Found {total_available} unprocessed files")
        
        if total_available == 0:
            print("❌ No new files to process")
            return
        
        # Sort files by generality score (highest first)
        print("\n📊 Sorting files by generality score...")
        md_files_with_scores = [(f, get_generality_score(f)) for f in all_md_files]
        sorted_md_files = [f for f, score in sorted(md_files_with_scores, key=lambda x: x[1], reverse=True)]
        
        # Select top 50 files (or all if less than 50 available) ⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️
        num_files = min(10, total_available)
        md_files = sorted_md_files[:num_files]
        
        print(f"\n📈 Selected top {num_files} files by generality score")
        
        # Track statistics
        successful = 0
        failed = 0
        
        # Process each file
        for index, md_file in enumerate(md_files, 1):
            print(f"\n📝 Processing file {index}/{num_files}: {md_file.name}")
            start_time_file = time.time()
            
            try:
                print("  ⌛ Reading file...")
                with open(md_file, 'r', encoding='utf-8') as f:
                    content = f.read()
                
                print("  ⌛ Extracting metadata...")
                metadata = extract_frontmatter(content)
                if not metadata:
                    print("  ❌ Could not extract metadata")
                    failed += 1
                    continue
                
                # Process the file
                success = process_file(client, md_file, metadata)
                if success:
                    successful += 1
                else:
                    failed += 1
                
                elapsed_time = time.time() - start_time_file
                print(f"  ⏱️ Time taken: {format_time(elapsed_time)}")
                
            except Exception as e:
                print(f"  ❌ Error: {str(e)}")
                failed += 1
        
        # Print summary
        total_time = time.time() - start_time_total
        print("\n====== Summary ======")
        print(f"✅ Successfully processed: {successful}")
        print(f"❌ Failed: {failed}")
        print(f"⏱️ Total time: {format_time(total_time)}")
        
    except Exception as e:
        print(f"\n❌ Fatal error: {str(e)}")
        raise
    
    print("\n✨ Process completed!")

# %%
# Cell 7 - Run Main
if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting AI Component Generator...
#
# 📂 Checking directories...
#
# 📂 Checking existing components...
#   ✓ Found 64 existing components across all directories
#
# 📁 Found 849 unprocessed files
#
# 📊 Sorting files by generality score...
#
# 📈 Selected top 10 files by generality score
#
# 📝 Processing file 1/10: instruction-following-model.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Instruction Following Model
#
#   ⌛ Stage 1: Generating conceptual understanding for Instruction Following Model...
#
#   💬 Stage 1 response: ```tsx
# "use client"
# import { useState, useEffect } from "react"
# import { Robot, ArrowRight, Sparkles, Brain, MessageSquare } from "lucide-react"
#
# interface ComponentProps {}
#
# type Instruction = {
#   command: string
#   animation: string
#   result: string
# }
#
# const INSTRUCTIONS: Instruction[] = [
#   {
#     command: "Make the robot dance",
#     animation: "dance",
#     result: "🕺 Dancing with style!"
#   },
#   {
#     command: "Tell a joke",
#     animation: "laugh",
#     result: "Why don't AI robots tell dad jokes? Because they have DATA issues! 😄"
#   },
#   {
#     command: "Solve math problem",
#     animation: "calculate",
#     result: "2 + 2 = 4 ✨"
#   },
#   {
#     command: "Draw a picture",
#     animation: "draw",
#     result: "🎨 Created a masterpiece!"
#   }
# ]
#
# /**
#  * An interactive component demonstrating how AI follows instructions
#  */
# export default function InstructionFollower({}: ComponentProps) {
#   const [currentInstruction, setCurrentInstruction] = useState<number>(0)
#   const [isAnimating, setIsAnimating] = useState<boolean>(false)
#   const [showResult, setShowResult] = useState<boolean>(false)
#
#   useEffect(() => {
#     if (isAnimating) {
#       const timer = setTimeout(() => {
#         setShowResult(true)
#         setIsAnimating(false)
#       }, 2000)
#
#       return () => clearTimeout(timer)
#     }
#   }, [isAnimating])
#
#   const handleInstructionClick = (index: number) => {
#     setCurrentInstruction(index)
#     setIsAnimating(true)
#     setShowResult(false)
#   }
#
#   return (
#     <div className="min-h-[500px] p-8 bg-gradient-to-br from-gray-50 to-blue-50 dark:from-gray-900 dark:to-blue-900 rounded-xl shadow-xl">
#       <h2 className="text-3xl font-bold text-gray-800 dark:text-white mb-8 flex items-center gap-2">
#         <Brain className="w-8 h-8" />
#         Instruction Following AI
#       </h2>
#
#       <div className="grid grid-cols-1 md:grid-cols-2 gap-8">
#         <div className="space-y-4">
#           <p className="text-gray-600 dark:text-gray-300 mb-4">
#             Select an instruction to see how AI follows commands:
#           </p>
#
#           {INSTRUCTIONS.map((instruction, index) => (
#             <button
#               key={instruction.command}
#               onClick={() => handleInstructionClick(index)}
#               className={`w-full p-4 rounded-lg transition-all duration-300 flex items-center justify-between
#                 ${currentInstruction === index
#                   ? 'bg-blue-500 text-white shadow-lg scale-105'
#                   : 'bg-white dark:bg-gray-800 text-gray-700 dark:text-gray-200 hover:bg-blue-50 dark:hover:bg-gray-700'
#                 }`}
#             >
#               <span>{instruction.command}</span>
#               <ArrowRight className="w-5 h-5" />
#             </button>
#           ))}
#         </div>
#
#         <div className="bg-white dark:bg-gray-800 rounded-xl p-8 flex flex-col items-center justify-center relative overflow-hidden">
#           <Robot
#             className={`w-24 h-24 transition-all duration-500 ${
#               isAnimating ? INSTRUCTIONS[currentInstruction].animation === 'dance'
#                 ? 'animate-bounce'
#                 : INSTRUCTIONS[currentInstruction].animation === 'laugh'
#                 ? 'animate-pulse'
#                 : INSTRUCTIONS[currentInstruction].animation === 'calculate'
#                 ? 'animate-spin'
#                 : 'animate-bounce'
#               : ''
#             }`}
#           />
#
#           {showResult && (
#             <div className="mt-6 text-center animate-fade-in">
#               <div className="flex items-center gap-2 text-gray-700 dark:text-gray-200">
#                 <MessageSquare className="w-5 h-5" />
#                 <span>{INSTRUCTIONS[currentInstruction].result}</span>
#               </div>
#               <Sparkles className="w-5 h-5 text-blue-500 absolute top-4 right-4 animate-pulse" />
#             </div>
#           )}
#         </div>
#       </div>
#
#       <p className="text-sm text-gray-500 dark:text-gray-400 mt-8 italic">
#         Just like a well-trained assistant, AI models learn to understand and execute instructions!
#       </p>
#     </div>
#   )
# }
# ```
#
#   ⌛ Stage 2: Generating component implementation for Instruction Following Model...
#   ✓ Saved: instruction-following-model.tsx
#   ⏱️ Time taken: 0m 46s
#
# 📝 Processing file 2/10: wake-sleep.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Wake Sleep
#
#   ⌛ Stage 1: Generating conceptual understanding for Wake Sleep...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Moon, Sun, Brain, ChevronDown, ChevronUp } from "lucide-react"
#
# interface ComponentProps {}
#
# type NeuronState = {
#   id: number
#   active: boolean
#   position: { x: number; y: number }
# }
#
# /**
#  * WakeSleepDemo demonstrates the wake-sleep algorithm through an interactive
#  * visualization of neurons activating in alternating phases
#  */
# const WakeSleepDemo: React.FC<ComponentProps> = () => {
#   const [isWakePhase, setIsWakePhase] = useState<boolean>(true)
#   const [neurons, setNeurons] = useState<NeuronState[]>([])
#   const [isPlaying, setIsPlaying] = useState<boolean>(false)
#
#   useEffect(() => {
#     // Initialize neurons in a grid pattern
#     const initialNeurons = Array.from({ length: 12 }, (_, i) => ({
#       id: i,
#       active: false,
#       position: {
#         x: (i % 4) * 80 + 100,
#         y: Math.floor(i / 4) * 80 + 100,
#       }
#     }))
#     setNeurons(initialNeurons)
#
#     return () => {
#       setNeurons([])
#       setIsPlaying(false)
#     }
#   }, [])
#
#   useEffect(() => {
#     if (!isPlaying) return
#
#     const interval = setInterval(() => {
#       setIsWakePhase(prev => !prev)
#
#       setNeurons(prev => prev.map(neuron => ({
#         ...neuron,
#         active: Math.random() > 0.5
#       })))
#     }, 2000)
#
#     return () => clearInterval(interval)
#   }, [isPlaying])
#
#   return (
#     <div className="flex flex-col items-center min-h-screen p-8 bg-gradient-to-b from-slate-50 to-slate-100 dark:from-slate-900 dark:to-slate-800 text-slate-800 dark:text-slate-100">
#       <h1 className="text-3xl font-bold mb-8 flex items-center gap-3">
#         <Brain className="w-8 h-8" />
#         Wake-Sleep Algorithm
#       </h1>
#
#       <div className="relative w-[400px] h-[400px] bg-white dark:bg-slate-700 rounded-xl shadow-xl mb-8 overflow-hidden">
#         {/* Network Visualization */}
#         <div className="absolute inset-0">
#           {neurons.map((neuron) => (
#             <div
#               key={neuron.id}
#               className={`absolute w-12 h-12 rounded-full transition-all duration-500 flex items-center justify-center
#                 ${neuron.active
#                   ? 'bg-blue-500 shadow-lg scale-110'
#                   : 'bg-gray-300 dark:bg-gray-600'
#                 }`}
#               style={{
#                 transform: `translate(${neuron.position.x}px, ${neuron.position.y}px)`,
#               }}
#             >
#               {isWakePhase ? (
#                 <ChevronUp className={`w-6 h-6 ${neuron.active ? 'text-white animate-bounce' : 'text-gray-500'}`} />
#               ) : (
#                 <ChevronDown className={`w-6 h-6 ${neuron.active ? 'text-white animate-bounce' : 'text-gray-500'}`} />
#               )}
#             </div>
#           ))}
#         </div>
#
#         {/* Phase Indicator */}
#         <div className="absolute top-4 left-4 flex items-center gap-2 bg-white dark:bg-slate-800 rounded-full px-4 py-2 shadow-lg">
#           {isWakePhase ? (
#             <>
#               <Sun className="w-5 h-5 text-yellow-500 animate-spin-slow" />
#               <span className="text-sm font-medium">Wake Phase</span>
#             </>
#           ) : (
#             <>
#               <Moon className="w-5 h-5 text-blue-500 animate-pulse" />
#               <span className="text-sm font-medium">Sleep Phase</span>
#             </>
#           )}
#         </div>
#       </div>
#
#       <button
#         onClick={() => setIsPlaying(!isPlaying)}
#         className={`px-6 py-3 rounded-full font-medium transition-all duration-300
#           ${isPlaying
#             ? 'bg-red-500 hover:bg-red-600 text-white'
#             : 'bg-blue-500 hover:bg-blue-600 text-white'
#           }`}
#       >
#         {isPlaying ? 'Pause Animation' : 'Start Animation'}
#       </button>
#
#       <div className="mt-8 max-w-md text-center text-sm">
#         <p className="mb-2">
#           Watch as the neurons alternate between wake (bottom-up) and sleep (top-down) phases,
#           learning patterns in an unsupervised manner! 🧠✨
#         </p>
#         <p className="text-gray-600 dark:text-gray-400">
#           Just like your brain during REM sleep, this network is processing and consolidating information.
#         </p>
#       </div>
#     </div>
#   )
# }
#
# export default WakeSleepDemo
# ```
#
#   ⌛ Stage 2: Generating component implementation for Wake Sleep...
#   ✓ Saved: wake-sleep.tsx
#   ⏱️ Time taken: 0m 52s
#
# 📝 Processing file 3/10: next-word-prediction.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Next Word Prediction
#
#   ⌛ Stage 1: Generating conceptual understanding for Next Word Prediction...
#
#   💬 Stage 1 response: ```tsx
# "use client"
# import { useState, useEffect } from "react"
# import { Brain, ChevronRight, Sparkles, Type } from "lucide-react"
#
# interface PredictionProps {}
#
# type Sentence = {
#   words: string[]
#   predictions: string[]
# }
#
# const SAMPLE_SENTENCES: Sentence[] = [
#   {
#     words: ["The", "cat", "sits", "on", "the"],
#     predictions: ["mat", "chair", "windowsill", "table", "bed"]
#   },
#   {
#     words: ["I", "love", "eating"],
#     predictions: ["pizza", "sushi", "ice cream", "chocolate", "pasta"]
#   },
#   {
#     words: ["She", "opened", "the"],
#     predictions: ["door", "window", "book", "letter", "box"]
#   }
# ]
#
# /**
#  * Interactive component demonstrating next word prediction in AI
#  * Animates typing process and shows predictions
#  */
# export default function NextWordPredictor({}: PredictionProps) {
#   const [currentSentence, setCurrentSentence] = useState<number>(0)
#   const [typedWords, setTypedWords] = useState<string[]>([])
#   const [selectedPrediction, setSelectedPrediction] = useState<string>("")
#   const [isTyping, setIsTyping] = useState(false)
#
#   useEffect(() => {
#     let typingInterval: NodeJS.Timeout
#
#     if (typedWords.length < SAMPLE_SENTENCES[currentSentence].words.length) {
#       setIsTyping(true)
#       typingInterval = setInterval(() => {
#         setTypedWords(prev => [
#           ...prev,
#           SAMPLE_SENTENCES[currentSentence].words[prev.length]
#         ])
#       }, 600)
#     } else {
#       setIsTyping(false)
#     }
#
#     return () => clearInterval(typingInterval)
#   }, [typedWords, currentSentence])
#
#   useEffect(() => {
#     const timer = setTimeout(() => {
#       setTypedWords([])
#       setSelectedPrediction("")
#       setCurrentSentence((prev) =>
#         prev === SAMPLE_SENTENCES.length - 1 ? 0 : prev + 1
#       )
#     }, 6000)
#
#     return () => clearTimeout(timer)
#   }, [selectedPrediction])
#
#   return (
#     <div className="min-h-[400px] p-8 rounded-xl bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-800 dark:to-gray-900 shadow-xl">
#       <div className="flex items-center gap-3 mb-8">
#         <Brain className="w-8 h-8 text-blue-500" />
#         <h2 className="text-2xl font-bold text-gray-800 dark:text-gray-100">
#           Next Word Prediction
#         </h2>
#       </div>
#
#       <div className="space-y-8">
#         <div className="flex items-center gap-3 min-h-[60px] p-4 rounded-lg bg-white dark:bg-gray-800 shadow-md">
#           <Type className="w-5 h-5 text-gray-400" />
#           <div className="flex flex-wrap gap-2">
#             {typedWords.map((word, i) => (
#               <span
#                 key={i}
#                 className="text-lg text-gray-700 dark:text-gray-300"
#               >
#                 {word}
#               </span>
#             ))}
#             {isTyping && (
#               <span className="inline-block w-2 h-5 bg-blue-500 animate-pulse" />
#             )}
#             {selectedPrediction && (
#               <span className="text-lg text-blue-500 font-medium">
#                 {selectedPrediction}
#               </span>
#             )}
#           </div>
#         </div>
#
#         {typedWords.length === SAMPLE_SENTENCES[currentSentence].words.length && (
#           <div className="space-y-3">
#             <div className="flex items-center gap-2">
#               <Sparkles className="w-5 h-5 text-blue-500" />
#               <p className="text-sm text-gray-600 dark:text-gray-400">
#                 AI Predictions:
#               </p>
#             </div>
#
#             <div className="flex flex-wrap gap-2">
#               {SAMPLE_SENTENCES[currentSentence].predictions.map((pred, i) => (
#                 <button
#                   key={i}
#                   onClick={() => setSelectedPrediction(pred)}
#                   className={`
#                     px-4 py-2 rounded-full text-sm font-medium
#                     transition-all duration-300
#                     ${selectedPrediction === pred
#                       ? 'bg-blue-500 text-white shadow-lg scale-105'
#                       : 'bg-gray-100 dark:bg-gray-700 text-gray-700 dark:text-gray-300 hover:bg-gray-200 dark:hover:bg-gray-600'
#                     }
#                   `}
#                 >
#                   {pred}
#                   <ChevronRight className="w-4 h-4 inline-block ml-1" />
#                 </button>
#               ))}
#             </div>
#           </div>
#         )}
#       </div>
#     </div>
#   )
# }
# ```
#
#   ⌛ Stage 2: Generating component implementation for Next Word Prediction...
#   ✓ Saved: next-word-prediction.tsx
#   ⏱️ Time taken: 0m 54s
#
# 📝 Processing file 4/10: vector-operation.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Vector Operation
#
#   ⌛ Stage 1: Generating conceptual understanding for Vector Operation...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { ArrowRight, Plus, X, Divide, RotateCcw } from "lucide-react"
#
# interface VectorOperationsProps {}
#
# type Vector = {
#   x: number
#   y: number
#   color: string
# }
#
# /**
#  * Interactive Vector Operations Component
#  * Demonstrates basic vector math through animated visualizations
#  */
# const VectorOperations: React.FC<VectorOperationsProps> = () => {
#   const [vectors, setVectors] = useState<Vector[]>([
#     { x: 2, y: 1, color: "#3B82F6" },
#     { x: 1, y: 2, color: "#22C55E" }
#   ])
#
#   const [operation, setOperation] = useState<"add" | "subtract" | "multiply" | "reset">("add")
#   const [isAnimating, setIsAnimating] = useState(false)
#
#   const gridSize = 300
#   const scale = 50
#
#   useEffect(() => {
#     if (isAnimating) {
#       const timer = setTimeout(() => {
#         setIsAnimating(false)
#       }, 1000)
#       return () => clearTimeout(timer)
#     }
#   }, [isAnimating])
#
#   const vectorToPoint = (vector: Vector) => {
#     return {
#       x: vector.x * scale + gridSize/2,
#       y: gridSize/2 - vector.y * scale
#     }
#   }
#
#   const performOperation = (op: "add" | "subtract" | "multiply" | "reset") => {
#     setOperation(op)
#     setIsAnimating(true)
#
#     const v1 = vectors[0]
#     const v2 = vectors[1]
#
#     let result: Vector
#     switch(op) {
#       case "add":
#         result = {
#           x: v1.x + v2.x,
#           y: v1.y + v2.y,
#           color: "#6B7280"
#         }
#         break
#       case "subtract":
#         result = {
#           x: v1.x - v2.x,
#           y: v1.y - v2.y,
#           color: "#6B7280"
#         }
#         break
#       case "multiply":
#         result = {
#           x: v1.x * v2.x,
#           y: v1.y * v2.y,
#           color: "#6B7280"
#         }
#         break
#       case "reset":
#         setVectors([
#           { x: 2, y: 1, color: "#3B82F6" },
#           { x: 1, y: 2, color: "#22C55E" }
#         ])
#         return
#     }
#
#     setVectors([...vectors.slice(0,2), result])
#   }
#
#   return (
#     <div className="flex flex-col items-center p-8 bg-white dark:bg-gray-900 min-h-screen">
#       <h1 className="text-3xl font-bold mb-8 text-gray-800 dark:text-white">
#         Vector Operations in AI
#       </h1>
#
#       <div className="relative w-[300px] h-[300px] mb-8 border border-gray-200 dark:border-gray-700">
#         {/* Grid lines */}
#         <div className="absolute inset-0 grid grid-cols-6 grid-rows-6">
#           {Array.from({length: 36}).map((_, i) => (
#             <div key={i} className="border border-gray-100 dark:border-gray-800" />
#           ))}
#         </div>
#
#         {/* Vectors */}
#         {vectors.map((vector, i) => {
#           const point = vectorToPoint(vector)
#           return (
#             <svg key={i} className="absolute inset-0">
#               <line
#                 x1={gridSize/2}
#                 y1={gridSize/2}
#                 x2={point.x}
#                 y2={point.y}
#                 stroke={vector.color}
#                 strokeWidth="2"
#                 className={`transition-all duration-500 ${isAnimating ? 'scale-110' : ''}`}
#               >
#                 <animate
#                   attributeName="stroke-dasharray"
#                   values="0,1000;1000,0"
#                   dur="1s"
#                   begin="0s"
#                   fill="freeze"
#                 />
#               </line>
#               <circle
#                 cx={point.x}
#                 cy={point.y}
#                 r="4"
#                 fill={vector.color}
#                 className={`transition-all duration-500 ${isAnimating ? 'scale-110' : ''}`}
#               />
#             </svg>
#           )
#         })}
#       </div>
#
#       <div className="flex gap-4 mb-8">
#         <button
#           onClick={() => performOperation("add")}
#           className="p-3 rounded-full bg-blue-500 text-white hover:bg-blue-600 transition-colors duration-300"
#         >
#           <Plus size={24} />
#         </button>
#         <button
#           onClick={() => performOperation("subtract")}
#           className="p-3 rounded-full bg-green-500 text-white hover:bg-green-600 transition-colors duration-300"
#         >
#           <X size={24} />
#         </button>
#         <button
#           onClick={() => performOperation("multiply")}
#           className="p-3 rounded-full bg-gray-500 text-white hover:bg-gray-600 transition-colors duration-300"
#         >
#           <Divide size={24} />
#         </button>
#         <button
#           onClick={() => performOperation("reset")}
#           className="p-3 rounded-full bg-red-500 text-white hover:bg-red-600 transition-colors duration-300"
#         >
#           <RotateCcw size={24} />
#         </button>
#       </div>
#
#       <div className="text-gray-600 dark:text-gray-300 text-center max-w-md">
#         <p>Click the buttons to see how vectors behave under different operations!</p>
#         <p className="mt-2 text-sm">
#           Blue Vector: ({vectors[0].x}, {vectors[0].y}) <br />
#           Green Vector: ({vectors[1].x}, {vectors[1].y})
#         </p>
#         {vectors.length > 2 && (
#           <p className="mt-2 text-sm">
#             Result: ({vectors[2].x}, {vectors[2].y})
#           </p>
#         )}
#       </div>
#     </div>
#   )
# }
#
# export default VectorOperations
# ```
#
#   ⌛ Stage 2: Generating component implementation for Vector Operation...
#   ✓ Saved: vector-operation.tsx
#   ⏱️ Time taken: 1m 1s
#
# 📝 Processing file 5/10: agent.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Agent
#
#   ⌛ Stage 1: Generating conceptual understanding for Agent...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react";
# import { Eye, Brain, Target, Robot, ArrowRight, Check } from "lucide-react";
#
# interface AgentState {
#   isPerceiving: boolean;
#   isThinking: boolean;
#   isActing: boolean;
#   currentGoal: string;
#   success: boolean;
# }
#
# const GOALS = [
#   "Find the blue ball",
#   "Avoid obstacles",
#   "Reach the target",
#   "Collect data",
# ];
#
# /**
#  * Interactive AI Agent demonstration component
#  * Shows perception, thinking, and action cycle
#  */
# export default function AIAgentDemo() {
#   const [state, setState] = useState<AgentState>({
#     isPerceiving: false,
#     isThinking: false,
#     isActing: false,
#     currentGoal: GOALS[0],
#     success: false,
#   });
#
#   const [position, setPosition] = useState({ x: 0, y: 0 });
#   const [cycle, setCycle] = useState(0);
#
#   useEffect(() => {
#     const interval = setInterval(() => {
#       setCycle((prev) => (prev + 1) % 3);
#
#       switch(cycle) {
#         case 0:
#           setState(prev => ({ ...prev, isPerceiving: true, isThinking: false, isActing: false }));
#           break;
#         case 1:
#           setState(prev => ({ ...prev, isPerceiving: false, isThinking: true, isActing: false }));
#           break;
#         case 2:
#           setState(prev => ({ ...prev, isPerceiving: false, isThinking: false, isActing: true }));
#           if (position.x < 280) {
#             setPosition(prev => ({ ...prev, x: prev.x + 40 }));
#           } else {
#             setState(prev => ({ ...prev, success: true }));
#           }
#           break;
#       }
#     }, 1500);
#
#     return () => clearInterval(interval);
#   }, [cycle, position.x]);
#
#   return (
#     <div className="w-full max-w-2xl mx-auto p-6 bg-white dark:bg-gray-800 rounded-xl shadow-xl">
#       <div className="text-center mb-8">
#         <h2 className="text-3xl font-bold text-gray-800 dark:text-white mb-4">
#           Meet the AI Agent
#         </h2>
#         <p className="text-gray-600 dark:text-gray-300">
#           Watch how I perceive, think, and act to achieve my goals!
#         </p>
#       </div>
#
#       <div className="relative h-64 bg-gray-100 dark:bg-gray-700 rounded-lg overflow-hidden">
#         <div
#           className={`absolute transition-all duration-500 transform ${
#             state.success ? "scale-110" : ""
#           }`}
#           style={{ left: `${position.x}px`, top: `${position.y}px` }}
#         >
#           <Robot
#             className={`w-16 h-16 ${
#               state.isPerceiving
#                 ? "text-blue-500"
#                 : state.isThinking
#                 ? "text-purple-500"
#                 : "text-green-500"
#             } transition-colors duration-300`}
#           />
#         </div>
#
#         <Target className="absolute right-8 top-1/2 transform -translate-y-1/2 w-12 h-12 text-red-500" />
#       </div>
#
#       <div className="mt-6 flex justify-center space-x-8">
#         <div className={`flex flex-col items-center ${state.isPerceiving ? "text-blue-500" : "text-gray-400"}`}>
#           <Eye className="w-8 h-8 mb-2" />
#           <span>Perceiving</span>
#         </div>
#         <ArrowRight className="w-6 h-6 text-gray-400 mt-4" />
#         <div className={`flex flex-col items-center ${state.isThinking ? "text-purple-500" : "text-gray-400"}`}>
#           <Brain className="w-8 h-8 mb-2" />
#           <span>Thinking</span>
#         </div>
#         <ArrowRight className="w-6 h-6 text-gray-400 mt-4" />
#         <div className={`flex flex-col items-center ${state.isActing ? "text-green-500" : "text-gray-400"}`}>
#           <Check className="w-8 h-8 mb-2" />
#           <span>Acting</span>
#         </div>
#       </div>
#
#       <div className="mt-6 text-center">
#         <p className={`text-lg font-semibold ${state.success ? "text-green-500" : "text-gray-600 dark:text-gray-300"}`}>
#           {state.success ? "Goal Achieved! 🎉" : `Current Goal: ${state.currentGoal}`}
#         </p>
#       </div>
#     </div>
#   );
# }
#
#   ⌛ Stage 2: Generating component implementation for Agent...
#   ✓ Saved: agent.tsx
#   ⏱️ Time taken: 0m 50s
#
# 📝 Processing file 6/10: invariance.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Invariance
#
#   ⌛ Stage 1: Generating conceptual understanding for Invariance...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Image, MoveHorizontal, MoveVertical, Palette, RotateCcw } from "lucide-react"
#
# interface InvarianceProps {}
#
# type TransformType = "rotate" | "scale" | "translate" | "color"
#
# /**
#  * An interactive component demonstrating AI invariance through visual transformations
#  * Shows how AI models recognize objects despite various changes
#  */
# const InvarianceDemo = ({}: InvarianceProps) => {
#   const [activeTransform, setActiveTransform] = useState<TransformType>("rotate")
#   const [isAnimating, setIsAnimating] = useState(false)
#   const [iteration, setIteration] = useState(0)
#
#   useEffect(() => {
#     const interval = setInterval(() => {
#       if (isAnimating) {
#         setIteration(prev => (prev + 1) % 360)
#       }
#     }, 50)
#     return () => clearInterval(interval)
#   }, [isAnimating])
#
#   const getTransformStyle = () => {
#     switch (activeTransform) {
#       case "rotate":
#         return `rotate(${iteration}deg)`
#       case "scale":
#         return `scale(${1 + Math.sin(iteration * 0.01)})`
#       case "translate":
#         return `translateX(${Math.sin(iteration * 0.01) * 50}px)`
#       case "color":
#         return "none"
#       default:
#         return "none"
#     }
#   }
#
#   const getFilterStyle = () => {
#     if (activeTransform === "color") {
#       return `hue-rotate(${iteration}deg)`
#     }
#     return "none"
#   }
#
#   return (
#     <div className="flex flex-col items-center justify-center min-h-screen p-8 bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-800 dark:to-gray-900">
#       <h1 className="text-4xl font-bold mb-8 text-gray-800 dark:text-gray-100">
#         AI Invariance Explorer
#       </h1>
#
#       <div className="relative w-full max-w-2xl p-8 bg-white dark:bg-gray-700 rounded-xl shadow-xl">
#         <div className="flex justify-center mb-8">
#           <div
#             className="relative w-48 h-48 flex items-center justify-center"
#             style={{
#               transform: getTransformStyle(),
#               filter: getFilterStyle(),
#               transition: "all 0.3s ease-in-out"
#             }}
#           >
#             <div className="w-32 h-32 bg-blue-500 rounded-lg flex items-center justify-center">
#               <span className="text-4xl">🐱</span>
#             </div>
#             <div className="absolute top-0 left-1/2 transform -translate-x-1/2 -translate-y-8 bg-green-500 text-white px-4 py-1 rounded-full text-sm">
#               Still a cat! 🎯
#             </div>
#           </div>
#         </div>
#
#         <div className="grid grid-cols-2 md:grid-cols-4 gap-4">
#           <button
#             onClick={() => {
#               setActiveTransform("rotate")
#               setIsAnimating(true)
#             }}
#             className={`flex items-center justify-center gap-2 p-3 rounded-lg transition-all duration-300 ${
#               activeTransform === "rotate"
#                 ? "bg-blue-500 text-white"
#                 : "bg-gray-100 dark:bg-gray-600 text-gray-700 dark:text-gray-200"
#             }`}
#           >
#             <RotateCcw size={20} />
#             Rotate
#           </button>
#
#           <button
#             onClick={() => {
#               setActiveTransform("scale")
#               setIsAnimating(true)
#             }}
#             className={`flex items-center justify-center gap-2 p-3 rounded-lg transition-all duration-300 ${
#               activeTransform === "scale"
#                 ? "bg-blue-500 text-white"
#                 : "bg-gray-100 dark:bg-gray-600 text-gray-700 dark:text-gray-200"
#             }`}
#           >
#             <Image size={20} />
#             Scale
#           </button>
#
#           <button
#             onClick={() => {
#               setActiveTransform("translate")
#               setIsAnimating(true)
#             }}
#             className={`flex items-center justify-center gap-2 p-3 rounded-lg transition-all duration-300 ${
#               activeTransform === "translate"
#                 ? "bg-blue-500 text-white"
#                 : "bg-gray-100 dark:bg-gray-600 text-gray-700 dark:text-gray-200"
#             }`}
#           >
#             <MoveHorizontal size={20} />
#             Move
#           </button>
#
#           <button
#             onClick={() => {
#               setActiveTransform("color")
#               setIsAnimating(true)
#             }}
#             className={`flex items-center justify-center gap-2 p-3 rounded-lg transition-all duration-300 ${
#               activeTransform === "color"
#                 ? "bg-blue-500 text-white"
#                 : "bg-gray-100 dark:bg-gray-600 text-gray-700 dark:text-gray-200"
#             }`}
#           >
#             <Palette size={20} />
#             Color
#           </button>
#         </div>
#
#         <div className="mt-8 text-center text-gray-600 dark:text-gray-300">
#           <p>
#             No matter how we transform the image, the AI still recognizes it as a cat!
#             <br />
#             <span className="text-sm">That's invariance in action 🧠✨</span>
#           </p>
#         </div>
#       </div>
#     </div>
#   )
# }
#
# export default InvarianceDemo
# ```
#
#   ⌛ Stage 2: Generating component implementation for Invariance...
#   ✓ Saved: invariance.tsx
#   ⏱️ Time taken: 0m 52s
#
# 📝 Processing file 7/10: surprise.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Surprise
#
#   ⌛ Stage 1: Generating conceptual understanding for Surprise...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Brain, Lightbulb, Zap, ThumbsUp, ThumbsDown } from "lucide-react"
#
# interface SurpriseProps {}
#
# type Prediction = {
#   item: string
#   expected: number
#   actual: number
#   surprise: number
# }
#
# const ITEMS: Prediction[] = [
#   { item: "🌞", expected: 90, actual: 85, surprise: 0.05 },
#   { item: "🌧️", expected: 5, actual: 10, surprise: 0.7 },
#   { item: "🌈", expected: 2, actual: 15, surprise: 0.95 },
#   { item: "❄️", expected: 3, actual: 90, surprise: 0.99 }
# ]
#
# /**
#  * Interactive component demonstrating AI Surprise concept
#  * Shows how unexpected outcomes generate surprise in AI systems
#  */
# const SurpriseDemo: React.FC<SurpriseProps> = () => {
#   const [activeIndex, setActiveIndex] = useState<number>(0)
#   const [isAnimating, setIsAnimating] = useState<boolean>(false)
#   const [showExplanation, setShowExplanation] = useState<boolean>(false)
#
#   useEffect(() => {
#     const timer = setInterval(() => {
#       setActiveIndex((prev) => (prev + 1) % ITEMS.length)
#       setIsAnimating(true)
#       setTimeout(() => setIsAnimating(false), 500)
#     }, 3000)
#
#     return () => clearInterval(timer)
#   }, [])
#
#   return (
#     <div className="min-h-[500px] p-8 bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-800 dark:to-gray-900 rounded-xl shadow-xl">
#       <div className="flex flex-col items-center space-y-8">
#         <div className="flex items-center space-x-2">
#           <Brain className="w-8 h-8 text-blue-500" />
#           <h2 className="text-2xl font-bold text-gray-800 dark:text-gray-100">
#             AI Surprise-O-Meter
#           </h2>
#         </div>
#
#         <div className="relative w-full max-w-md p-6 bg-white dark:bg-gray-700 rounded-lg shadow-lg">
#           <div className="flex justify-between items-center mb-8">
#             <div className="text-4xl">{ITEMS[activeIndex].item}</div>
#             <Zap
#               className={`w-6 h-6 ${isAnimating ? 'text-yellow-400 animate-bounce' : 'text-gray-400'}`}
#             />
#           </div>
#
#           <div className="space-y-4">
#             <div className="flex justify-between">
#               <span className="text-gray-600 dark:text-gray-300">Expected Probability:</span>
#               <span className="font-mono">{ITEMS[activeIndex].expected}%</span>
#             </div>
#
#             <div className="flex justify-between">
#               <span className="text-gray-600 dark:text-gray-300">Actual Occurrence:</span>
#               <span className="font-mono">{ITEMS[activeIndex].actual}%</span>
#             </div>
#
#             <div className="relative h-4 bg-gray-200 dark:bg-gray-600 rounded-full overflow-hidden">
#               <div
#                 className="absolute h-full bg-blue-500 transition-all duration-500"
#                 style={{width: `${ITEMS[activeIndex].surprise * 100}%`}}
#               />
#             </div>
#
#             <div className="flex justify-between items-center">
#               <ThumbsDown className="w-5 h-5 text-gray-400" />
#               <span className="text-sm text-gray-500 dark:text-gray-400">Surprise Level</span>
#               <ThumbsUp className="w-5 h-5 text-blue-500" />
#             </div>
#           </div>
#         </div>
#
#         <button
#           onClick={() => setShowExplanation(!showExplanation)}
#           className="flex items-center space-x-2 px-4 py-2 bg-blue-500 hover:bg-blue-600 text-white rounded-lg transition duration-300"
#         >
#           <Lightbulb className="w-5 h-5" />
#           <span>{showExplanation ? "Hide" : "Show"} Explanation</span>
#         </button>
#
#         {showExplanation && (
#           <div className="text-center text-gray-600 dark:text-gray-300 max-w-md animate-fade-in">
#             <p>
#               Just like humans, AI systems experience "surprise" when reality differs
#               from expectations! The bigger the difference between expected and actual
#               probabilities, the higher the surprise level. This helps AI learn and
#               adapt to new patterns.
#             </p>
#           </div>
#         )}
#       </div>
#     </div>
#   )
# }
#
# export default SurpriseDemo
# ```
#
#   ⌛ Stage 2: Generating component implementation for Surprise...
#   ❌ Error generating component implementation: Error code: 529 - {'type': 'error', 'error': {'type': 'overloaded_error', 'message': 'Overloaded'}}
#   ❌ Failed to generate component for: surprise.md
#   ⏱️ Time taken: 1m 6s
#
# 📝 Processing file 8/10: misuse.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Misuse
#
#   ⌛ Stage 1: Generating conceptual understanding for Misuse...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react";
# import { AlertTriangle, Shield, Skull, Heart, XCircle, CheckCircle, Users, Lock, Bot } from "lucide-react";
#
# interface ScenarioType {
#   id: number;
#   title: string;
#   ethical: boolean;
#   icon: JSX.Element;
#   description: string;
# }
#
# /**
#  * AIEthicsLearningComponent
#  * Educational component demonstrating AI misuse through interactive scenarios
#  */
# const AIEthicsLearningComponent = () => {
#   const [draggedItem, setDraggedItem] = useState<number | null>(null);
#   const [score, setScore] = useState<number>(0);
#   const [feedback, setFeedback] = useState<string>("");
#   const [showCelebration, setShowCelebration] = useState<boolean>(false);
#
#   const scenarios: ScenarioType[] = [
#     {
#       id: 1,
#       title: "AI-Generated Homework",
#       ethical: false,
#       icon: <Bot className="w-8 h-8" />,
#       description: "Using AI to complete assignments without learning"
#     },
#     {
#       id: 2,
#       title: "Deepfake Creation",
#       ethical: false,
#       icon: <Skull className="w-8 h-8" />,
#       description: "Creating fake videos to deceive others"
#     },
#     {
#       id: 3,
#       title: "Medical Assistance",
#       ethical: true,
#       icon: <Heart className="w-8 h-8" />,
#       description: "Supporting doctors with diagnosis"
#     },
#     {
#       id: 4,
#       title: "Privacy Protection",
#       ethical: true,
#       icon: <Shield className="w-8 h-8" />,
#       description: "Securing personal data"
#     }
#   ];
#
#   const handleDragStart = (id: number) => {
#     setDraggedItem(id);
#   };
#
#   const handleDrop = (isEthicalZone: boolean) => {
#     if (draggedItem === null) return;
#
#     const scenario = scenarios.find(s => s.id === draggedItem);
#     if (!scenario) return;
#
#     const isCorrect = scenario.ethical === isEthicalZone;
#     setScore(prev => isCorrect ? prev + 1 : prev);
#     setFeedback(isCorrect ? "Correct! 🎉" : "Try again! 🤔");
#
#     if (isCorrect) {
#       setShowCelebration(true);
#       setTimeout(() => setShowCelebration(false), 2000);
#     }
#
#     setDraggedItem(null);
#   };
#
#   useEffect(() => {
#     return () => {
#       setShowCelebration(false);
#     };
#   }, []);
#
#   return (
#     <div className="min-h-screen bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-800 dark:to-gray-900 p-8">
#       <div className="max-w-4xl mx-auto">
#         <div className="text-center mb-8">
#           <h1 className="text-4xl font-bold text-gray-800 dark:text-white mb-4">
#             AI Ethics: The Right Path 🤖
#           </h1>
#           <p className="text-gray-600 dark:text-gray-300">
#             Drag scenarios to their ethical or unethical zones
#           </p>
#         </div>
#
#         <div className="flex gap-8 mb-8">
#           <div
#             className="flex-1 min-h-[300px] rounded-xl bg-green-50 dark:bg-green-900/20 p-6 border-2 border-dashed border-green-300 dark:border-green-700"
#             onDragOver={(e) => e.preventDefault()}
#             onDrop={(e) => {
#               e.preventDefault();
#               handleDrop(true);
#             }}
#           >
#             <div className="flex items-center gap-2 mb-4">
#               <CheckCircle className="text-green-500" />
#               <h2 className="text-xl font-semibold text-green-700 dark:text-green-400">Ethical Use</h2>
#             </div>
#           </div>
#
#           <div
#             className="flex-1 min-h-[300px] rounded-xl bg-red-50 dark:bg-red-900/20 p-6 border-2 border-dashed border-red-300 dark:border-red-700"
#             onDragOver={(e) => e.preventDefault()}
#             onDrop={(e) => {
#               e.preventDefault();
#               handleDrop(false);
#             }}
#           >
#             <div className="flex items-center gap-2 mb-4">
#               <XCircle className="text-red-500" />
#               <h2 className="text-xl font-semibold text-red-700 dark:text-red-400">Misuse</h2>
#             </div>
#           </div>
#         </div>
#
#         <div className="grid grid-cols-2 gap-4">
#           {scenarios.map((scenario) => (
#             <div
#               key={scenario.id}
#               draggable
#               onDragStart={() => handleDragStart(scenario.id)}
#               className={`
#                 p-4 rounded-lg bg-white dark:bg-gray-800 shadow-lg
#                 transform transition-all duration-300
#                 hover:scale-105 cursor-move
#                 border-2 border-blue-200 dark:border-blue-700
#               `}
#             >
#               <div className="flex items-center gap-3">
#                 {scenario.icon}
#                 <div>
#                   <h3 className="font-semibold text-gray-800 dark:text-white">
#                     {scenario.title}
#                   </h3>
#                   <p className="text-sm text-gray-600 dark:text-gray-300">
#                     {scenario.description}
#                   </p>
#                 </div>
#               </div>
#             </div>
#           ))}
#         </div>
#
#         {feedback && (
#           <div className="mt-6 text-center text-xl font-bold text-blue-600 dark:text-blue-400">
#             {feedback}
#           </div>
#         )}
#
#         {showCelebration && (
#           <div className="fixed inset-0 flex items-center justify-center pointer-events-none">
#             <div className="animate-bounce text-6xl">🎉</div>
#           </div>
#         )}
#       </div>
#     </div>
#   );
# };
#
# export default AIEthicsLearningComponent;
#
#   ⌛ Stage 2: Generating component implementation for Misuse...
#   ✓ Saved: misuse.tsx
#   ⏱️ Time taken: 1m 0s
#
# 📝 Processing file 9/10: decomposition.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Decomposition
#
#   ⌛ Stage 1: Generating conceptual understanding for Decomposition...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react"
# import { Puzzle, PuzzlePiece, ArrowRight, BrainCog, Check } from "lucide-react"
#
# interface DecompositionProps {}
#
# type TaskType = {
#     id: number
#     title: string
#     isComplete: boolean
#     icon: JSX.Element
# }
#
# const INITIAL_TASKS: TaskType[] = [
#     { id: 1, title: "Research Topic", isComplete: false, icon: <BrainCog className="w-6 h-6" /> },
#     { id: 2, title: "Create Outline", isComplete: false, icon: <PuzzlePiece className="w-6 h-6" /> },
#     { id: 3, title: "Write Introduction", isComplete: false, icon: <PuzzlePiece className="w-6 h-6" /> },
#     { id: 4, title: "Write Body", isComplete: false, icon: <PuzzlePiece className="w-6 h-6" /> },
#     { id: 5, title: "Write Conclusion", isComplete: false, icon: <PuzzlePiece className="w-6 h-6" /> }
# ]
#
# export default function Decomposition({}: DecompositionProps) {
#     const [tasks, setTasks] = useState<TaskType[]>(INITIAL_TASKS)
#     const [isAnimating, setIsAnimating] = useState<boolean>(true)
#     const [showSuccess, setShowSuccess] = useState<boolean>(false)
#
#     useEffect(() => {
#         const timer = setTimeout(() => {
#             setIsAnimating(false)
#         }, 2000)
#
#         return () => clearTimeout(timer)
#     }, [])
#
#     const handleTaskClick = (taskId: number) => {
#         setTasks(prev =>
#             prev.map(task =>
#                 task.id === taskId
#                     ? { ...task, isComplete: true }
#                     : task
#             )
#         )
#
#         if (tasks.filter(t => !t.isComplete).length === 1) {
#             setShowSuccess(true)
#         }
#     }
#
#     return (
#         <div className="min-h-screen bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-800 dark:to-gray-900 p-8 flex flex-col items-center justify-center">
#             <div className="max-w-2xl w-full space-y-8">
#                 <div className="text-center space-y-4">
#                     <h1 className="text-4xl font-bold text-gray-800 dark:text-white">
#                         Decomposition in AI
#                     </h1>
#                     <p className="text-gray-600 dark:text-gray-300">
#                         Breaking down complex problems into smaller, manageable pieces
#                     </p>
#                 </div>
#
#                 <div className="relative">
#                     <div className={`flex items-center justify-center mb-8 ${
#                         isAnimating ? 'scale-100' : 'scale-95'
#                     } transition-transform duration-500`}>
#                         <Puzzle className="w-20 h-20 text-blue-500 animate-pulse" />
#                     </div>
#
#                     <div className="space-y-4">
#                         {tasks.map((task, index) => (
#                             <div
#                                 key={task.id}
#                                 onClick={() => handleTaskClick(task.id)}
#                                 className={`
#                                     flex items-center space-x-4 p-4 rounded-lg
#                                     ${task.isComplete
#                                         ? 'bg-green-100 dark:bg-green-900 cursor-default'
#                                         : 'bg-white dark:bg-gray-700 hover:shadow-lg cursor-pointer'
#                                     }
#                                     transform transition-all duration-300
#                                     ${isAnimating ? 'translate-y-10 opacity-0' : 'translate-y-0 opacity-100'}
#                                 `}
#                                 style={{ transitionDelay: `${index * 100}ms` }}
#                             >
#                                 {task.icon}
#                                 <span className="flex-grow text-gray-700 dark:text-gray-200">
#                                     {task.title}
#                                 </span>
#                                 {task.isComplete && (
#                                     <Check className="w-6 h-6 text-green-500" />
#                                 )}
#                             </div>
#                         ))}
#                     </div>
#                 </div>
#
#                 {showSuccess && (
#                     <div className="text-center animate-bounce">
#                         <p className="text-green-500 text-xl font-semibold">
#                             Great job! You've decomposed the problem! 🎉
#                         </p>
#                     </div>
#                 )}
#             </div>
#         </div>
#     )
# }
#
#   ⌛ Stage 2: Generating component implementation for Decomposition...
#   ✓ Saved: decomposition.tsx
#   ⏱️ Time taken: 0m 46s
#
# 📝 Processing file 10/10: ontology.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Ontology
#
#   ⌛ Stage 1: Generating conceptual understanding for Ontology...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Tree, Book, Brain, Database, Link2, Folder, FolderTree } from "lucide-react"
#
# interface OntologyNode {
#   id: string
#   label: string
#   children?: OntologyNode[]
#   isExpanded?: boolean
# }
#
# const SAMPLE_ONTOLOGY: OntologyNode = {
#   id: "entity",
#   label: "Entity",
#   children: [
#     {
#       id: "living",
#       label: "Living Thing",
#       children: [
#         {
#           id: "animal",
#           label: "Animal",
#           children: [
#             { id: "dog", label: "Dog" },
#             { id: "cat", label: "Cat" }
#           ]
#         },
#         {
#           id: "plant",
#           label: "Plant",
#           children: [
#             { id: "tree", label: "Tree" },
#             { id: "flower", label: "Flower" }
#           ]
#         }
#       ]
#     },
#     {
#       id: "object",
#       label: "Object",
#       children: [
#         { id: "book", label: "Book" },
#         { id: "phone", label: "Phone" }
#       ]
#     }
#   ]
# }
#
# export default function OntologyVisualizer() {
#   const [ontology, setOntology] = useState<OntologyNode>(SAMPLE_ONTOLOGY)
#   const [highlightedPath, setHighlightedPath] = useState<string[]>([])
#
#   const toggleNode = (nodeId: string) => {
#     const updateNode = (node: OntologyNode): OntologyNode => {
#       if (node.id === nodeId) {
#         return { ...node, isExpanded: !node.isExpanded }
#       }
#       if (node.children) {
#         return {
#           ...node,
#           children: node.children.map(updateNode)
#         }
#       }
#       return node
#     }
#     setOntology(updateNode(ontology))
#   }
#
#   const highlightPath = (nodeId: string) => {
#     const findPath = (node: OntologyNode, path: string[] = []): string[] | null => {
#       const currentPath = [...path, node.id]
#       if (node.id === nodeId) return currentPath
#       if (!node.children) return null
#
#       for (const child of node.children) {
#         const foundPath = findPath(child, currentPath)
#         if (foundPath) return foundPath
#       }
#       return null
#     }
#
#     const path = findPath(ontology) || []
#     setHighlightedPath(path)
#   }
#
#   const renderNode = (node: OntologyNode, depth: number = 0) => {
#     const isHighlighted = highlightedPath.includes(node.id)
#
#     return (
#       <div
#         key={node.id}
#         className={`
#           transition-all duration-300
#           ${isHighlighted ? 'scale-105' : ''}
#         `}
#         style={{ marginLeft: `${depth * 24}px` }}
#       >
#         <div
#           className={`
#             flex items-center gap-2 p-2 rounded-lg cursor-pointer
#             transition-colors duration-300
#             ${isHighlighted ? 'bg-blue-500 text-white' : 'hover:bg-gray-100 dark:hover:bg-gray-800'}
#           `}
#           onClick={() => {
#             toggleNode(node.id)
#             highlightPath(node.id)
#           }}
#         >
#           {node.children ? (
#             <FolderTree className={`
#               w-5 h-5 transition-transform duration-300
#               ${node.isExpanded ? 'rotate-90' : ''}
#             `}/>
#           ) : (
#             <Link2 className="w-4 h-4" />
#           )}
#           <span className="font-medium">{node.label}</span>
#         </div>
#
#         {node.children && node.isExpanded && (
#           <div className={`
#             overflow-hidden transition-all duration-500
#             border-l-2 border-gray-200 dark:border-gray-700 ml-3
#           `}>
#             {node.children.map(child => renderNode(child, depth + 1))}
#           </div>
#         )}
#       </div>
#     )
#   }
#
#   return (
#     <div className="p-6 max-w-2xl mx-auto">
#       <div className="mb-6 text-center">
#         <h1 className="text-3xl font-bold mb-3 flex items-center justify-center gap-2">
#           <Brain className="w-8 h-8 text-blue-500" />
#           Understanding Ontologies
#         </h1>
#         <p className="text-gray-600 dark:text-gray-300">
#           Click on categories to explore how knowledge is organized in AI systems
#         </p>
#       </div>
#
#       <div className="bg-white dark:bg-gray-900 rounded-xl shadow-lg p-6 transition-all duration-300">
#         {renderNode(ontology)}
#       </div>
#
#       <div className="mt-6 text-center text-sm text-gray-500 dark:text-gray-400">
#         <p>This is how AI organizes and understands relationships between concepts</p>
#       </div>
#     </div>
#   )
# }
# ```
#
#   ⌛ Stage 2: Generating component implementation for Ontology...
#   ✓ Saved: ontology.tsx
#   ⏱️ Time taken: 0m 50s
#
# ====== Summary ======
# ✅ Successfully processed: 9
# ❌ Failed: 1
# ⏱️ Total time: 9m 1s
#
# ✨ Process completed!
