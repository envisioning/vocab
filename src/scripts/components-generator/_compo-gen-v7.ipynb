# %%
# Cell 1: Imports and Setup
# All necessary imports and API key setup
import os
import yaml
import anthropic
import time
import json
from datetime import datetime
from pathlib import Path
from typing import Dict, List, Tuple, Optional
from lucideIconList import icons
from config import ANTHROPIC_API_KEY

print(f"Anthropic version: {anthropic.__version__}")

# API Key Setup
os.environ['ANTHROPIC_API_KEY'] = ANTHROPIC_API_KEY

# Directory paths
INPUT_DIR = "/Users/kemi/Documents/GitHub/vocab/src/content/articles"
OUTPUT_DIR = "/Users/kemi/Documents/GitHub/vocab/src/components/articles/2-adjust"
CHECK0_DIR = "/Users/kemi/Documents/GitHub/vocab/src/components/articles/0"
CHECK1_DIR = "/Users/kemi/Documents/GitHub/vocab/src/components/articles/1-ok"

# Constants for Claude API
#MODEL_NAME = "claude-3-5-sonnet-20240620" 
MODEL_NAME = "claude-3-5-sonnet-20241022"
MAX_TOKENS1 = 2000
MAX_TOKENS2 = 6000
TEMPERATURE = 0.7

LUCIDEICONS = icons

# Print setup confirmation
print("🔧 Environment setup complete")
print(f"📁 Input directory: {INPUT_DIR}")
print(f"📁 Output directory: {OUTPUT_DIR}")
# Out:
# Anthropic version: 0.37.1
# 🔧 Environment setup complete
# 📁 Input directory: /Users/kemi/Documents/GitHub/vocab/src/content/articles
# 📁 Output directory: /Users/kemi/Documents/GitHub/vocab/src/components/articles/2-adjust

# %%
# Cell 2 - User Prompts

def create_concept_prompt(title: str, summary: str) -> str:
    """
    Creates the first-shot prompt focusing on conceptual understanding and metaphors.
    
    Args:
        title (str): The concept title
        summary (str): Brief summary of the concept
        
    Returns:
        str: Formatted conceptual prompt
    """
    prompt = f'''
help me explain the following AI concept in a didactic react component which helps someone learn about it, either with interaction or animation. keep it simple. use lucide icons where possible. don't use shadcn only tailwind. make it intuitive. user shouldn't have to type anything. an animation can suffice if it's illustrative of the concept in the context of AI. The interactions might include, but not limited to, moving objects, selecting objects given a criteria, sliding objects, Scroll or Pinch-to-zoom, Swipe navigation, Drag and Drop Operations, Scroll-Based Interactions, Drawing, Music notes. Use humor and relatable situations when appropriate. aim for beautiful and artistic animations. 

CONCEPT BREAKDOWN:
1. Name of the concept: {title}
2. Core Principle: {summary}

'''
    return prompt

def create_implementation_prompt(title: str, summary: str, concept_response: str) -> str:
    """
    Creates the second-shot prompt for component implementation.
    
    Args:
        title (str): The concept title
        summary (str): Brief summary of the concept
        concept_response (str): Claude's response from the first shot
        
    Returns:
        str: Formatted implementation prompt
    """
    prompt = f'''
The execution of the react component is underwhelming and confusing. 
I know you can do better. 
1. More beautiful and artistic. 
2. Add short helper texts to help convey the information better.
3. Responsive Design: Implement font and element resizing from tailwind so the component is more legible in narrower smaller screens.
4. Add system-based theme switching using the prefers-color-scheme media query and Tailwind's dark mode feature.
5. Remember: "Cube", "Robot", "Plant" and "PuzzlePiece" are not valid Lucide imports, you can use instead, only if necessary and relevant, "Box", "Bot", "Sprout" and "Puzzle" respectively. 
6. Don't use full viewport height (min-h-screen), adjust the component to only take the space it needs.

CONCEPT BREAKDOWN:
1. Name of the concept: {title}
2. Core Principle: {summary}
3. Claude 3.5 Sonnet's 1st try: 
{concept_response}

'''
    return prompt

# Print confirmation
print("✅ User Prompts loaded")
# Out:
# ✅ User Prompts loaded

# %%
# Cell 3 - Base Functions

def extract_frontmatter(content: str) -> Optional[Dict]:
    """
    Extract YAML frontmatter from markdown content.
    
    Args:
        content (str): Full markdown file content
        
    Returns:
        dict or None: Extracted frontmatter as dictionary, None if extraction fails
    """
    if content.startswith('---'):
        parts = content.split('---', 2)[1:]
        if len(parts) >= 1:
            try:
                return yaml.safe_load(parts[0])
            except yaml.YAMLError as e:
                print(f"  ⚠️ Error parsing YAML frontmatter: {str(e)}")
                return None
    return None

def format_time(seconds: float) -> str:
    """
    Format seconds into minutes and seconds.
    
    Args:
        seconds (float): Number of seconds
        
    Returns:
        str: Formatted string like "1m 30s"
    """
    return f"{int(seconds // 60)}m {int(seconds % 60)}s"

def get_existing_component_names_in_dir(directory: str) -> set:
    """
    Get names of existing components in a single directory.
    
    Args:
        directory (str): Path to components directory
        
    Returns:
        set: Set of component names (without .tsx extension)
    """
    existing_names = set()
    if os.path.exists(directory):
        for file in os.listdir(directory):
            if file.endswith('.tsx'):
                existing_names.add(file[:-4])
    return existing_names

def get_all_existing_component_names(directories: list[str]) -> set:
    """
    Get names of existing components across multiple directories.
    
    Args:
        directories (list[str]): List of directory paths to check
        
    Returns:
        set: Combined set of component names found in any directory
    """
    all_existing_names = set()
    
    for directory in directories:
        dir_components = get_existing_component_names_in_dir(directory)
        all_existing_names.update(dir_components)
    
    return all_existing_names

# Print confirmation
print("✅ Base functions loaded")
# Out:
# ✅ Base functions loaded

# %%
# Cell 4 - Component Generation Core

def generate_concept_understanding(client, title: str, prompt: str) -> str:
    """
    Generate conceptual understanding using Claude API (First shot).
    
    Args:
        client: Anthropic client instance
        title: The concept title
        prompt: Generated first-shot prompt
        
    Returns:
        str: concept explanation
    """
    print(f"\n  ⌛ Stage 1: Generating conceptual understanding for {title}...")
    
    system_prompt_concept = '''
    You are a creative artistic expert React developer and AI professor specializing in educational components for 15 to 18-year-old humans. 
Your components must strictly follow these technical requirements:

1. Architecture:
- "use client" directive at start (first line)
- import { useState, useEffect } from "react"; as the second line
- Only useState and useEffect hooks
- Only Lucide icons for visuals.
- Only Tailwind CSS for styling
- No external libraries/components
- File extension: .tsx

2. TypeScript Implementation:
interface ComponentProps {
    // Define if needed, empty interface required
}
// All state must use explicit types
const [state, setState] = useState<StateType>(initialValue);
// Event handlers must be typed
const handleEvent = (e: React.MouseEvent<HTMLButtonElement>) => {...};
// Constants outside component
const SCENARIOS: ScenarioType[] = [...];

3. Effects & Cleanup:
useEffect(() => {
    // Effect logic
    return () => {
    // Cleanup required
    };
}, [dependencies]);

4. Styling Standards:
- Only core Tailwind classes
- No arbitrary values (e.g., h-[500px])
- Transitions: duration-300 to duration-500
- Color scheme:
    • Blue (#3B82F6) - active/focus
    • Gray (#6B7280) - background
    • Green (#22C55E) - success
- Avoid minimalistic and underwhelming design. I know you can do better. Be more beautiful and artistic.
- Account for light and dark mode.

5. Code Organization:
- Max 200 lines per component
- Early returns with type guards
- JSDoc component documentation
- Proper hooks cleanup
- No inline styles
- No setTimeout/setInterval (use useEffect)
- Write the complete code, no comments or commented sections

Return only raw TSX code without explanations or markdown.
    '''
    
    try:
        response = client.messages.create(
            model=MODEL_NAME,
            max_tokens=MAX_TOKENS1,
            temperature=TEMPERATURE,
            system=system_prompt_concept,
            messages=[{"role": "user", "content": prompt}]
        )
        
        concept_response = response.content[0].text
        print(f"\n  💬 Stage 1 response: {concept_response}")
        
        return concept_response
        
    except Exception as e:
        print(f"  ❌ Error generating concept understanding: {str(e)}")
        return None

def generate_component_implementation(
    client,
    title: str,
    prompt: str,
    concept_response: str
) -> str:
    """
    Generate React component implementation using Claude API (Second shot).
    
    Args:
        client: Anthropic client instance
        title: The concept title
        prompt: Generated second-shot prompt
        concept_response: Response from first shot
        
    Returns:
        str: component_code
    """
    print(f"\n  ⌛ Stage 2: Generating component implementation for {title}...")
    
    system_prompt_implementation = '''
You are a creative artistic expert React developer and AI professor specializing in educational components for 15 to 18-year-old humans. 
Your components must strictly follow these technical requirements:

1. Architecture:
- "use client" directive at start (first line)
- import { useState, useEffect } from "react"; as the second line
- Only useState and useEffect hooks
- Only Lucide icons for visuals.
- Only Tailwind CSS for styling
- No external libraries/components
- File extension: .tsx

2. TypeScript Implementation:
interface ComponentProps {
    // Define if needed, empty interface required
}
// All state must use explicit types
const [state, setState] = useState<StateType>(initialValue);
// Event handlers must be typed
const handleEvent = (e: React.MouseEvent<HTMLButtonElement>) => {...};
// Constants outside component
const SCENARIOS: ScenarioType[] = [...];

3. Effects & Cleanup:
useEffect(() => {
    // Effect logic
    return () => {
    // Cleanup required
    };
}, [dependencies]);

4. Styling Standards:
- Only core Tailwind classes
- No arbitrary values (e.g., h-[500px])
- Transitions: duration-300 to duration-500
- Color scheme:
    • Blue (#3B82F6) - active/focus
    • Gray (#6B7280) - background
    • Green (#22C55E) - success
- Avoid minimalistic and underwhelming design. I know you can do better. Be more beautiful and artistic.

5. Code Organization:
- Max 200 lines per component
- Early returns with type guards
- JSDoc component documentation
- Proper hooks cleanup
- No inline styles
- No setTimeout/setInterval (use useEffect)
- Write the complete code, no comments or commented sections

Return only raw TSX code without explanations or markdown.
'''

# - Only Lucide icons for visuals. Limit yourself to these icons: ''' + str(LUCIDEICONS) + '''

    try:
        response = client.messages.create(
            model=MODEL_NAME,
            max_tokens=MAX_TOKENS2,
            temperature=TEMPERATURE,
            system=system_prompt_implementation,
            messages=[{
                "role": "user", 
                "content": f"{prompt}\n\nFirst-shot understanding:\n{concept_response}"
            }]
        )
        
        component_code = response.content[0].text
        
        # Clean up the code if it's wrapped in markdown
        if component_code.startswith('```'):
            first_newline = component_code.find('\n')
            if first_newline != -1:
                component_code = component_code[first_newline + 1:]
            if component_code.strip().endswith('```'):
                component_code = component_code.strip()[:-3]
        
        return component_code
        
    except Exception as e:
        print(f"  ❌ Error generating component implementation: {str(e)}")
        return None

def generate_component_with_refinement(
    client,
    title: str,
    summary: str
) -> Tuple[str, List[str]]:
    """
    Two-stage component generation with conceptual understanding and implementation.
    
    Args:
        client: Anthropic client instance
        title: Component title for logging
        summary: Brief summary of the concept
    
    Returns:
        tuple: (final_component_code, validation_issues)
    """
    # Stage 1: Conceptual Understanding
    concept_prompt = create_concept_prompt(title, summary)
    concept_response = generate_concept_understanding(
        client,
        title,
        concept_prompt
    )
    
    if not concept_response:
        return None, ["Concept generation failed"]
    
    # Stage 2: Implementation
    implementation_prompt = create_implementation_prompt(
        title,
        summary,
        concept_response
    )
    
    component_code = generate_component_implementation(
        client,
        title,
        implementation_prompt,
        concept_response
    )
    
    if not component_code:
        return None, ["Implementation generation failed"]
    
    # Validate the generated code
    issues = validate_component(component_code)
    
    if not issues:
        print("  ✅ Component validation passed")
    else:
        print("\n  ⚠️ Component validation issues found:")
        for issue in issues:
            print(f"    {issue}")
    
    return component_code, issues

# Print confirmation
print("✅ Component generation functions loaded")
# Out:
# ✅ Component generation functions loaded

# %%
# Cell 5 - Component Validation and Fixes

def save_tsx_file(
    content: str,
    md_filename: str,
    output_dir: str
) -> None:
    """
    Save the API response as a .tsx file with minimal validation.
    
    Args:
        content (str): The component code to save
        md_filename (str): Original markdown filename with .md extension
        output_dir (str): Directory to save the TSX file
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # Convert .md to .tsx while preserving exact filename
    tsx_filename = md_filename.replace('.md', '.tsx')
    filepath = os.path.join(output_dir, tsx_filename)
    
    # Clean the content
    cleaned_content = content
    if content.startswith('```'):
        first_newline = content.find('\n')
        if first_newline != -1:
            cleaned_content = content[first_newline + 1:]
        if cleaned_content.strip().endswith('```'):
            cleaned_content = cleaned_content.strip()[:-3]
    
    # Check and ensure "use client" directive
    cleaned_content = cleaned_content.strip()
    if not cleaned_content.startswith('"use client"'):
        cleaned_content = '"use client"\n\n' + cleaned_content
        print("  🔧 Added missing 'use client' directive")
    
    # Save the file
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(cleaned_content)
    print(f"  ✓ Saved: {tsx_filename}")

# Print confirmation
print("✅ Component save function loaded")
# Out:
# ✅ Component save function loaded

# %%
# Cell 6 - Main Execution

def get_generality_score(md_file):
    """
    Get the generality score from the JSON data based on the markdown file's slug.
    
    Args:
        md_file (Path): Path object for the markdown file
        
    Returns:
        float: Generality score, or -1 if not found
    """
    try:
        # Get the slug from the markdown filename by removing .md extension
        slug = md_file.stem
        
        # Read and parse the JSON file
        json_path = "/Users/kemi/Documents/GitHub/vocab/src/data/polyhierarchy.json"
        with open(json_path, 'r', encoding='utf-8') as f:
            concepts_data = json.load(f)
        
        # Find the concept with matching slug
        for concept in concepts_data:
            if concept.get('slug') == slug:
                return float(concept.get('generality', -1))
                
        return -1  # Return -1 if slug not found in JSON
        
    except Exception as e:
        print(f"  ⚠️ Error reading generality from {md_file.name}: {str(e)}")
        return -1

def process_file(client, md_file, metadata):
    """
    Process a single file to generate its component.
    
    Args:
        client: Anthropic client instance
        md_file: Path object for the markdown file
        metadata: Dictionary containing file metadata
        
    Returns:
        bool: success status
    """
    try:
        print(f"  ⌛ Creating prompts for: {metadata['title']}")
        
        # First shot - Conceptual Understanding
        concept_prompt = create_concept_prompt(metadata['title'], metadata['summary'])
        concept_response = generate_concept_understanding(
            client,
            metadata['title'],
            concept_prompt
        )
        
        if not concept_response:
            print(f"  ❌ Failed to generate concept understanding for: {md_file.name}")
            return False
            
        # Second shot - Implementation
        implementation_prompt = create_implementation_prompt(
            metadata['title'],
            metadata['summary'],
            concept_response
        )
        
        component_code = generate_component_implementation(
            client,
            metadata['title'],
            implementation_prompt,
            concept_response
        )
        
        if component_code:
            save_tsx_file(
                component_code,
                md_file.name,
                OUTPUT_DIR
            )
            return True
        else:
            print(f"  ❌ Failed to generate component for: {md_file.name}")
            return False
            
    except Exception as e:
        print(f"  ❌ Error processing file: {str(e)}")
        return False

def main():
    """Main execution function for the component generator."""
    print("\n🚀 Starting AI Component Generator...\n")
    start_time_total = time.time()
    
    try:
        # Initialize Anthropic client
        client = anthropic.Client(api_key=os.getenv('ANTHROPIC_API_KEY'))
        
        # Check directories
        print("📂 Checking directories...")
        if not os.path.exists(INPUT_DIR):
            raise Exception(f"Input directory not found: {INPUT_DIR}")
        if not os.path.exists(OUTPUT_DIR):
            os.makedirs(OUTPUT_DIR)
            print(f"  ✓ Created output directory: {OUTPUT_DIR}")
        
        # Get existing component names from all directories
        print("\n📂 Checking existing components...")
        dirs_to_check = [OUTPUT_DIR, CHECK0_DIR, CHECK1_DIR]
        existing_components = get_all_existing_component_names(dirs_to_check)
        
        if existing_components:
            print(f"  ✓ Found {len(existing_components)} existing components across all directories")
            
        # Get list of all .md files that don't have corresponding .tsx files
        all_md_files = []
        for md_file in Path(INPUT_DIR).glob('*.md'):
            if md_file.stem not in existing_components:
                all_md_files.append(md_file)
        
        total_available = len(all_md_files)
        print(f"\n📁 Found {total_available} unprocessed files")
        
        if total_available == 0:
            print("❌ No new files to process")
            return
        
        # Sort files by generality score (highest first)
        print("\n📊 Sorting files by generality score...")
        md_files_with_scores = [(f, get_generality_score(f)) for f in all_md_files]
        sorted_md_files = [f for f, score in sorted(md_files_with_scores, key=lambda x: x[1], reverse=True)]
        
        # Select top 50 files (or all if less than 50 available) ⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️
        num_files = min(10, total_available)
        md_files = sorted_md_files[:num_files]
        
        print(f"\n📈 Selected top {num_files} files by generality score")
        
        # Track statistics
        successful = 0
        failed = 0
        
        # Process each file
        for index, md_file in enumerate(md_files, 1):
            print(f"\n📝 Processing file {index}/{num_files}: {md_file.name}")
            start_time_file = time.time()
            
            try:
                print("  ⌛ Reading file...")
                with open(md_file, 'r', encoding='utf-8') as f:
                    content = f.read()
                
                print("  ⌛ Extracting metadata...")
                metadata = extract_frontmatter(content)
                if not metadata:
                    print("  ❌ Could not extract metadata")
                    failed += 1
                    continue
                
                # Process the file
                success = process_file(client, md_file, metadata)
                if success:
                    successful += 1
                else:
                    failed += 1
                
                elapsed_time = time.time() - start_time_file
                print(f"  ⏱️ Time taken: {format_time(elapsed_time)}")
                
            except Exception as e:
                print(f"  ❌ Error: {str(e)}")
                failed += 1
        
        # Print summary
        total_time = time.time() - start_time_total
        print("\n====== Summary ======")
        print(f"✅ Successfully processed: {successful}")
        print(f"❌ Failed: {failed}")
        print(f"⏱️ Total time: {format_time(total_time)}")
        
    except Exception as e:
        print(f"\n❌ Fatal error: {str(e)}")
        raise
    
    print("\n✨ Process completed!")

# %%
# Cell 7 - Run Main
if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting AI Component Generator...
#
# 📂 Checking directories...
#
# 📂 Checking existing components...
#   ✓ Found 81 existing components across all directories
#
# 📁 Found 832 unprocessed files
#
# 📊 Sorting files by generality score...
#
# 📈 Selected top 10 files by generality score
#
# 📝 Processing file 1/10: algorithm.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Algorithm
#
#   ⌛ Stage 1: Generating conceptual understanding for Algorithm...
#
#   💬 Stage 1 response: ```tsx
# "use client"
# import { useState, useEffect } from "react"
# import { ChevronRight, Coffee, Box, Pizza, Sandwich, Check } from "lucide-react"
#
# interface AlgorithmStepProps {
#     isActive: boolean
#     isComplete: boolean
#     children: React.ReactNode
# }
#
# /**
#  * Interactive component demonstrating algorithms through a fun sandwich-making sequence
#  */
# export default function AlgorithmExplainer() {
#     const [currentStep, setCurrentStep] = useState<number>(0)
#     const [isPlaying, setIsPlaying] = useState<boolean>(false)
#     const [showResult, setShowResult] = useState<boolean>(false)
#
#     const steps = [
#         "Get bread from cabinet",
#         "Take out peanut butter",
#         "Take out jelly",
#         "Spread peanut butter on one slice",
#         "Spread jelly on other slice",
#         "Put slices together",
#         "Cut diagonally (important!)",
#         "Enjoy your PB&J!"
#     ]
#
#     useEffect(() => {
#         if (isPlaying && currentStep < steps.length) {
#             const timer = setTimeout(() => {
#                 setCurrentStep(prev => prev + 1)
#                 if (currentStep === steps.length - 1) {
#                     setIsPlaying(false)
#                     setShowResult(true)
#                 }
#             }, 1500)
#
#             return () => clearTimeout(timer)
#         }
#     }, [currentStep, isPlaying, steps.length])
#
#     const handleStart = () => {
#         setCurrentStep(0)
#         setShowResult(false)
#         setIsPlaying(true)
#     }
#
#     const AlgorithmStep = ({ isActive, isComplete, children }: AlgorithmStepProps) => (
#         <div className={`flex items-center gap-3 p-4 rounded-lg transition-all duration-300 transform
#             ${isActive ? 'bg-blue-500 text-white scale-105' :
#               isComplete ? 'bg-green-500 text-white' :
#               'bg-gray-100 dark:bg-gray-800'}
#         `}>
#             {isComplete ? (
#                 <Check className="w-6 h-6" />
#             ) : (
#                 <ChevronRight className={`w-6 h-6 ${isActive ? 'animate-bounce' : ''}`} />
#             )}
#             <span className="font-medium">{children}</span>
#         </div>
#     )
#
#     return (
#         <div className="max-w-2xl mx-auto p-6 space-y-8">
#             <div className="text-center space-y-4">
#                 <h2 className="text-3xl font-bold text-gray-800 dark:text-white">
#                     Algorithm: Making a PB&J Sandwich
#                 </h2>
#                 <p className="text-gray-600 dark:text-gray-300">
#                     An algorithm is just a fancy word for a step-by-step process!
#                 </p>
#             </div>
#
#             <div className="grid gap-3">
#                 {steps.map((step, index) => (
#                     <AlgorithmStep
#                         key={index}
#                         isActive={currentStep === index}
#                         isComplete={currentStep > index}
#                     >
#                         {step}
#                     </AlgorithmStep>
#                 ))}
#             </div>
#
#             <div className="flex justify-center">
#                 <button
#                     onClick={handleStart}
#                     disabled={isPlaying}
#                     className="px-6 py-3 bg-blue-500 text-white rounded-lg hover:bg-blue-600
#                              transition duration-300 disabled:opacity-50 flex items-center gap-2"
#                 >
#                     {isPlaying ? (
#                         <>
#                             <Coffee className="w-5 h-5 animate-spin" />
#                             Running Algorithm...
#                         </>
#                     ) : (
#                         <>
#                             <Sandwich className="w-5 h-5" />
#                             {showResult ? "Make Another!" : "Start Making Sandwich"}
#                         </>
#                     )}
#                 </button>
#             </div>
#
#             {showResult && (
#                 <div className="flex justify-center">
#                     <div className="animate-bounce">
#                         <Pizza className="w-16 h-16 text-green-500" />
#                     </div>
#                 </div>
#             )}
#         </div>
#     )
# }
# ```
#
#   ⌛ Stage 2: Generating component implementation for Algorithm...
#   ✓ Saved: algorithm.tsx
#   ⏱️ Time taken: 0m 40s
#
# 📝 Processing file 2/10: training-data.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Training Data
#
#   ⌛ Stage 1: Generating conceptual understanding for Training Data...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Brain, Database, Check, X, Image, Music, MessageSquare } from "lucide-react"
#
# interface ComponentProps {}
#
# type TrainingItem = {
#   id: number
#   type: "image" | "text" | "audio"
#   label: "cat" | "dog" | "bird"
#   isLabeled: boolean
# }
#
# const INITIAL_DATA: TrainingItem[] = [
#   { id: 1, type: "image", label: "cat", isLabeled: false },
#   { id: 2, type: "image", label: "dog", isLabeled: false },
#   { id: 3, type: "audio", label: "bird", isLabeled: false },
#   { id: 4, type: "text", label: "cat", isLabeled: false },
#   { id: 5, type: "image", label: "dog", isLabeled: false },
#   { id: 6, type: "audio", label: "bird", isLabeled: false }
# ]
#
# /**
#  * Interactive component demonstrating AI training data concepts
#  * Shows data labeling process and model training visualization
#  */
# export default function TrainingDataDemo({}: ComponentProps) {
#   const [items, setItems] = useState<TrainingItem[]>(INITIAL_DATA)
#   const [isTraining, setIsTraining] = useState(false)
#   const [progress, setProgress] = useState(0)
#   const [modelReady, setModelReady] = useState(false)
#
#   const handleLabel = (id: number) => {
#     setItems(prev =>
#       prev.map(item =>
#         item.id === id ? {...item, isLabeled: true} : item
#       )
#     )
#   }
#
#   useEffect(() => {
#     if (isTraining) {
#       const interval = setInterval(() => {
#         setProgress(prev => {
#           if (prev >= 100) {
#             setIsTraining(false)
#             setModelReady(true)
#             return 100
#           }
#           return prev + 10
#         })
#       }, 200)
#
#       return () => clearInterval(interval)
#     }
#   }, [isTraining])
#
#   const getIcon = (type: string) => {
#     switch(type) {
#       case "image": return <Image className="w-6 h-6" />
#       case "audio": return <Music className="w-6 h-6" />
#       case "text": return <MessageSquare className="w-6 h-6" />
#       default: return null
#     }
#   }
#
#   return (
#     <div className="min-h-screen bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-900 dark:to-gray-800 p-8">
#       <div className="max-w-4xl mx-auto space-y-8">
#         <div className="text-center space-y-4">
#           <h1 className="text-4xl font-bold text-gray-800 dark:text-white">
#             Training Data Explorer 🎓
#           </h1>
#           <p className="text-gray-600 dark:text-gray-300">
#             Help label the training data to teach our AI model!
#           </p>
#         </div>
#
#         <div className="grid grid-cols-2 md:grid-cols-3 gap-4">
#           {items.map(item => (
#             <div
#               key={item.id}
#               className={`
#                 p-6 rounded-lg border-2 transition-all duration-300
#                 ${item.isLabeled
#                   ? 'border-green-500 bg-green-50 dark:bg-green-900/20'
#                   : 'border-gray-300 bg-white dark:bg-gray-800 hover:border-blue-500'
#                 }
#               `}
#             >
#               <div className="flex items-center justify-between">
#                 {getIcon(item.type)}
#                 <span className="text-sm text-gray-600 dark:text-gray-300">
#                   {item.label}
#                 </span>
#               </div>
#
#               {!item.isLabeled && (
#                 <button
#                   onClick={() => handleLabel(item.id)}
#                   className="mt-4 w-full py-2 px-4 bg-blue-500 text-white rounded-md
#                     hover:bg-blue-600 transition-colors duration-300"
#                 >
#                   Label Data
#                 </button>
#               )}
#             </div>
#           ))}
#         </div>
#
#         <div className="flex justify-center">
#           <button
#             onClick={() => setIsTraining(true)}
#             disabled={!items.every(item => item.isLabeled) || isTraining || modelReady}
#             className={`
#               px-6 py-3 rounded-lg flex items-center space-x-2
#               ${items.every(item => item.isLabeled) && !modelReady
#                 ? 'bg-blue-500 hover:bg-blue-600 text-white'
#                 : 'bg-gray-300 text-gray-600 cursor-not-allowed'
#               }
#               transition-all duration-300
#             `}
#           >
#             <Brain className="w-5 h-5" />
#             <span>Train Model</span>
#           </button>
#         </div>
#
#         {isTraining && (
#           <div className="space-y-2">
#             <div className="h-2 bg-gray-200 rounded-full overflow-hidden">
#               <div
#                 className="h-full bg-blue-500 transition-all duration-300"
#                 style={{ width: `${progress}%` }}
#               />
#             </div>
#             <p className="text-center text-gray-600 dark:text-gray-300">
#               Training in progress... {progress}%
#             </p>
#           </div>
#         )}
#
#         {modelReady && (
#           <div className="text-center p-6 bg-green-100 dark:bg-green-900/20 rounded-lg">
#             <Check className="w-12 h-12 text-green-500 mx-auto mb-2" />
#             <p className="text-green-700 dark:text-green-300 font-medium">
#               Model successfully trained! 🎉
#             </p>
#           </div>
#         )}
#       </div>
#     </div>
#   )
# }
# ```
#
#   ⌛ Stage 2: Generating component implementation for Training Data...
#   ✓ Saved: training-data.tsx
#   ⏱️ Time taken: 1m 1s
#
# 📝 Processing file 3/10: universality.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Universality
#
#   ⌛ Stage 1: Generating conceptual understanding for Universality...
#
#   💬 Stage 1 response: ```tsx
# "use client"
# import { useState, useEffect } from "react"
# import { Computer, Smartphone, Calculator, Watch, Brain, ArrowRight } from "lucide-react"
#
# interface ComponentProps {}
#
# type Device = {
#   icon: JSX.Element
#   name: string
#   isSimulating: boolean
# }
#
# /**
#  * UniversalityDemo demonstrates how a computer can simulate other computational devices
#  * through an interactive visualization with transitions and animations
#  */
# const UniversalityDemo: React.FC<ComponentProps> = () => {
#   const [selectedDevice, setSelectedDevice] = useState<number>(0)
#   const [isSimulating, setIsSimulating] = useState<boolean>(false)
#
#   const devices: Device[] = [
#     { icon: <Calculator size={32} />, name: "Calculator", isSimulating: false },
#     { icon: <Smartphone size={32} />, name: "Phone", isSimulating: false },
#     { icon: <Watch size={32} />, name: "Smart Watch", isSimulating: false },
#     { icon: <Brain size={32} />, name: "Neural Network", isSimulating: false }
#   ]
#
#   useEffect(() => {
#     if (isSimulating) {
#       const timer = setTimeout(() => {
#         setIsSimulating(false)
#       }, 3000)
#       return () => clearTimeout(timer)
#     }
#   }, [isSimulating])
#
#   const handleDeviceClick = (index: number) => {
#     setSelectedDevice(index)
#     setIsSimulating(true)
#   }
#
#   return (
#     <div className="min-h-screen bg-gradient-to-br from-gray-50 to-gray-200 dark:from-gray-800 dark:to-gray-900 p-8">
#       <div className="max-w-4xl mx-auto">
#         <h1 className="text-4xl font-bold text-gray-800 dark:text-white mb-8 text-center">
#           Universal Computation
#         </h1>
#
#         <div className="bg-white dark:bg-gray-800 rounded-xl shadow-xl p-8">
#           <div className="flex justify-center mb-12">
#             <div className={`
#               transform transition-all duration-500 p-8 rounded-xl
#               ${isSimulating ? 'bg-blue-500' : 'bg-gray-100 dark:bg-gray-700'}
#               `}>
#               <Computer size={64} className={`
#                 ${isSimulating ? 'text-white animate-pulse' : 'text-gray-600 dark:text-gray-300'}
#               `} />
#               <p className="text-center mt-2 font-medium text-gray-700 dark:text-gray-300">
#                 Universal Computer
#               </p>
#             </div>
#           </div>
#
#           <div className="grid grid-cols-2 gap-8 md:grid-cols-4">
#             {devices.map((device, index) => (
#               <div
#                 key={device.name}
#                 onClick={() => handleDeviceClick(index)}
#                 className={`
#                   relative cursor-pointer transform transition-all duration-300
#                   hover:scale-105 p-6 rounded-xl text-center
#                   ${selectedDevice === index && isSimulating
#                     ? 'bg-green-500 text-white'
#                     : 'bg-gray-100 dark:bg-gray-700 text-gray-700 dark:text-gray-300'
#                   }
#                 `}
#               >
#                 <div className="flex justify-center mb-2">
#                   {device.icon}
#                 </div>
#                 <p className="font-medium">{device.name}</p>
#
#                 {selectedDevice === index && isSimulating && (
#                   <div className="absolute -top-6 left-1/2 transform -translate-x-1/2">
#                     <ArrowRight className="text-blue-500 animate-bounce" />
#                   </div>
#                 )}
#               </div>
#             ))}
#           </div>
#
#           <div className="mt-8 text-center text-gray-600 dark:text-gray-400">
#             <p className="text-lg">
#               {isSimulating
#                 ? "Simulating selected device... 🚀"
#                 : "Click any device to see the universal computer simulate it! 🎮"}
#             </p>
#           </div>
#         </div>
#
#         <div className="mt-8 bg-white dark:bg-gray-800 rounded-xl shadow-xl p-6">
#           <p className="text-gray-600 dark:text-gray-400 text-center">
#             Just like how your computer can run a calculator app, play games, or simulate
#             neural networks, a universal computer can simulate any computational system!
#             It's like having a super-talented actor who can play any role perfectly. 🎭
#           </p>
#         </div>
#       </div>
#     </div>
#   )
# }
#
# export default UniversalityDemo
# ```
#
#   ⌛ Stage 2: Generating component implementation for Universality...
#   ✓ Saved: universality.tsx
#   ⏱️ Time taken: 0m 44s
#
# 📝 Processing file 4/10: training.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Training
#
#   ⌛ Stage 1: Generating conceptual understanding for Training...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Brain, Target, Crosshair, CheckCircle2, XCircle } from "lucide-react"
#
# interface TrainingProps {}
#
# type DataPoint = {
#   x: number
#   y: number
#   label: "cat" | "dog"
#   isCorrect?: boolean
# }
#
# const INITIAL_DATA: DataPoint[] = [
#   { x: 20, y: 30, label: "cat" },
#   { x: 60, y: 70, label: "dog" },
#   { x: 40, y: 50, label: "cat" },
#   { x: 80, y: 20, label: "dog" },
#   { x: 30, y: 80, label: "cat" }
# ]
#
# /**
#  * Interactive AI Training Visualization Component
#  * Demonstrates how ML models learn from data through animated training iterations
#  */
# export default function Training({}: TrainingProps) {
#   const [iteration, setIteration] = useState<number>(0)
#   const [accuracy, setAccuracy] = useState<number>(0)
#   const [data, setData] = useState<DataPoint[]>(INITIAL_DATA)
#   const [isTraining, setIsTraining] = useState<boolean>(false)
#   const [decisionBoundary, setDecisionBoundary] = useState<number>(50)
#
#   useEffect(() => {
#     if (!isTraining) return
#
#     const interval = setInterval(() => {
#       if (iteration >= 5) {
#         setIsTraining(false)
#         return
#       }
#
#       // Simulate model learning
#       setDecisionBoundary(prev => prev + (Math.random() - 0.5) * 10)
#
#       // Update data points with predictions
#       setData(prev => prev.map(point => ({
#         ...point,
#         isCorrect: (point.y > decisionBoundary && point.label === "cat") ||
#                   (point.y <= decisionBoundary && point.label === "dog")
#       })))
#
#       setAccuracy(Math.min(100, accuracy + Math.random() * 20))
#       setIteration(prev => prev + 1)
#     }, 1000)
#
#     return () => clearInterval(interval)
#   }, [isTraining, iteration, accuracy, decisionBoundary])
#
#   const handleStartTraining = () => {
#     setIsTraining(true)
#     setIteration(0)
#     setAccuracy(20)
#   }
#
#   return (
#     <div className="w-full max-w-2xl mx-auto p-8 bg-white dark:bg-gray-800 rounded-xl shadow-xl">
#       <div className="flex items-center justify-between mb-8">
#         <h2 className="text-2xl font-bold text-gray-800 dark:text-white flex items-center gap-2">
#           <Brain className="w-8 h-8 text-blue-500" />
#           AI Training Playground
#         </h2>
#         <div className="flex items-center gap-2">
#           <span className="text-gray-600 dark:text-gray-300">
#             Accuracy: {accuracy.toFixed(1)}%
#           </span>
#           <Target className="w-5 h-5 text-green-500" />
#         </div>
#       </div>
#
#       <div className="relative h-80 bg-gray-100 dark:bg-gray-700 rounded-lg mb-6 overflow-hidden">
#         {/* Decision Boundary */}
#         <div
#           className="absolute w-full h-0.5 bg-blue-500 transition-all duration-500"
#           style={{ top: `${decisionBoundary}%` }}
#         />
#
#         {/* Data Points */}
#         {data.map((point, i) => (
#           <div
#             key={i}
#             className={`absolute w-8 h-8 -translate-x-1/2 -translate-y-1/2
#               transition-all duration-500 flex items-center justify-center`}
#             style={{ left: `${point.x}%`, top: `${point.y}%` }}
#           >
#             {point.label === "cat" ? "🐱" : "🐶"}
#             {point.isCorrect !== undefined && (
#               point.isCorrect ?
#                 <CheckCircle2 className="absolute -top-2 -right-2 w-4 h-4 text-green-500" /> :
#                 <XCircle className="absolute -top-2 -right-2 w-4 h-4 text-red-500" />
#             )}
#           </div>
#         ))}
#       </div>
#
#       <div className="flex justify-between items-center">
#         <button
#           onClick={handleStartTraining}
#           disabled={isTraining}
#           className={`
#             px-6 py-3 rounded-lg font-medium flex items-center gap-2
#             ${isTraining ?
#               'bg-gray-300 text-gray-600 cursor-not-allowed' :
#               'bg-blue-500 text-white hover:bg-blue-600 transition-colors duration-300'
#             }
#           `}
#         >
#           <Crosshair className="w-5 h-5" />
#           {isTraining ? 'Training...' : 'Start Training'}
#         </button>
#
#         <div className="text-gray-600 dark:text-gray-300">
#           Iteration: {iteration}/5
#         </div>
#       </div>
#     </div>
#   )
# }
# ```
#
#   ⌛ Stage 2: Generating component implementation for Training...
#   ✓ Saved: training.tsx
#   ⏱️ Time taken: 0m 52s
#
# 📝 Processing file 5/10: bnns-biological-neural-networks.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: BNNs (Biological Neural Networks)
#
#   ⌛ Stage 1: Generating conceptual understanding for BNNs (Biological Neural Networks)...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react";
# import { Brain, Zap, Connection, Activity, ArrowRight } from "lucide-react";
#
# interface NeuronState {
#   id: number;
#   active: boolean;
#   position: { x: number; y: number };
# }
#
# interface ComponentProps {}
#
# const INITIAL_NEURONS: NeuronState[] = [
#   { id: 1, active: false, position: { x: 20, y: 30 } },
#   { id: 2, active: false, position: { x: 50, y: 20 } },
#   { id: 3, active: false, position: { x: 80, y: 40 } },
#   { id: 4, active: false, position: { x: 40, y: 60 } },
#   { id: 5, active: false, position: { x: 70, y: 70 } },
# ];
#
# /**
#  * BiologicalNeuralNetwork - Interactive demonstration of neural signal propagation
#  */
# const BiologicalNeuralNetwork: React.FC<ComponentProps> = () => {
#   const [neurons, setNeurons] = useState<NeuronState[]>(INITIAL_NEURONS);
#   const [isSimulating, setIsSimulating] = useState<boolean>(false);
#   const [currentStep, setCurrentStep] = useState<number>(0);
#
#   useEffect(() => {
#     if (!isSimulating) return;
#
#     const interval = setInterval(() => {
#       setNeurons((prev) => {
#         const newNeurons = [...prev];
#         const activeIndex = currentStep % newNeurons.length;
#         newNeurons.forEach((n, i) => {
#           n.active = i === activeIndex;
#         });
#         return newNeurons;
#       });
#       setCurrentStep((prev) => prev + 1);
#     }, 800);
#
#     return () => clearInterval(interval);
#   }, [isSimulating, currentStep]);
#
#   const handleSimulationToggle = () => {
#     setIsSimulating((prev) => !prev);
#     if (isSimulating) {
#       setNeurons(INITIAL_NEURONS);
#       setCurrentStep(0);
#     }
#   };
#
#   return (
#     <div className="w-full min-h-[500px] p-8 bg-gradient-to-br from-gray-50 to-blue-50 dark:from-gray-900 dark:to-blue-900 rounded-xl shadow-xl">
#       <div className="flex flex-col items-center space-y-6">
#         <div className="flex items-center space-x-3">
#           <Brain className="w-8 h-8 text-blue-500" />
#           <h2 className="text-2xl font-bold text-gray-800 dark:text-white">
#             Biological Neural Network
#           </h2>
#         </div>
#
#         <div className="relative w-full h-[300px] bg-white/30 dark:bg-gray-800/30 rounded-lg backdrop-blur-sm">
#           {neurons.map((neuron) => (
#             <div
#               key={neuron.id}
#               className="absolute transform -translate-x-1/2 -translate-y-1/2"
#               style={{
#                 left: `${neuron.position.x}%`,
#                 top: `${neuron.position.y}%`,
#               }}
#             >
#               <div
#                 className={`w-12 h-12 rounded-full flex items-center justify-center transition-all duration-500
#                 ${
#                   neuron.active
#                     ? "bg-blue-500 scale-110 shadow-lg shadow-blue-500/50"
#                     : "bg-gray-300 dark:bg-gray-600"
#                 }`}
#               >
#                 <Activity
#                   className={`w-6 h-6 ${
#                     neuron.active ? "text-white" : "text-gray-600 dark:text-gray-300"
#                   }`}
#                 />
#               </div>
#               {neuron.active && (
#                 <div className="absolute inset-0 w-12 h-12 rounded-full animate-ping bg-blue-500/30" />
#               )}
#             </div>
#           ))}
#
#           <svg className="absolute inset-0 w-full h-full">
#             {neurons.map((n1) =>
#               neurons
#                 .filter((n2) => n2.id > n1.id)
#                 .map((n2) => (
#                   <line
#                     key={`${n1.id}-${n2.id}`}
#                     x1={`${n1.position.x}%`}
#                     y1={`${n1.position.y}%`}
#                     x2={`${n2.position.x}%`}
#                     y2={`${n2.position.y}%`}
#                     className={`stroke-gray-300 dark:stroke-gray-600 stroke-2 ${
#                       n1.active || n2.active ? "stroke-blue-500" : ""
#                     }`}
#                   />
#                 ))
#             )}
#           </svg>
#         </div>
#
#         <button
#           onClick={handleSimulationToggle}
#           className="flex items-center space-x-2 px-6 py-3 bg-blue-500 hover:bg-blue-600 text-white rounded-full transition-colors duration-300"
#         >
#           <Zap className="w-5 h-5" />
#           <span>{isSimulating ? "Stop Signal" : "Start Signal"}</span>
#         </button>
#
#         <p className="text-center text-gray-600 dark:text-gray-300 max-w-md">
#           Watch how neurons activate and transmit signals through their network,
#           just like the billions of neurons in your brain right now trying to
#           understand this concept! 🧠✨
#         </p>
#       </div>
#     </div>
#   );
# };
#
# export default BiologicalNeuralNetwork;
#
#   ⌛ Stage 2: Generating component implementation for BNNs (Biological Neural Networks)...
#   ✓ Saved: bnns-biological-neural-networks.tsx
#   ⏱️ Time taken: 0m 54s
#
# 📝 Processing file 6/10: loss-function.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Loss Function
#
#   ⌛ Stage 1: Generating conceptual understanding for Loss Function...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react"
# import { Brain, Target, ArrowRight, Frown, Smile } from "lucide-react"
#
# interface PredictionPoint {
#     actual: number
#     predicted: number
#     error: number
# }
#
# interface ComponentProps {}
#
# const LossFunctionVisualizer: React.FC<ComponentProps> = () => {
#     const [predictions, setPredictions] = useState<PredictionPoint[]>([])
#     const [totalLoss, setTotalLoss] = useState<number>(0)
#     const [isAnimating, setIsAnimating] = useState<boolean>(true)
#
#     useEffect(() => {
#         const initialPredictions: PredictionPoint[] = [
#             { actual: 80, predicted: 30, error: 50 },
#             { actual: 40, predicted: 60, error: -20 },
#             { actual: 60, predicted: 55, error: 5 },
#             { actual: 20, predicted: 35, error: -15 },
#             { actual: 90, predicted: 75, error: 15 }
#         ]
#
#         let currentIndex = 0
#         const interval = setInterval(() => {
#             if (currentIndex < initialPredictions.length) {
#                 setPredictions(prev => [...prev, initialPredictions[currentIndex]])
#                 setTotalLoss(prev => prev + Math.abs(initialPredictions[currentIndex].error))
#                 currentIndex++
#             } else {
#                 setIsAnimating(false)
#                 clearInterval(interval)
#             }
#         }, 1000)
#
#         return () => clearInterval(interval)
#     }, [])
#
#     return (
#         <div className="min-h-screen bg-gradient-to-b from-gray-100 to-gray-200 dark:from-gray-800 dark:to-gray-900 p-8">
#             <div className="max-w-4xl mx-auto space-y-8">
#                 <div className="text-center space-y-4">
#                     <h1 className="text-4xl font-bold text-gray-800 dark:text-gray-100">
#                         Loss Function Visualizer
#                     </h1>
#                     <p className="text-gray-600 dark:text-gray-300">
#                         Watch how our AI model learns from its mistakes!
#                     </p>
#                 </div>
#
#                 <div className="bg-white dark:bg-gray-800 rounded-xl shadow-xl p-6">
#                     <div className="h-80 relative">
#                         <div className="absolute left-0 h-full w-px bg-gray-300 dark:bg-gray-600" />
#                         <div className="absolute bottom-0 w-full h-px bg-gray-300 dark:bg-gray-600" />
#
#                         {predictions.map((point, index) => (
#                             <div
#                                 key={index}
#                                 className="absolute transition-all duration-500 transform"
#                                 style={{
#                                     left: `${(index / 4) * 80 + 10}%`,
#                                     bottom: `${point.actual}%`
#                                 }}
#                             >
#                                 <div className="relative">
#                                     <Target className="w-4 h-4 text-blue-500" />
#                                     <div
#                                         className="absolute w-px bg-red-400 transition-all duration-500"
#                                         style={{
#                                             height: `${Math.abs(point.error)}%`,
#                                             bottom: point.error > 0 ? '0' : 'auto',
#                                             top: point.error > 0 ? 'auto' : '0'
#                                         }}
#                                     />
#                                     <div
#                                         className="absolute w-4 h-4 -ml-2 transition-all duration-500"
#                                         style={{
#                                             bottom: point.error > 0 ? `${Math.abs(point.error)}%` : 'auto',
#                                             top: point.error > 0 ? 'auto' : `${Math.abs(point.error)}%`
#                                         }}
#                                     >
#                                         <Brain className="w-4 h-4 text-purple-500" />
#                                     </div>
#                                 </div>
#                             </div>
#                         ))}
#                     </div>
#
#                     <div className="mt-6 flex items-center justify-between">
#                         <div className="flex items-center space-x-2">
#                             <Target className="w-5 h-5 text-blue-500" />
#                             <span className="text-gray-600 dark:text-gray-300">Actual Value</span>
#                         </div>
#                         <div className="flex items-center space-x-2">
#                             <Brain className="w-5 h-5 text-purple-500" />
#                             <span className="text-gray-600 dark:text-gray-300">Predicted Value</span>
#                         </div>
#                         <div className="flex items-center space-x-2">
#                             <div className="w-4 h-4 bg-red-400 rounded-full" />
#                             <span className="text-gray-600 dark:text-gray-300">Error</span>
#                         </div>
#                     </div>
#                 </div>
#
#                 <div className="bg-white dark:bg-gray-800 rounded-xl shadow-xl p-6 text-center">
#                     <h2 className="text-2xl font-bold text-gray-800 dark:text-gray-100 mb-4">
#                         Total Loss: {totalLoss.toFixed(2)}
#                     </h2>
#                     <div className="flex justify-center">
#                         {totalLoss > 50 ? (
#                             <Frown className="w-12 h-12 text-red-500 animate-bounce" />
#                         ) : (
#                             <Smile className="w-12 h-12 text-green-500 animate-bounce" />
#                         )}
#                     </div>
#                 </div>
#             </div>
#         </div>
#     )
# }
#
# export default LossFunctionVisualizer
#
#   ⌛ Stage 2: Generating component implementation for Loss Function...
#   ✓ Saved: loss-function.tsx
#   ⏱️ Time taken: 0m 54s
#
# 📝 Processing file 7/10: tensorflow.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: TensorFlow
#
#   ⌛ Stage 1: Generating conceptual understanding for TensorFlow...
#
#   💬 Stage 1 response: ```tsx
# "use client"
# import { useState, useEffect } from "react"
# import { Brain, Box, Network, Play, Pause, RotateCcw } from "lucide-react"
#
# interface TensorFlowVisualizerProps {}
#
# type Node = {
#   id: number
#   x: number
#   y: number
#   active: boolean
# }
#
# const INITIAL_NODES: Node[] = Array.from({length: 12}, (_, i) => ({
#   id: i,
#   x: (i % 4) * 160 + 100,
#   y: Math.floor(i / 4) * 120 + 100,
#   active: false
# }))
#
# /**
#  * An interactive visualization demonstrating TensorFlow's neural network computation
#  * with flowing data and node activation animations
#  */
# const TensorFlowVisualizer = ({}: TensorFlowVisualizerProps) => {
#   const [nodes, setNodes] = useState<Node[]>(INITIAL_NODES)
#   const [isPlaying, setIsPlaying] = useState<boolean>(false)
#   const [iteration, setIteration] = useState<number>(0)
#
#   useEffect(() => {
#     if (!isPlaying) return
#
#     const interval = setInterval(() => {
#       setNodes(prev => prev.map(node => ({
#         ...node,
#         active: Math.random() > 0.5
#       })))
#       setIteration(i => i + 1)
#     }, 800)
#
#     return () => clearInterval(interval)
#   }, [isPlaying])
#
#   const handleReset = () => {
#     setNodes(INITIAL_NODES)
#     setIteration(0)
#     setIsPlaying(false)
#   }
#
#   return (
#     <div className="relative w-full max-w-3xl mx-auto p-8 rounded-xl bg-gradient-to-br from-slate-50 to-blue-50 dark:from-slate-900 dark:to-blue-900 shadow-xl">
#       <div className="absolute top-4 right-4 flex gap-2">
#         <button
#           onClick={() => setIsPlaying(!isPlaying)}
#           className="p-2 rounded-lg bg-blue-500 text-white hover:bg-blue-600 transition-colors duration-300"
#         >
#           {isPlaying ? <Pause size={24} /> : <Play size={24} />}
#         </button>
#         <button
#           onClick={handleReset}
#           className="p-2 rounded-lg bg-gray-500 text-white hover:bg-gray-600 transition-colors duration-300"
#         >
#           <RotateCcw size={24} />
#         </button>
#       </div>
#
#       <div className="flex items-center gap-3 mb-8">
#         <Brain className="w-8 h-8 text-blue-500" />
#         <h2 className="text-2xl font-bold text-gray-800 dark:text-white">
#           TensorFlow Visualization
#         </h2>
#       </div>
#
#       <div className="relative h-[400px]">
#         {nodes.map((node, i) => (
#           <div
#             key={node.id}
#             className={`absolute transform -translate-x-1/2 -translate-y-1/2 transition-all duration-500
#               ${node.active ? 'scale-110' : 'scale-100'}`}
#             style={{left: node.x, top: node.y}}
#           >
#             <div className={`w-16 h-16 rounded-xl flex items-center justify-center
#               ${node.active
#                 ? 'bg-blue-500 shadow-lg shadow-blue-500/50'
#                 : 'bg-gray-200 dark:bg-gray-700'}
#               transition-colors duration-300`}
#             >
#               {i % 2 === 0 ? (
#                 <Network className={`w-8 h-8 ${node.active ? 'text-white' : 'text-gray-500'}`} />
#               ) : (
#                 <Box className={`w-8 h-8 ${node.active ? 'text-white' : 'text-gray-500'}`} />
#               )}
#             </div>
#
#             {iteration > 0 && node.active && (
#               <div className="absolute inset-0 animate-ping rounded-xl bg-blue-400 opacity-20" />
#             )}
#           </div>
#         ))}
#
#         {/* Connection Lines */}
#         <svg className="absolute inset-0 w-full h-full -z-10">
#           {nodes.map(node =>
#             nodes
#               .filter(n => Math.abs(n.x - node.x) <= 160 && Math.abs(n.y - node.y) <= 120)
#               .map(target => (
#                 <line
#                   key={`${node.id}-${target.id}`}
#                   x1={node.x}
#                   y1={node.y}
#                   x2={target.x}
#                   y2={target.y}
#                   className={`${
#                     node.active && target.active
#                       ? 'stroke-blue-400 stroke-2'
#                       : 'stroke-gray-200 dark:stroke-gray-700'
#                   } transition-colors duration-300`}
#                 />
#               ))
#           )}
#         </svg>
#       </div>
#
#       <div className="mt-6 text-center text-gray-600 dark:text-gray-300">
#         <p>Iteration: {iteration}</p>
#         <p className="mt-2 text-sm">
#           Watch as TensorFlow processes data through its neural network,
#           <br />activating nodes and strengthening connections
#         </p>
#       </div>
#     </div>
#   )
# }
#
# export default TensorFlowVisualizer
# ```
#
#   ⌛ Stage 2: Generating component implementation for TensorFlow...
#   ✓ Saved: tensorflow.tsx
#   ⏱️ Time taken: 0m 59s
#
# 📝 Processing file 8/10: neural-network.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Neural Network
#
#   ⌛ Stage 1: Generating conceptual understanding for Neural Network...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react";
# import { Brain, Circle, ArrowRight, Zap } from "lucide-react";
#
# interface NeuralNode {
#   id: number;
#   active: boolean;
# }
#
# interface ComponentProps {}
#
# const INITIAL_INPUT: NeuralNode[] = [
#   { id: 1, active: false },
#   { id: 2, active: false },
#   { id: 3, active: false },
# ];
#
# const HIDDEN_LAYER: NeuralNode[] = [
#   { id: 4, active: false },
#   { id: 5, active: false },
#   { id: 6, active: false },
#   { id: 7, active: false },
# ];
#
# const OUTPUT_LAYER: NeuralNode[] = [
#   { id: 8, active: false },
#   { id: 9, active: false },
# ];
#
# const NeuralNetworkVisualizer: React.FC<ComponentProps> = () => {
#   const [inputNodes, setInputNodes] = useState<NeuralNode[]>(INITIAL_INPUT);
#   const [hiddenNodes, setHiddenNodes] = useState<NeuralNode[]>(HIDDEN_LAYER);
#   const [outputNodes, setOutputNodes] = useState<NeuralNode[]>(OUTPUT_LAYER);
#   const [isProcessing, setIsProcessing] = useState<boolean>(false);
#
#   const activateNetwork = (inputId: number) => {
#     setIsProcessing(true);
#     setInputNodes(prev =>
#       prev.map(node => ({
#         ...node,
#         active: node.id === inputId,
#       }))
#     );
#
#     setTimeout(() => {
#       setHiddenNodes(prev =>
#         prev.map(node => ({
#           ...node,
#           active: Math.random() > 0.5,
#         }))
#       );
#     }, 500);
#
#     setTimeout(() => {
#       setOutputNodes(prev =>
#         prev.map(node => ({
#           ...node,
#           active: Math.random() > 0.5,
#         }))
#       );
#     }, 1000);
#
#     setTimeout(() => {
#       setIsProcessing(false);
#       resetNetwork();
#     }, 2000);
#   };
#
#   const resetNetwork = () => {
#     setTimeout(() => {
#       setInputNodes(INITIAL_INPUT);
#       setHiddenNodes(HIDDEN_LAYER);
#       setOutputNodes(OUTPUT_LAYER);
#     }, 1000);
#   };
#
#   return (
#     <div className="flex flex-col items-center justify-center min-h-screen bg-gradient-to-b from-gray-100 to-gray-200 dark:from-gray-800 dark:to-gray-900 p-8">
#       <div className="mb-8 flex items-center gap-2">
#         <Brain className="w-8 h-8 text-blue-500" />
#         <h1 className="text-3xl font-bold text-gray-800 dark:text-white">Neural Network Simulator</h1>
#       </div>
#
#       <div className="relative w-full max-w-3xl h-96">
#         {/* Input Layer */}
#         <div className="absolute left-0 top-1/2 -translate-y-1/2 flex flex-col gap-8">
#           {inputNodes.map(node => (
#             <button
#               key={node.id}
#               disabled={isProcessing}
#               onClick={() => activateNetwork(node.id)}
#               className={`w-12 h-12 rounded-full border-2 transition-all duration-300 flex items-center justify-center
#                 ${
#                   node.active
#                     ? "bg-blue-500 border-blue-600"
#                     : "bg-white border-gray-300 hover:border-blue-400"
#                 }
#                 ${isProcessing ? "cursor-not-allowed" : "cursor-pointer"}
#               `}
#             >
#               <Circle
#                 className={`w-6 h-6 ${
#                   node.active ? "text-white" : "text-gray-400"
#                 }`}
#               />
#             </button>
#           ))}
#         </div>
#
#         {/* Hidden Layer */}
#         <div className="absolute left-1/2 top-1/2 -translate-x-1/2 -translate-y-1/2 flex flex-col gap-6">
#           {hiddenNodes.map(node => (
#             <div
#               key={node.id}
#               className={`w-10 h-10 rounded-full border-2 transition-all duration-300 flex items-center justify-center
#                 ${
#                   node.active
#                     ? "bg-blue-500 border-blue-600"
#                     : "bg-white border-gray-300"
#                 }
#               `}
#             >
#               <Zap
#                 className={`w-5 h-5 ${
#                   node.active ? "text-white" : "text-gray-400"
#                 }`}
#               />
#             </div>
#           ))}
#         </div>
#
#         {/* Output Layer */}
#         <div className="absolute right-0 top-1/2 -translate-y-1/2 flex flex-col gap-8">
#           {outputNodes.map(node => (
#             <div
#               key={node.id}
#               className={`w-12 h-12 rounded-full border-2 transition-all duration-300 flex items-center justify-center
#                 ${
#                   node.active
#                     ? "bg-green-500 border-green-600"
#                     : "bg-white border-gray-300"
#                 }
#               `}
#             >
#               <ArrowRight
#                 className={`w-6 h-6 ${
#                   node.active ? "text-white" : "text-gray-400"
#                 }`}
#               />
#             </div>
#           ))}
#         </div>
#
#         {/* Connection Lines */}
#         <svg className="absolute inset-0 w-full h-full -z-10">
#           <defs>
#             <linearGradient id="gradient" x1="0%" y1="0%" x2="100%" y2="0%">
#               <stop offset="0%" stopColor="#3B82F6" stopOpacity="0.2" />
#               <stop offset="100%" stopColor="#22C55E" stopOpacity="0.2" />
#             </linearGradient>
#           </defs>
#           {inputNodes.map(input =>
#             hiddenNodes.map(hidden => (
#               <line
#                 key={`${input.id}-${hidden.id}`}
#                 x1="60"
#                 y1={100 + input.id * 80}
#                 x2="400"
#                 y2={80 + hidden.id * 60}
#                 stroke="url(#gradient)"
#                 strokeWidth="1"
#               />
#             ))
#           )}
#           {hiddenNodes.map(hidden =>
#             outputNodes.map(output => (
#               <line
#                 key={`${hidden.id}-${output.id}`}
#                 x1="400"
#                 y1={80 + hidden.id * 60}
#                 x2="740"
#                 y2={140 + output.id * 80}
#                 stroke="url(#gradient)"
#                 strokeWidth="1"
#               />
#             ))
#           )}
#         </svg>
#       </div>
#
#       <p className="mt-8 text-gray-600 dark:text-gray-300 text-center max-w-md">
#         Click on any input node (left) to see how information flows through the neural network!
#         Watch as the hidden layer processes the data and produces output signals.
#       </p>
#     </div>
#   );
# };
#
# export default NeuralNetworkVisualizer;
#
#   ⌛ Stage 2: Generating component implementation for Neural Network...
#   ✓ Saved: neural-network.tsx
#   ⏱️ Time taken: 1m 3s
#
# 📝 Processing file 9/10: tensor.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Tensor
#
#   ⌛ Stage 1: Generating conceptual understanding for Tensor...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Cube, Box, ArrowRight, ArrowDown, Maximize2 } from "lucide-react"
#
# interface TensorDemoProps {}
#
# type CellType = {
#   value: number
#   highlighted: boolean
# }
#
# const TensorDemo: React.FC<TensorDemoProps> = () => {
#   const [dimension, setDimension] = useState<1 | 2 | 3>(1)
#   const [cells, setCells] = useState<CellType[][][]>([])
#   const [isAnimating, setIsAnimating] = useState(false)
#
#   useEffect(() => {
#     const generate3DTensor = () => {
#       const newCells: CellType[][][] = Array(3)
#         .fill(null)
#         .map(() =>
#           Array(3)
#             .fill(null)
#             .map(() =>
#               Array(3)
#                 .fill(null)
#                 .map(() => ({
#                   value: Math.floor(Math.random() * 9) + 1,
#                   highlighted: false,
#                 }))
#             )
#         )
#       setCells(newCells)
#     }
#
#     generate3DTensor()
#
#     return () => {
#       setCells([])
#     }
#   }, [])
#
#   useEffect(() => {
#     if (isAnimating) {
#       const interval = setInterval(() => {
#         setCells(prev =>
#           prev.map(layer =>
#             layer.map(row =>
#               row.map(cell => ({
#                 ...cell,
#                 highlighted: Math.random() > 0.7,
#               }))
#             )
#           )
#         )
#       }, 800)
#
#       return () => clearInterval(interval)
#     }
#   }, [isAnimating])
#
#   const renderTensor = () => {
#     switch (dimension) {
#       case 1:
#         return (
#           <div className="flex items-center gap-2">
#             {cells[0]?.[0]?.map((cell, i) => (
#               <div
#                 key={i}
#                 className={`w-12 h-12 flex items-center justify-center rounded-lg transition-all duration-300 ${
#                   cell.highlighted
#                     ? "bg-blue-500 text-white transform scale-110"
#                     : "bg-gray-200 dark:bg-gray-700"
#                 }`}
#               >
#                 {cell.value}
#               </div>
#             ))}
#           </div>
#         )
#
#       case 2:
#         return (
#           <div className="grid gap-2">
#             {cells[0]?.map((row, i) => (
#               <div key={i} className="flex gap-2">
#                 {row.map((cell, j) => (
#                   <div
#                     key={`${i}-${j}`}
#                     className={`w-12 h-12 flex items-center justify-center rounded-lg transition-all duration-300 ${
#                       cell.highlighted
#                         ? "bg-blue-500 text-white transform scale-110"
#                         : "bg-gray-200 dark:bg-gray-700"
#                     }`}
#                   >
#                     {cell.value}
#                   </div>
#                 ))}
#               </div>
#             ))}
#           </div>
#         )
#
#       case 3:
#         return (
#           <div className="grid grid-cols-3 gap-8 perspective-1000">
#             {cells.map((layer, i) => (
#               <div
#                 key={i}
#                 className="grid gap-2 transform transition-transform duration-300 hover:scale-110"
#                 style={{
#                   transform: `translateZ(${i * 20}px)`,
#                 }}
#               >
#                 {layer.map((row, j) => (
#                   <div key={j} className="flex gap-2">
#                     {row.map((cell, k) => (
#                       <div
#                         key={`${i}-${j}-${k}`}
#                         className={`w-12 h-12 flex items-center justify-center rounded-lg transition-all duration-300 ${
#                           cell.highlighted
#                             ? "bg-blue-500 text-white transform scale-110"
#                             : "bg-gray-200 dark:bg-gray-700"
#                         }`}
#                       >
#                         {cell.value}
#                       </div>
#                     ))}
#                   </div>
#                 ))}
#               </div>
#             ))}
#           </div>
#         )
#     }
#   }
#
#   return (
#     <div className="flex flex-col items-center gap-8 p-8 min-h-screen bg-white dark:bg-gray-900 text-gray-900 dark:text-gray-100">
#       <h1 className="text-3xl font-bold">Understanding Tensors</h1>
#
#       <div className="flex gap-4 items-center">
#         <button
#           onClick={() => setDimension(1)}
#           className={`flex items-center gap-2 px-4 py-2 rounded-lg transition-colors duration-300 ${
#             dimension === 1
#               ? "bg-blue-500 text-white"
#               : "bg-gray-200 dark:bg-gray-700"
#           }`}
#         >
#           <ArrowRight size={20} />
#           1D (Vector)
#         </button>
#
#         <button
#           onClick={() => setDimension(2)}
#           className={`flex items-center gap-2 px-4 py-2 rounded-lg transition-colors duration-300 ${
#             dimension === 2
#               ? "bg-blue-500 text-white"
#               : "bg-gray-200 dark:bg-gray-700"
#           }`}
#         >
#           <Box size={20} />
#           2D (Matrix)
#         </button>
#
#         <button
#           onClick={() => setDimension(3)}
#           className={`flex items-center gap-2 px-4 py-2 rounded-lg transition-colors duration-300 ${
#             dimension === 3
#               ? "bg-blue-500 text-white"
#               : "bg-gray-200 dark:bg-gray-700"
#           }`}
#         >
#           <Cube size={20} />
#           3D (Tensor)
#         </button>
#       </div>
#
#       <div className="relative">
#         <button
#           onClick={() => setIsAnimating(!isAnimating)}
#           className="absolute -top-12 right-0 flex items-center gap-2 px-4 py-2 rounded-lg bg-green-500 text-white transition-colors duration-300 hover:bg-green-600"
#         >
#           <Maximize2 size={20} />
#           {isAnimating ? "Stop Animation" : "Animate Flow"}
#         </button>
#
#         <div className="p-8 rounded-xl bg-gray-100 dark:bg-gray-800 shadow-xl">
#           {renderTensor()}
#         </div>
#       </div>
#
#       <p className="max-w-md text-center text-gray-600 dark:text-gray-400">
#         Tensors are like magical data containers that can hold numbers in multiple dimensions.
#         They're the secret sauce that helps AI understand and process complex patterns!
#       </p>
#     </div>
#   )
# }
#
# export default TensorDemo
# ```
#
#   ⌛ Stage 2: Generating component implementation for Tensor...
#   ✓ Saved: tensor.tsx
#   ⏱️ Time taken: 1m 2s
#
# 📝 Processing file 10/10: dnn-deep-neural-networks.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: DNN (Deep Neural Networks)
#
#   ⌛ Stage 1: Generating conceptual understanding for DNN (Deep Neural Networks)...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Brain, Circle, ArrowRight, Zap } from "lucide-react"
#
# interface ComponentProps {}
#
# type NeuronType = {
#   id: number
#   active: boolean
#   x: number
#   y: number
# }
#
# const LAYERS = [4, 6, 6, 3]
# const ANIMATION_SPEED = 1500
#
# const DeepNeuralNetworkDemo = ({}: ComponentProps) => {
#   const [neurons, setNeurons] = useState<NeuronType[]>([])
#   const [activePathIndex, setActivePathIndex] = useState<number>(0)
#   const [isAnimating, setIsAnimating] = useState<boolean>(false)
#
#   useEffect(() => {
#     // Initialize neurons positions
#     let neuronsList: NeuronType[] = []
#     let id = 0
#
#     LAYERS.forEach((count, layerIndex) => {
#       const layerWidth = 800
#       const spacing = layerWidth / (count + 1)
#
#       for(let i = 0; i < count; i++) {
#         neuronsList.push({
#           id: id++,
#           active: false,
#           x: spacing * (i + 1),
#           y: 100 + (layerIndex * 120)
#         })
#       }
#     })
#
#     setNeurons(neuronsList)
#
#     return () => {
#       setNeurons([])
#       setIsAnimating(false)
#     }
#   }, [])
#
#   const animate = () => {
#     if(isAnimating) return
#     setIsAnimating(true)
#
#     const interval = setInterval(() => {
#       setActivePathIndex(prev => {
#         if(prev >= LAYERS[0] - 1) {
#           setIsAnimating(false)
#           clearInterval(interval)
#           return 0
#         }
#         return prev + 1
#       })
#     }, ANIMATION_SPEED)
#
#     return () => clearInterval(interval)
#   }
#
#   const getNeuronColor = (neuron: NeuronType) => {
#     if(!isAnimating) return "bg-gray-200 dark:bg-gray-700"
#     const layerIndex = Math.floor(neuron.y / 120) - 0.8
#     if(layerIndex === 0 && neuron.id % LAYERS[0] === activePathIndex) {
#       return "bg-blue-500"
#     }
#     if(layerIndex > 0 && Math.random() > 0.5) {
#       return "bg-green-400"
#     }
#     return "bg-gray-200 dark:bg-gray-700"
#   }
#
#   return (
#     <div className="w-full min-h-screen bg-white dark:bg-gray-900 p-8">
#       <div className="max-w-4xl mx-auto">
#         <div className="flex items-center gap-3 mb-8">
#           <Brain className="w-8 h-8 text-blue-500" />
#           <h1 className="text-2xl font-bold text-gray-800 dark:text-white">
#             Deep Neural Network Visualization
#           </h1>
#         </div>
#
#         <button
#           onClick={animate}
#           disabled={isAnimating}
#           className="mb-8 px-6 py-3 bg-blue-500 hover:bg-blue-600 text-white rounded-lg
#                    flex items-center gap-2 disabled:opacity-50 transition-all duration-300"
#         >
#           <Zap className="w-5 h-5" />
#           {isAnimating ? "Processing..." : "Process Input"}
#         </button>
#
#         <div className="relative w-full h-[600px] border-2 border-gray-200 dark:border-gray-700
#                       rounded-xl overflow-hidden bg-gray-50 dark:bg-gray-800">
#           {neurons.map((neuron) => (
#             <div
#               key={neuron.id}
#               className={`absolute w-8 h-8 -ml-4 -mt-4 rounded-full transition-all duration-500
#                          ${getNeuronColor(neuron)} shadow-lg transform hover:scale-110`}
#               style={{
#                 left: neuron.x,
#                 top: neuron.y
#               }}
#             />
#           ))}
#
#           <div className="absolute bottom-4 left-4 flex items-center gap-2 text-sm text-gray-600 dark:text-gray-300">
#             <Circle className="w-3 h-3 fill-gray-200 dark:fill-gray-700" /> Inactive Neuron
#             <Circle className="w-3 h-3 fill-blue-500 ml-4" /> Active Input
#             <Circle className="w-3 h-3 fill-green-400 ml-4" /> Activated Neuron
#           </div>
#         </div>
#       </div>
#     </div>
#   )
# }
#
# export default DeepNeuralNetworkDemo
# ```
#
#   ⌛ Stage 2: Generating component implementation for DNN (Deep Neural Networks)...
#   ✓ Saved: dnn-deep-neural-networks.tsx
#   ⏱️ Time taken: 0m 49s
#
# ====== Summary ======
# ✅ Successfully processed: 10
# ❌ Failed: 0
# ⏱️ Total time: 9m 7s
#
# ✨ Process completed!
