# %%
# Cell 1: Imports and Setup
# All necessary imports and API key setup
import os
import yaml
import anthropic
import time
import json
from datetime import datetime
from pathlib import Path
from typing import Dict, List, Tuple, Optional
from lucideIconList import icons
from config import ANTHROPIC_API_KEY

print(f"Anthropic version: {anthropic.__version__}")

# API Key Setup
os.environ['ANTHROPIC_API_KEY'] = ANTHROPIC_API_KEY

# Directory paths
INPUT_DIR = "/Users/kemi/Documents/GitHub/vocab/src/content/articles"
OUTPUT_DIR = "/Users/kemi/Documents/GitHub/vocab/src/components/articles/2-adjust"
CHECK0_DIR = "/Users/kemi/Documents/GitHub/vocab/src/components/articles/0"
CHECK1_DIR = "/Users/kemi/Documents/GitHub/vocab/src/components/articles/1-ok"

# Constants for Claude API
#MODEL_NAME = "claude-3-5-sonnet-20240620" 
MODEL_NAME = "claude-3-5-sonnet-20241022"
MAX_TOKENS1 = 2000
MAX_TOKENS2 = 6000
TEMPERATURE = 0.7

LUCIDEICONS = icons

# Print setup confirmation
print("🔧 Environment setup complete")
print(f"📁 Input directory: {INPUT_DIR}")
print(f"📁 Output directory: {OUTPUT_DIR}")
# Out:
# Anthropic version: 0.37.1
# 🔧 Environment setup complete
# 📁 Input directory: /Users/kemi/Documents/GitHub/vocab/src/content/articles
# 📁 Output directory: /Users/kemi/Documents/GitHub/vocab/src/components/articles/2-adjust

# %%
# Cell 2 - User Prompts

def create_concept_prompt(title: str, summary: str, content: str) -> str:
    """
    Creates the first-shot prompt focusing on conceptual understanding and metaphors.
    
    Args:
        title (str): The concept title
        summary (str): Brief summary of the concept
        content (str): Full content of the markdown file (after frontmatter)
        
    Returns:
        str: Formatted conceptual prompt
    """
    prompt = f'''
help me explain the following AI concept in a didactic react component which helps someone learn about it, either with interaction or animation. keep it simple. use lucide icons where possible. don't use shadcn only tailwind. make it intuitive. user shouldn't have to type anything. an animation can suffice if it's illustrative of the concept in the context of AI. The interactions might include, but not limited to, moving objects, selecting objects given a criteria, sliding objects, Scroll or Pinch-to-zoom, Swipe navigation, Drag and Drop Operations, Scroll-Based Interactions, Drawing, Music notes. Use humor and relatable situations when appropriate. aim for beautiful and artistic animations.

CONCEPT BREAKDOWN:
1. Name of the concept: {title}
2. Core Principle: {summary}
3. Detailed explanation: {content}
'''
    return prompt

def create_implementation_prompt(title: str, summary: str, content: str, concept_response: str) -> str:
    """
    Creates the second-shot prompt for component implementation.
    
    Args:
        title (str): The concept title
        summary (str): Brief summary of the concept
        concept_response (str): Claude's response from the first shot
        
    Returns:
        str: Formatted implementation prompt
    """
    prompt = f'''
The execution of the react component is underwhelming and confusing. 
I know you can do better. 
1. More beautiful and artistic. 
2. Add short helper texts to help convey the information better.
3. Implement font and element resizing from tailwind so the component is more legible in mobile devices with narrower or smaller screens.
4. Add system-based theme switching using the prefers-color-scheme media query and Tailwind's dark mode feature.
5. Remember: "Cube", "Robot", "Plant" and "PuzzlePiece" are not valid Lucide imports, you can use instead, only if necessary and relevant, "Box", "Bot", "Sprout" and "Puzzle" respectively. 
6. Don't use full viewport height (min-h-screen), adjust the component to only take the space it needs.

CONCEPT BREAKDOWN:
1. Name of the concept: {title}
2. Core Principle: {summary}
3. Detailed explanation: {content}
3. Claude 3.5 Sonnet's 1st try: 
{concept_response}

'''
    return prompt

# Print confirmation
print("✅ User Prompts loaded")
# Out:
# ✅ User Prompts loaded

# %%
# Cell 3 - Base Functions

def extract_frontmatter(content: str) -> Optional[Dict]:
    """
    Extract YAML frontmatter from markdown content.
    
    Args:
        content (str): Full markdown file content
        
    Returns:
        dict or None: Extracted frontmatter as dictionary, None if extraction fails
    """
    if content.startswith('---'):
        parts = content.split('---', 2)[1:]
        if len(parts) >= 1:
            try:
                return yaml.safe_load(parts[0])
            except yaml.YAMLError as e:
                print(f"  ⚠️ Error parsing YAML frontmatter: {str(e)}")
                return None
    return None

def format_time(seconds: float) -> str:
    """
    Format seconds into minutes and seconds.
    
    Args:
        seconds (float): Number of seconds
        
    Returns:
        str: Formatted string like "1m 30s"
    """
    return f"{int(seconds // 60)}m {int(seconds % 60)}s"

def get_existing_component_names_in_dir(directory: str) -> set:
    """
    Get names of existing components in a single directory.
    
    Args:
        directory (str): Path to components directory
        
    Returns:
        set: Set of component names (without .tsx extension)
    """
    existing_names = set()
    if os.path.exists(directory):
        for file in os.listdir(directory):
            if file.endswith('.tsx'):
                existing_names.add(file[:-4])
    return existing_names

def get_all_existing_component_names(directories: list[str]) -> set:
    """
    Get names of existing components across multiple directories.
    
    Args:
        directories (list[str]): List of directory paths to check
        
    Returns:
        set: Combined set of component names found in any directory
    """
    all_existing_names = set()
    
    for directory in directories:
        dir_components = get_existing_component_names_in_dir(directory)
        all_existing_names.update(dir_components)
    
    return all_existing_names

# Print confirmation
print("✅ Base functions loaded")
# Out:
# ✅ Base functions loaded

# %%
# Cell 4 - Component Generation Core

def generate_concept_understanding(client, title: str, prompt: str) -> str:
    """
    Generate conceptual understanding using Claude API (First shot).
    
    Args:
        client: Anthropic client instance
        title: The concept title
        prompt: Generated first-shot prompt
        
    Returns:
        str: concept explanation
    """
    print(f"\n  ⌛ Stage 1: Generating conceptual understanding for {title}...")
    
    system_prompt_concept = '''
    You are a creative artistic expert React developer and AI professor specializing in educational components for 15 to 18-year-old humans. 
Your components must strictly follow these technical requirements:

1. Architecture:
- "use client" directive at start (first line)
- import { useState, useEffect } from "react"; as the second line
- Only useState and useEffect hooks
- Only Lucide icons for visuals.
- Only Tailwind CSS for styling
- No external libraries/components
- File extension: .tsx

2. TypeScript Implementation:
interface ComponentProps {
    // Define if needed, empty interface required
}
// All state must use explicit types
const [state, setState] = useState<StateType>(initialValue);
// Event handlers must be typed
const handleEvent = (e: React.MouseEvent<HTMLButtonElement>) => {...};
// Constants outside component
const SCENARIOS: ScenarioType[] = [...];

3. Effects & Cleanup:
useEffect(() => {
    // Effect logic
    return () => {
    // Cleanup required
    };
}, [dependencies]);

4. Styling Standards:
- Only core Tailwind classes
- No arbitrary values (e.g., h-[500px])
- Transitions: duration-300 to duration-500
- Color scheme:
    • Blue (#3B82F6) - active/focus
    • Gray (#6B7280) - background
    • Green (#22C55E) - success
- Avoid minimalistic and underwhelming design. I know you can do better. Be more beautiful and artistic.
- Account for light and dark mode.

5. Code Organization:
- Max 200 lines per component
- Early returns with type guards
- JSDoc component documentation
- Proper hooks cleanup
- No inline styles
- No setTimeout/setInterval (use useEffect)
- Write the complete code, no comments or commented sections

Return only raw TSX code without explanations or markdown.
    '''
    
    try:
        response = client.messages.create(
            model=MODEL_NAME,
            max_tokens=MAX_TOKENS1,
            temperature=TEMPERATURE,
            system=system_prompt_concept,
            messages=[{"role": "user", "content": prompt}]
        )
        
        concept_response = response.content[0].text
        print(f"\n  💬 Stage 1 response: {concept_response}")
        
        return concept_response
        
    except Exception as e:
        print(f"  ❌ Error generating concept understanding: {str(e)}")
        return None

def generate_component_implementation(
    client,
    title: str,
    prompt: str,
    concept_response: str
) -> str:
    """
    Generate React component implementation using Claude API (Second shot).
    
    Args:
        client: Anthropic client instance
        title: The concept title
        prompt: Generated second-shot prompt
        concept_response: Response from first shot
        
    Returns:
        str: component_code
    """
    print(f"\n  ⌛ Stage 2: Generating component implementation for {title}...")
    
    system_prompt_implementation = '''
You are a creative artistic expert React developer and AI professor specializing in educational components for 15 to 18-year-old humans. 
Your components must strictly follow these technical requirements:

1. Architecture:
- "use client" directive at start (first line)
- import { useState, useEffect } from "react"; as the second line
- Only useState and useEffect hooks
- Only Lucide icons for visuals.
- Only Tailwind CSS for styling
- No external libraries/components
- File extension: .tsx

2. TypeScript Implementation:
interface ComponentProps {
    // Define if needed, empty interface required
}
// All state must use explicit types
const [state, setState] = useState<StateType>(initialValue);
// Event handlers must be typed
const handleEvent = (e: React.MouseEvent<HTMLButtonElement>) => {...};
// Constants outside component
const SCENARIOS: ScenarioType[] = [...];

3. Effects & Cleanup:
useEffect(() => {
    // Effect logic
    return () => {
    // Cleanup required
    };
}, [dependencies]);

4. Styling Standards:
- Only core Tailwind classes
- No arbitrary values (e.g., h-[500px])
- Transitions: duration-300 to duration-500
- Color scheme:
    • Blue (#3B82F6) - active/focus
    • Gray (#6B7280) - background
    • Green (#22C55E) - success
- Avoid minimalistic and underwhelming design. I know you can do better. Be more beautiful and artistic.

5. Code Organization:
- Max 200 lines per component
- Early returns with type guards
- JSDoc component documentation
- Proper hooks cleanup
- No inline styles
- No setTimeout/setInterval (use useEffect)
- Write the complete code, no comments or commented sections

Return only raw TSX code without explanations or markdown.
'''

# - Only Lucide icons for visuals. Limit yourself to these icons: ''' + str(LUCIDEICONS) + '''

    try:
        response = client.messages.create(
            model=MODEL_NAME,
            max_tokens=MAX_TOKENS2,
            temperature=TEMPERATURE,
            system=system_prompt_implementation,
            messages=[{
                "role": "user", 
                "content": f"{prompt}\n\nFirst-shot understanding:\n{concept_response}"
            }]
        )
        
        component_code = response.content[0].text
        
        # Clean up the code if it's wrapped in markdown
        if component_code.startswith('```'):
            first_newline = component_code.find('\n')
            if first_newline != -1:
                component_code = component_code[first_newline + 1:]
            if component_code.strip().endswith('```'):
                component_code = component_code.strip()[:-3]
        
        return component_code
        
    except Exception as e:
        print(f"  ❌ Error generating component implementation: {str(e)}")
        return None

def generate_component_with_refinement(
    client,
    title: str,
    summary: str
) -> str:
    """
    Two-stage component generation with conceptual understanding and implementation.
    
    Args:
        client: Anthropic client instance
        title: Component title for logging
        summary: Brief summary of the concept
    
    Returns:
        str: final_component_code
    """
    # Stage 1: Conceptual Understanding
    concept_prompt = create_concept_prompt(title, summary)
    concept_response = generate_concept_understanding(
        client,
        title,
        concept_prompt
    )
    
    if not concept_response:
        return None
    
    # Stage 2: Implementation
    implementation_prompt = create_implementation_prompt(
        title,
        summary,
        concept_response
    )
    
    component_code = generate_component_implementation(
        client,
        title,
        implementation_prompt,
        concept_response
    )
    
    return component_code

# Print confirmation
print("✅ Component generation functions loaded")
# Out:
# ✅ Component generation functions loaded

# %%
# Cell 5 - Component Validation and Fixes

def save_tsx_file(
    content: str,
    md_filename: str,
    output_dir: str
) -> None:
    """
    Save the API response as a .tsx file with minimal validation.
    
    Args:
        content (str): The component code to save
        md_filename (str): Original markdown filename with .md extension
        output_dir (str): Directory to save the TSX file
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # Convert .md to .tsx while preserving exact filename
    tsx_filename = md_filename.replace('.md', '.tsx')
    filepath = os.path.join(output_dir, tsx_filename)
    
    # Clean the content
    cleaned_content = content
    if content.startswith('```'):
        first_newline = content.find('\n')
        if first_newline != -1:
            cleaned_content = content[first_newline + 1:]
        if cleaned_content.strip().endswith('```'):
            cleaned_content = cleaned_content.strip()[:-3]
    
    # Check and ensure "use client" directive
    cleaned_content = cleaned_content.strip()
    if not cleaned_content.startswith('"use client"'):
        cleaned_content = '"use client"\n\n' + cleaned_content
        print("  🔧 Added missing 'use client' directive")
    
    # Save the file
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(cleaned_content)
    print(f"  ✓ Saved: {tsx_filename}")

# Print confirmation
print("✅ Component save function loaded")
# Out:
# ✅ Component save function loaded

# %%
# Cell 6 - Main Execution

def get_generality_score(md_file):
    """
    Get the generality score from the JSON data based on the markdown file's slug.
    
    Args:
        md_file (Path): Path object for the markdown file
        
    Returns:
        float: Generality score, or -1 if not found
    """
    try:
        # Get the slug from the markdown filename by removing .md extension
        slug = md_file.stem
        
        # Read and parse the JSON file
        json_path = "/Users/kemi/Documents/GitHub/vocab/src/data/polyhierarchy.json"
        with open(json_path, 'r', encoding='utf-8') as f:
            concepts_data = json.load(f)
        
        # Find the concept with matching slug
        for concept in concepts_data:
            if concept.get('slug') == slug:
                return float(concept.get('generality', -1))
                
        return -1  # Return -1 if slug not found in JSON
        
    except Exception as e:
        print(f"  ⚠️ Error reading generality from {md_file.name}: {str(e)}")
        return -1

def process_file(client, md_file, metadata):
    try:
        print(f"  ⌛ Creating prompts for: {metadata['title']}")
        
        # Read the file content
        with open(md_file, 'r', encoding='utf-8') as f:
            full_content = f.read()
        
        # Split content by frontmatter markers
        content_parts = full_content.split('---')
        if len(content_parts) >= 3:
            # The actual content is after the second '---'
            main_content = content_parts[2].strip()
        else:
            main_content = ""
            print(f"  ⚠️ Warning: Could not extract main content from {md_file.name}")
        
        # First shot - Conceptual Understanding
        concept_prompt = create_concept_prompt(
            metadata['title'], 
            metadata['summary'],
            main_content
        )
        
        concept_response = generate_concept_understanding(
            client,
            metadata['title'],
            concept_prompt
        )
        
        # Rest of your processing code...
        
        if not concept_response:
            print(f"  ❌ Failed to generate concept understanding for: {md_file.name}")
            return False
            
        # Second shot - Implementation
        implementation_prompt = create_implementation_prompt(
            metadata['title'],
            metadata['summary'],
            concept_response
        )
        
        component_code = generate_component_implementation(
            client,
            metadata['title'],
            implementation_prompt,
            concept_response
        )
        
        if component_code:
            save_tsx_file(
                component_code,
                md_file.name,
                OUTPUT_DIR
            )
            return True
        else:
            print(f"  ❌ Failed to generate component for: {md_file.name}")
            return False
            
    except Exception as e:
        print(f"  ❌ Error processing file: {str(e)}")
        return False

def main():
    """Main execution function for the component generator."""
    print("\n🚀 Starting AI Component Generator...\n")
    start_time_total = time.time()
    
    try:
        # Initialize Anthropic client
        client = anthropic.Client(api_key=os.getenv('ANTHROPIC_API_KEY'))
        
        # Check directories
        print("📂 Checking directories...")
        if not os.path.exists(INPUT_DIR):
            raise Exception(f"Input directory not found: {INPUT_DIR}")
        if not os.path.exists(OUTPUT_DIR):
            os.makedirs(OUTPUT_DIR)
            print(f"  ✓ Created output directory: {OUTPUT_DIR}")
        
        # Get existing component names from all directories
        print("\n📂 Checking existing components...")
        dirs_to_check = [OUTPUT_DIR, CHECK0_DIR, CHECK1_DIR]
        existing_components = get_all_existing_component_names(dirs_to_check)
        
        if existing_components:
            print(f"  ✓ Found {len(existing_components)} existing components across all directories")
            
        # Get list of all .md files that don't have corresponding .tsx files
        all_md_files = []
        for md_file in Path(INPUT_DIR).glob('*.md'):
            if md_file.stem not in existing_components:
                all_md_files.append(md_file)
        
        total_available = len(all_md_files)
        print(f"\n📁 Found {total_available} unprocessed files")
        
        if total_available == 0:
            print("❌ No new files to process")
            return
        
        # Sort files by generality score (highest first)
        print("\n📊 Sorting files by generality score...")
        md_files_with_scores = [(f, get_generality_score(f)) for f in all_md_files]
        sorted_md_files = [f for f, score in sorted(md_files_with_scores, key=lambda x: x[1], reverse=True)]
        
        # Select top 50 files (or all if less than 50 available) ⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️
        num_files = min(10, total_available)
        md_files = sorted_md_files[:num_files]
        
        print(f"\n📈 Selected top {num_files} files by generality score")
        
        # Track statistics
        successful = 0
        failed = 0
        
        # Process each file
        for index, md_file in enumerate(md_files, 1):
            print(f"\n📝 Processing file {index}/{num_files}: {md_file.name}")
            start_time_file = time.time()
            
            try:
                print("  ⌛ Reading file...")
                with open(md_file, 'r', encoding='utf-8') as f:
                    content = f.read()
                
                print("  ⌛ Extracting metadata...")
                metadata = extract_frontmatter(content)
                if not metadata:
                    print("  ❌ Could not extract metadata")
                    failed += 1
                    continue
                
                # Process the file
                success = process_file(client, md_file, metadata)
                if success:
                    successful += 1
                else:
                    failed += 1
                
                elapsed_time = time.time() - start_time_file
                print(f"  ⏱️ Time taken: {format_time(elapsed_time)}")
                
            except Exception as e:
                print(f"  ❌ Error: {str(e)}")
                failed += 1
        
        # Print summary
        total_time = time.time() - start_time_total
        print("\n====== Summary ======")
        print(f"✅ Successfully processed: {successful}")
        print(f"❌ Failed: {failed}")
        print(f"⏱️ Total time: {format_time(total_time)}")
        
    except Exception as e:
        print(f"\n❌ Fatal error: {str(e)}")
        raise
    
    print("\n✨ Process completed!")

# %%
# Cell 7 - Run Main
if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting AI Component Generator...
#
# 📂 Checking directories...
#
# 📂 Checking existing components...
#   ✓ Found 89 existing components across all directories
#
# 📁 Found 835 unprocessed files
#
# 📊 Sorting files by generality score...
#
# 📈 Selected top 10 files by generality score
#
# 📝 Processing file 1/10: functional-agi.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Functional AGI
#
#   ⌛ Stage 1: Generating conceptual understanding for Functional AGI...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react"
# import { Brain, Zap, Code, Cpu, Robot, Sparkles, BookOpen, Target, Workflow } from "lucide-react"
#
# interface AGITask {
#   id: number
#   name: string
#   icon: JSX.Element
#   completed: boolean
# }
#
# export default function FunctionalAGI() {
#   const [tasks, setTasks] = useState<AGITask[]>([
#     { id: 1, name: "Learn Mathematics", icon: <Target className="w-6 h-6" />, completed: false },
#     { id: 2, name: "Write Poetry", icon: <BookOpen className="w-6 h-6" />, completed: false },
#     { id: 3, name: "Solve Physics", icon: <Zap className="w-6 h-6" />, completed: false },
#     { id: 4, name: "Program Software", icon: <Code className="w-6 h-6" />, completed: false },
#   ])
#
#   const [isProcessing, setIsProcessing] = useState(false)
#   const [currentTaskIndex, setCurrentTaskIndex] = useState(0)
#
#   useEffect(() => {
#     if (isProcessing && currentTaskIndex < tasks.length) {
#       const timer = setTimeout(() => {
#         setTasks(prev => prev.map((task, idx) =>
#           idx === currentTaskIndex ? { ...task, completed: true } : task
#         ))
#         setCurrentTaskIndex(prev => prev + 1)
#
#         if (currentTaskIndex === tasks.length - 1) {
#           setIsProcessing(false)
#         }
#       }, 1500)
#
#       return () => clearTimeout(timer)
#     }
#   }, [isProcessing, currentTaskIndex, tasks.length])
#
#   return (
#     <div className="min-h-screen bg-gradient-to-br from-gray-900 to-gray-800 text-white p-8 flex flex-col items-center">
#       <h1 className="text-4xl font-bold mb-8 flex items-center gap-3">
#         <Brain className="w-8 h-8 text-blue-400" />
#         Functional AGI Simulator
#       </h1>
#
#       <div className="relative w-full max-w-2xl bg-gray-800 rounded-xl p-8 shadow-xl">
#         <div className="absolute -top-6 left-1/2 transform -translate-x-1/2">
#           <Robot className={`w-12 h-12 ${isProcessing ? 'text-green-400 animate-pulse' : 'text-gray-400'}`} />
#         </div>
#
#         <div className="grid grid-cols-2 gap-6 mt-8">
#           {tasks.map((task, index) => (
#             <div
#               key={task.id}
#               className={`p-4 rounded-lg border-2 transition-all duration-500 transform
#                 ${task.completed
#                   ? 'border-green-400 bg-green-400/10'
#                   : 'border-gray-600 bg-gray-700/50'}
#                 ${isProcessing && index === currentTaskIndex ? 'scale-105' : 'scale-100'}
#               `}
#             >
#               <div className="flex items-center gap-3">
#                 {task.icon}
#                 <span>{task.name}</span>
#                 {task.completed && <Sparkles className="w-4 h-4 text-green-400 animate-pulse" />}
#               </div>
#             </div>
#           ))}
#         </div>
#
#         <div className="flex flex-col items-center mt-8">
#           <button
#             onClick={() => {
#               setIsProcessing(true)
#               setTasks(prev => prev.map(task => ({ ...task, completed: false })))
#               setCurrentTaskIndex(0)
#             }}
#             disabled={isProcessing}
#             className={`
#               px-6 py-3 rounded-lg font-semibold
#               transition-all duration-300
#               flex items-center gap-2
#               ${isProcessing
#                 ? 'bg-gray-600 cursor-not-allowed'
#                 : 'bg-blue-500 hover:bg-blue-600 active:scale-95'}
#             `}
#           >
#             <Cpu className="w-5 h-5" />
#             {isProcessing ? 'Processing...' : 'Start AGI Simulation'}
#           </button>
#         </div>
#
#         <div className="mt-6 text-center text-gray-400">
#           <p className="flex items-center justify-center gap-2">
#             <Workflow className="w-4 h-4" />
#             Watch as AGI adapts and learns across different domains
#           </p>
#         </div>
#       </div>
#     </div>
#   )
# }
#   ❌ Error processing file: create_implementation_prompt() missing 1 required positional argument: 'concept_response'
#   ⏱️ Time taken: 0m 19s
#
# 📝 Processing file 2/10: dl-deep-learning.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: DL (Deep Learning)
#
#   ⌛ Stage 1: Generating conceptual understanding for DL (Deep Learning)...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Brain, Image, MessageSquare, Music, Circle, ArrowRight } from "lucide-react"
#
# interface NetworkLayer {
#   nodes: number[]
#   connections: {from: number, to: number}[]
# }
#
# const DeepLearningVisualizer = () => {
#   const [activeLayer, setActiveLayer] = useState<number>(0)
#   const [dataPoint, setDataPoint] = useState<{x: number, y: number}>({x: 0, y: 0})
#   const [isProcessing, setIsProcessing] = useState<boolean>(false)
#
#   const networkLayers: NetworkLayer[] = [
#     {
#       nodes: [0, 1, 2],
#       connections: [{from: 0, to: 0}, {from: 1, to: 1}, {from: 2, to: 0}]
#     },
#     {
#       nodes: [0, 1],
#       connections: [{from: 0, to: 0}, {from: 1, to: 1}]
#     },
#     {
#       nodes: [0, 1, 2, 3],
#       connections: [{from: 0, to: 0}, {from: 1, to: 1}, {from: 2, to: 2}]
#     }
#   ]
#
#   const tasks = [
#     {icon: <Image className="w-6 h-6"/>, label: "Image Recognition"},
#     {icon: <MessageSquare className="w-6 h-6"/>, label: "Language Processing"},
#     {icon: <Music className="w-6 h-6"/>, label: "Audio Analysis"}
#   ]
#
#   useEffect(() => {
#     const interval = setInterval(() => {
#       setActiveLayer(prev => (prev + 1) % networkLayers.length)
#       setDataPoint({
#         x: Math.random() * 400,
#         y: Math.random() * 200
#       })
#     }, 2000)
#
#     return () => clearInterval(interval)
#   }, [])
#
#   const handleTaskClick = (index: number) => {
#     setIsProcessing(true)
#     setTimeout(() => setIsProcessing(false), 1500)
#   }
#
#   return (
#     <div className="min-h-screen bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-900 dark:to-gray-800 p-8 flex flex-col items-center justify-center">
#       <div className="max-w-4xl w-full space-y-8">
#         <div className="text-center space-y-4">
#           <h1 className="text-4xl font-bold text-gray-800 dark:text-gray-100">
#             Deep Learning Explorer
#           </h1>
#           <p className="text-gray-600 dark:text-gray-300">
#             Watch how neural networks process information through multiple layers
#           </p>
#         </div>
#
#         <div className="relative h-80 bg-white dark:bg-gray-800 rounded-xl shadow-lg p-6 overflow-hidden">
#           {networkLayers.map((layer, i) => (
#             <div
#               key={i}
#               className={`absolute transition-all duration-500 flex items-center justify-around h-full
#                 ${i === activeLayer ? 'opacity-100' : 'opacity-0'}`}
#               style={{
#                 left: `${(i * 33) + 16}%`,
#                 width: '30%'
#               }}
#             >
#               {layer.nodes.map((_, nodeIndex) => (
#                 <div
#                   key={nodeIndex}
#                   className={`w-8 h-8 rounded-full transition-all duration-300
#                     ${isProcessing ? 'bg-blue-500' : 'bg-gray-300 dark:bg-gray-600'}
#                     ${nodeIndex === Math.floor(layer.nodes.length/2) ? 'scale-125' : 'scale-100'}
#                   `}
#                 />
#               ))}
#             </div>
#           ))}
#
#           <div
#             className="absolute w-4 h-4 bg-blue-500 rounded-full transition-all duration-500"
#             style={{
#               left: dataPoint.x,
#               top: dataPoint.y,
#               transform: 'translate(-50%, -50%)'
#             }}
#           />
#         </div>
#
#         <div className="grid grid-cols-3 gap-4">
#           {tasks.map((task, i) => (
#             <button
#               key={i}
#               onClick={() => handleTaskClick(i)}
#               className="flex items-center justify-center space-x-2 p-4 bg-white dark:bg-gray-800
#                 rounded-lg shadow-md hover:shadow-lg transition-all duration-300
#                 hover:scale-105 focus:outline-none focus:ring-2 focus:ring-blue-500"
#             >
#               {task.icon}
#               <span className="text-gray-700 dark:text-gray-200">{task.label}</span>
#             </button>
#           ))}
#         </div>
#
#         <div className="flex items-center justify-center space-x-2 text-gray-600 dark:text-gray-300">
#           <Brain className="w-5 h-5"/>
#           <span>Each layer learns increasingly complex features</span>
#         </div>
#       </div>
#     </div>
#   )
# }
#
# export default DeepLearningVisualizer
# ```
#   ❌ Error processing file: create_implementation_prompt() missing 1 required positional argument: 'concept_response'
#   ⏱️ Time taken: 0m 22s
#
# 📝 Processing file 3/10: unsupervised-learning.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Unsupervised Learning
#
#   ⌛ Stage 1: Generating conceptual understanding for Unsupervised Learning...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react"
# import { CircleDot, Circle, MoveHorizontal, Sparkles } from "lucide-react"
#
# interface ComponentProps {}
#
# type DataPoint = {
#   id: number
#   x: number
#   y: number
#   cluster: number | null
# }
#
# const INITIAL_DATA: DataPoint[] = Array.from({ length: 20 }, (_, i) => ({
#   id: i,
#   x: Math.random() * 80 + 10,
#   y: Math.random() * 80 + 10,
#   cluster: null
# }))
#
# const UnsupervisedLearningDemo: React.FC<ComponentProps> = () => {
#   const [dataPoints, setDataPoints] = useState<DataPoint[]>(INITIAL_DATA)
#   const [isLearning, setIsLearning] = useState(false)
#   const [step, setStep] = useState(0)
#
#   useEffect(() => {
#     if (!isLearning) return
#
#     const timer = setInterval(() => {
#       setDataPoints(prev => {
#         return prev.map(point => {
#           if (point.x < 40 && point.y < 40) {
#             return { ...point, cluster: 0 }
#           } else if (point.x > 60 && point.y > 60) {
#             return { ...point, cluster: 1 }
#           } else {
#             return { ...point, cluster: 2 }
#           }
#         })
#       })
#       setStep(prev => prev + 1)
#       if (step > 5) {
#         setIsLearning(false)
#         clearInterval(timer)
#       }
#     }, 1000)
#
#     return () => clearInterval(timer)
#   }, [isLearning, step])
#
#   const handleStart = () => {
#     setIsLearning(true)
#     setStep(0)
#   }
#
#   const handleReset = () => {
#     setDataPoints(INITIAL_DATA)
#     setIsLearning(false)
#     setStep(0)
#   }
#
#   return (
#     <div className="flex flex-col items-center p-8 min-h-screen bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-900 dark:to-gray-800">
#       <h1 className="text-4xl font-bold mb-8 text-gray-800 dark:text-white">
#         Unsupervised Learning
#         <Sparkles className="inline-block ml-2 text-blue-500" />
#       </h1>
#
#       <div className="relative w-[400px] h-[400px] bg-white dark:bg-gray-700 rounded-lg shadow-xl mb-8">
#         <div className="absolute inset-0 p-4">
#           {dataPoints.map(point => (
#             <div
#               key={point.id}
#               className={`absolute transform -translate-x-1/2 -translate-y-1/2 transition-all duration-500 ${
#                 isLearning ? "animate-pulse" : ""
#               }`}
#               style={{
#                 left: `${point.x}%`,
#                 top: `${point.y}%`
#               }}
#             >
#               {point.cluster === null ? (
#                 <Circle className="w-6 h-6 text-gray-400" />
#               ) : (
#                 <CircleDot
#                   className={`w-6 h-6 ${
#                     point.cluster === 0
#                       ? "text-blue-500"
#                       : point.cluster === 1
#                       ? "text-green-500"
#                       : "text-purple-500"
#                   }`}
#                 />
#               )}
#             </div>
#           ))}
#         </div>
#       </div>
#
#       <div className="flex gap-4">
#         <button
#           onClick={handleStart}
#           disabled={isLearning}
#           className="px-6 py-3 bg-blue-500 text-white rounded-lg shadow-lg hover:bg-blue-600 disabled:opacity-50 transition-colors duration-300 flex items-center gap-2"
#         >
#           <MoveHorizontal className="w-5 h-5" />
#           Start Clustering
#         </button>
#         <button
#           onClick={handleReset}
#           className="px-6 py-3 bg-gray-500 text-white rounded-lg shadow-lg hover:bg-gray-600 transition-colors duration-300"
#         >
#           Reset
#         </button>
#       </div>
#
#       <p className="mt-8 text-center text-gray-600 dark:text-gray-300 max-w-md">
#         Watch as the algorithm discovers patterns and groups similar data points
#         together, all without any prior knowledge of the categories!
#       </p>
#     </div>
#   )
# }
#
# export default UnsupervisedLearningDemo
#   ❌ Error processing file: create_implementation_prompt() missing 1 required positional argument: 'concept_response'
#   ⏱️ Time taken: 0m 19s
#
# 📝 Processing file 4/10: cognitive-computing.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Cognitive Computing
#
#   ⌛ Stage 1: Generating conceptual understanding for Cognitive Computing...
#
#   💬 Stage 1 response: ```tsx
# "use client"
# import { useState, useEffect } from "react"
# import { Brain, Database, Search, Zap, MessageCircle, Activity, Heart, Calculator } from "lucide-react"
#
# interface CognitiveNode {
#   id: number
#   icon: JSX.Element
#   label: string
#   x: number
#   y: number
# }
#
# /**
#  * Interactive visualization of cognitive computing concepts
#  * Shows how computer systems simulate human thought processes
#  */
# export default function CognitiveComputing() {
#   const [nodes, setNodes] = useState<CognitiveNode[]>([
#     {id: 1, icon: <Brain className="w-12 h-12"/>, label: "Reasoning", x: 50, y: 50},
#     {id: 2, icon: <Database className="w-12 h-12"/>, label: "Learning", x: 200, y: 50},
#     {id: 3, icon: <Search className="w-12 h-12"/>, label: "Pattern Recognition", x: 350, y: 50},
#     {id: 4, icon: <Zap className="w-12 h-12"/>, label: "Processing", x: 50, y: 200},
#     {id: 5, icon: <MessageCircle className="w-12 h-12"/>, label: "Language", x: 200, y: 200},
#     {id: 6, icon: <Activity className="w-12 h-12"/>, label: "Analysis", x: 350, y: 200}
#   ])
#
#   const [activeNode, setActiveNode] = useState<number | null>(null)
#   const [pulsePosition, setPulsePosition] = useState<{x: number, y: number}>({x: 0, y: 0})
#   const [isProcessing, setIsProcessing] = useState<boolean>(false)
#
#   useEffect(() => {
#     const interval = setInterval(() => {
#       const randomNode = Math.floor(Math.random() * nodes.length)
#       setActiveNode(randomNode)
#       setPulsePosition({
#         x: nodes[randomNode].x,
#         y: nodes[randomNode].y
#       })
#       setIsProcessing(true)
#
#       setTimeout(() => setIsProcessing(false), 1000)
#     }, 2000)
#
#     return () => clearInterval(interval)
#   }, [nodes])
#
#   return (
#     <div className="relative w-full h-[600px] bg-gradient-to-br from-gray-100 to-gray-200 dark:from-gray-800 dark:to-gray-900 rounded-xl p-8 overflow-hidden">
#       <div className="absolute top-4 left-4 flex items-center gap-2">
#         <Heart className="w-6 h-6 text-blue-500 animate-pulse" />
#         <h2 className="text-xl font-bold text-gray-800 dark:text-gray-100">
#           Cognitive Computing Simulation
#         </h2>
#       </div>
#
#       <div className="mt-12">
#         {nodes.map((node) => (
#           <div
#             key={node.id}
#             className={`absolute transition-all duration-500 transform
#               ${activeNode === node.id ? 'scale-125' : 'scale-100'}
#               ${isProcessing && activeNode === node.id ? 'text-blue-500' : 'text-gray-600 dark:text-gray-300'}`}
#             style={{
#               left: `${node.x}px`,
#               top: `${node.y}px`
#             }}
#           >
#             <div className="flex flex-col items-center gap-2">
#               {node.icon}
#               <span className="text-sm font-medium">{node.label}</span>
#             </div>
#           </div>
#         ))}
#
#         {isProcessing && (
#           <div
#             className="absolute w-8 h-8 bg-blue-500/20 rounded-full animate-ping"
#             style={{
#               left: `${pulsePosition.x + 24}px`,
#               top: `${pulsePosition.y + 24}px`
#             }}
#           />
#         )}
#
#         <svg className="absolute top-0 left-0 w-full h-full pointer-events-none">
#           {nodes.map((node, i) =>
#             nodes.slice(i + 1).map((target, j) => (
#               <line
#                 key={`${i}-${j}`}
#                 x1={node.x + 24}
#                 y1={node.y + 24}
#                 x2={target.x + 24}
#                 y2={target.y + 24}
#                 className={`stroke-gray-300 dark:stroke-gray-600 ${
#                   activeNode === node.id || activeNode === target.id
#                     ? 'stroke-2 opacity-100'
#                     : 'stroke-1 opacity-30'
#                 }`}
#               />
#             ))
#           )}
#         </svg>
#
#         <div className="absolute bottom-4 left-4 right-4 bg-white/90 dark:bg-gray-800/90 p-4 rounded-lg shadow-lg">
#           <div className="flex items-center gap-2">
#             <Calculator className="w-5 h-5 text-blue-500" />
#             <p className="text-sm text-gray-600 dark:text-gray-300">
#               Watch as the system simulates human-like cognitive processes, connecting different aspects of intelligence
#             </p>
#           </div>
#         </div>
#       </div>
#     </div>
#   )
# }
# ```
#   ❌ Error processing file: create_implementation_prompt() missing 1 required positional argument: 'concept_response'
#   ⏱️ Time taken: 0m 21s
#
# 📝 Processing file 5/10: cybernetics.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Cybernetics
#
#   ⌛ Stage 1: Generating conceptual understanding for Cybernetics...
#
#   💬 Stage 1 response: ```tsx
# "use client"
# import { useState, useEffect } from "react";
# import { Brain, Robot, Zap, ArrowBigRight, Repeat, RefreshCw } from "lucide-react";
#
# interface CyberneticsProps {}
#
# type FeedbackLoop = {
#   id: number;
#   input: string;
#   process: string;
#   output: string;
#   feedback: string;
# }
#
# const FEEDBACK_LOOPS: FeedbackLoop[] = [
#   {
#     id: 1,
#     input: "Temperature sensor reads 25°C",
#     process: "Thermostat compares with target (20°C)",
#     output: "AC turns on to cool room",
#     feedback: "New temperature reading"
#   },
#   {
#     id: 2,
#     input: "Camera detects obstacle",
#     process: "Robot calculates distance",
#     output: "Changes direction to avoid collision",
#     feedback: "New position data"
#   },
#   {
#     id: 3,
#     input: "Blood sugar level rises",
#     process: "Pancreas detects change",
#     output: "Releases insulin",
#     feedback: "Decreased blood sugar"
#   }
# ];
#
# /**
#  * Interactive component demonstrating cybernetics principles through animated feedback loops
#  */
# const Cybernetics: React.FC<CyberneticsProps> = () => {
#   const [activeLoop, setActiveLoop] = useState<number>(0);
#   const [isAnimating, setIsAnimating] = useState<boolean>(false);
#   const [rotation, setRotation] = useState<number>(0);
#
#   useEffect(() => {
#     const rotationInterval = setInterval(() => {
#       setRotation(prev => (prev + 1) % 360);
#     }, 50);
#
#     return () => clearInterval(rotationInterval);
#   }, []);
#
#   useEffect(() => {
#     if (isAnimating) {
#       const timeout = setTimeout(() => {
#         setActiveLoop((prev) => (prev + 1) % FEEDBACK_LOOPS.length);
#         setIsAnimating(false);
#       }, 2000);
#       return () => clearTimeout(timeout);
#     }
#   }, [isAnimating]);
#
#   const handleNextLoop = () => {
#     setIsAnimating(true);
#   };
#
#   return (
#     <div className="min-h-screen bg-gradient-to-br from-gray-50 to-gray-200 dark:from-gray-800 dark:to-gray-900 p-8 flex flex-col items-center justify-center">
#       <h1 className="text-4xl font-bold mb-8 text-gray-800 dark:text-gray-100 flex items-center gap-3">
#         <Brain className="w-10 h-10" />
#         Cybernetics Explorer
#         <Robot className="w-10 h-10" />
#       </h1>
#
#       <div className="relative w-96 h-96 bg-white dark:bg-gray-800 rounded-full shadow-xl flex items-center justify-center">
#         <div
#           className="absolute w-full h-full"
#           style={{ transform: `rotate(${rotation}deg)` }}
#         >
#           <div className="absolute top-0 left-1/2 -translate-x-1/2 w-2 h-2 bg-blue-500 rounded-full" />
#         </div>
#
#         <div className="relative w-80 h-80 rounded-full border-4 border-gray-300 dark:border-gray-600">
#           <div className={`absolute w-full h-full transition-opacity duration-500 ${isAnimating ? 'opacity-100' : 'opacity-0'}`}>
#             <RefreshCw className="absolute top-1/2 left-1/2 -translate-x-1/2 -translate-y-1/2 w-16 h-16 text-blue-500 animate-spin" />
#           </div>
#
#           <div className="absolute top-0 left-1/2 -translate-x-1/2 -mt-8">
#             <div className="text-center text-sm font-medium text-gray-700 dark:text-gray-300">
#               Input
#             </div>
#           </div>
#
#           <div className="absolute bottom-0 left-1/2 -translate-x-1/2 -mb-8">
#             <div className="text-center text-sm font-medium text-gray-700 dark:text-gray-300">
#               Feedback
#             </div>
#           </div>
#
#           <div className="absolute left-0 top-1/2 -translate-y-1/2 -ml-24">
#             <div className="text-center text-sm font-medium text-gray-700 dark:text-gray-300">
#               Process
#             </div>
#           </div>
#
#           <div className="absolute right-0 top-1/2 -translate-y-1/2 -mr-24">
#             <div className="text-center text-sm font-medium text-gray-700 dark:text-gray-300">
#               Output
#             </div>
#           </div>
#         </div>
#       </div>
#
#       <div className="mt-8 w-96 bg-white dark:bg-gray-800 rounded-xl p-6 shadow-lg">
#         <div className="space-y-2">
#           <p className="text-sm text-gray-600 dark:text-gray-400">{FEEDBACK_LOOPS[activeLoop].input}</p>
#           <ArrowBigRight className="w-5 h-5 text-blue-500 ml-2" />
#           <p className="text-sm text-gray-600 dark:text-gray-400">{FEEDBACK_LOOPS[activeLoop].process}</p>
#           <ArrowBigRight className="w-5 h-5 text-blue-500 ml-2" />
#           <p className="text-sm text-gray-600 dark:text-gray-400">{FEEDBACK_LOOPS[activeLoop].output}</p>
#           <Repeat className="w-5 h-5 text-blue-500 ml-2" />
#           <p className="text-sm text-gray-600 dark:text-gray-400">{FEEDBACK_LOOPS[activeLoop].feedback}</p>
#         </div>
#
#         <button
#           onClick={handleNextLoop}
#           disabled={isAnimating}
#           className="mt-4 w-full py-2 px-4 bg-blue-500 hover:bg-blue-600 disabled:bg-gray-400 text-white rounded-lg transition-colors duration-300 flex items-center justify-center gap-2"
#         >
#           <Zap className="w-5 h-5" />
#           Next Example
#         </button>
#       </div>
#     </div>
#   );
# };
#
# export default Cybernetics;
# ```
#   ❌ Error processing file: create_implementation_prompt() missing 1 required positional argument: 'concept_response'
#   ⏱️ Time taken: 0m 26s
#
# 📝 Processing file 6/10: subsymbolic-ai.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Subsymbolic AI
#
#   ⌛ Stage 1: Generating conceptual understanding for Subsymbolic AI...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react"
# import { Brain, Network, Cpu, CircuitBoard, ArrowRight, ChevronRight } from "lucide-react"
#
# interface NeuronPosition {
#   x: number
#   y: number
#   value: number
# }
#
# interface SubsymbolicAIProps {}
#
# const SubsymbolicAI = ({}: SubsymbolicAIProps) => {
#   const [neurons, setNeurons] = useState<NeuronPosition[]>([])
#   const [activeConnections, setActiveConnections] = useState<number>(0)
#   const [isProcessing, setIsProcessing] = useState<boolean>(false)
#   const [step, setStep] = useState<number>(0)
#
#   useEffect(() => {
#     const initialNeurons: NeuronPosition[] = Array.from({ length: 12 }, (_, i) => ({
#       x: Math.cos((i * 2 * Math.PI) / 12) * 120 + 200,
#       y: Math.sin((i * 2 * Math.PI) / 12) * 120 + 200,
#       value: Math.random()
#     }))
#     setNeurons(initialNeurons)
#
#     return () => {
#       setNeurons([])
#       setActiveConnections(0)
#     }
#   }, [])
#
#   useEffect(() => {
#     if (isProcessing) {
#       const interval = setInterval(() => {
#         setNeurons(prev =>
#           prev.map(n => ({
#             ...n,
#             value: Math.random()
#           }))
#         )
#         setActiveConnections(prev => (prev + 1) % 20)
#       }, 500)
#
#       return () => clearInterval(interval)
#     }
#   }, [isProcessing])
#
#   const handleNextStep = () => {
#     setStep(prev => (prev + 1) % 4)
#     setIsProcessing(true)
#   }
#
#   return (
#     <div className="min-h-screen bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-900 dark:to-gray-800 p-8">
#       <div className="max-w-4xl mx-auto">
#         <div className="flex items-center gap-4 mb-8">
#           <Brain className="w-10 h-10 text-blue-500" />
#           <h1 className="text-3xl font-bold text-gray-800 dark:text-white">
#             Subsymbolic AI Visualization
#           </h1>
#         </div>
#
#         <div className="bg-white dark:bg-gray-800 rounded-2xl shadow-xl p-6 mb-8">
#           <div className="relative h-[400px] w-full">
#             <svg className="w-full h-full">
#               {neurons.map((n1, i) =>
#                 neurons.map((n2, j) => (
#                   <line
#                     key={`${i}-${j}`}
#                     x1={n1.x}
#                     y1={n1.y}
#                     x2={n2.x}
#                     y2={n2.y}
#                     stroke={`rgba(59, 130, 246, ${
#                       (i + j) % 5 === activeConnections ? 0.8 : 0.1
#                     })`}
#                     strokeWidth="1"
#                   />
#                 ))
#               )}
#               {neurons.map((neuron, i) => (
#                 <circle
#                   key={i}
#                   cx={neuron.x}
#                   cy={neuron.y}
#                   r={12}
#                   fill={`rgba(59, 130, 246, ${neuron.value})`}
#                   className="transition-all duration-500"
#                 />
#               ))}
#             </svg>
#           </div>
#         </div>
#
#         <div className="grid grid-cols-1 md:grid-cols-2 gap-6">
#           <div className="bg-white dark:bg-gray-800 rounded-xl p-6 shadow-lg">
#             <div className="flex items-center gap-3 mb-4">
#               <Network className="w-6 h-6 text-blue-500" />
#               <h3 className="text-xl font-semibold text-gray-800 dark:text-white">
#                 Neural Processing
#               </h3>
#             </div>
#             <p className="text-gray-600 dark:text-gray-300">
#               Watch as information flows through interconnected neurons, demonstrating how
#               subsymbolic AI processes data without explicit rules.
#             </p>
#           </div>
#
#           <div className="bg-white dark:bg-gray-800 rounded-xl p-6 shadow-lg">
#             <div className="flex items-center gap-3 mb-4">
#               <Cpu className="w-6 h-6 text-blue-500" />
#               <h3 className="text-xl font-semibold text-gray-800 dark:text-white">
#                 Distributed Learning
#               </h3>
#             </div>
#             <p className="text-gray-600 dark:text-gray-300">
#               Each neuron contributes to the overall pattern recognition, creating
#               emergent behavior from simple interactions.
#             </p>
#           </div>
#         </div>
#
#         <button
#           onClick={handleNextStep}
#           className="mt-8 flex items-center gap-2 bg-blue-500 hover:bg-blue-600 text-white px-6 py-3 rounded-lg transition-colors duration-300"
#         >
#           Next Step
#           <ChevronRight className="w-5 h-5" />
#         </button>
#       </div>
#     </div>
#   )
# }
#
# export default SubsymbolicAI
#   ❌ Error processing file: create_implementation_prompt() missing 1 required positional argument: 'concept_response'
#   ⏱️ Time taken: 0m 21s
#
# 📝 Processing file 7/10: clustering.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Clustering
#
#   ⌛ Stage 1: Generating conceptual understanding for Clustering...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Circle, MoveHorizontal, Sparkles } from "lucide-react"
#
# interface Point {
#   id: number
#   x: number
#   y: number
#   cluster: number
#   color: string
# }
#
# interface ClusteringDemoProps {}
#
# const COLORS = ["#EC4899", "#8B5CF6", "#22C55E", "#3B82F6"]
# const POINT_COUNT = 40
#
# /**
#  * An interactive clustering visualization component that demonstrates
#  * how K-means clustering works through animation
#  */
# const ClusteringDemo: React.FC<ClusteringDemoProps> = () => {
#   const [points, setPoints] = useState<Point[]>([])
#   const [step, setStep] = useState(0)
#   const [isRunning, setIsRunning] = useState(false)
#   const [centroids, setCentroids] = useState<{x: number, y: number}[]>([])
#
#   // Initialize random points
#   useEffect(() => {
#     const initialPoints = Array.from({length: POINT_COUNT}, (_, i) => ({
#       id: i,
#       x: Math.random() * 80 + 10,
#       y: Math.random() * 80 + 10,
#       cluster: -1,
#       color: "#6B7280"
#     }))
#     setPoints(initialPoints)
#
#     // Initialize random centroids
#     const initialCentroids = Array.from({length: 4}, () => ({
#       x: Math.random() * 80 + 10,
#       y: Math.random() * 80 + 10
#     }))
#     setCentroids(initialCentroids)
#
#     return () => setIsRunning(false)
#   }, [])
#
#   // Animation loop
#   useEffect(() => {
#     if (!isRunning) return
#
#     const timer = setInterval(() => {
#       setStep(prev => {
#         if (prev >= 5) {
#           setIsRunning(false)
#           return prev
#         }
#         return prev + 1
#       })
#     }, 1000)
#
#     return () => clearInterval(timer)
#   }, [isRunning])
#
#   // Update clusters
#   useEffect(() => {
#     if (step === 0) return
#
#     setPoints(prev => prev.map(point => {
#       // Find closest centroid
#       let minDist = Infinity
#       let cluster = 0
#
#       centroids.forEach((centroid, i) => {
#         const dist = Math.sqrt(
#           Math.pow(point.x - centroid.x, 2) +
#           Math.pow(point.y - centroid.y, 2)
#         )
#         if (dist < minDist) {
#           minDist = dist
#           cluster = i
#         }
#       })
#
#       return {
#         ...point,
#         cluster,
#         color: COLORS[cluster]
#       }
#     }))
#
#     // Update centroids
#     setCentroids(prev => prev.map((centroid, i) => {
#       const clusteredPoints = points.filter(p => p.cluster === i)
#       if (!clusteredPoints.length) return centroid
#
#       return {
#         x: clusteredPoints.reduce((sum, p) => sum + p.x, 0) / clusteredPoints.length,
#         y: clusteredPoints.reduce((sum, p) => sum + p.y, 0) / clusteredPoints.length
#       }
#     }))
#   }, [step])
#
#   return (
#     <div className="w-full max-w-2xl mx-auto p-8 bg-white dark:bg-gray-800 rounded-xl shadow-lg">
#       <div className="flex items-center justify-between mb-6">
#         <h2 className="text-2xl font-bold text-gray-800 dark:text-white">
#           K-Means Clustering
#         </h2>
#         <button
#           onClick={() => setIsRunning(!isRunning)}
#           className="px-4 py-2 bg-blue-500 hover:bg-blue-600 text-white rounded-lg
#                      transition duration-300 flex items-center gap-2"
#         >
#           {isRunning ? "Pause" : "Start"}
#           <MoveHorizontal className="w-4 h-4" />
#         </button>
#       </div>
#
#       <div className="relative w-full aspect-square bg-gray-100 dark:bg-gray-700
#                       rounded-lg overflow-hidden">
#         {/* Points */}
#         {points.map(point => (
#           <div
#             key={point.id}
#             style={{
#               left: `${point.x}%`,
#               top: `${point.y}%`,
#               transform: 'translate(-50%, -50%)',
#               backgroundColor: point.color
#             }}
#             className={`absolute w-3 h-3 rounded-full transition-all duration-500
#                        ${step > 0 ? 'scale-100' : 'scale-50'}`}
#           />
#         ))}
#
#         {/* Centroids */}
#         {step > 0 && centroids.map((centroid, i) => (
#           <div
#             key={i}
#             style={{
#               left: `${centroid.x}%`,
#               top: `${centroid.y}%`,
#               borderColor: COLORS[i]
#             }}
#             className="absolute w-6 h-6 border-2 rounded-full transform -translate-x-1/2
#                        -translate-y-1/2 transition-all duration-500"
#           >
#             <Sparkles className="w-4 h-4 m-auto mt-0.5" style={{color: COLORS[i]}} />
#           </div>
#         ))}
#       </div>
#
#       <div className="mt-6 text-gray-600 dark:text-gray-300">
#         <p className="text-center">
#           {step === 0 && "Click Start to begin clustering!"}
#           {step > 0 && step < 5 && `Iteration ${step}: Points are joining their nearest clusters...`}
#           {step >= 5 && "Clustering complete! Points have found their families 🎉"}
#         </p>
#       </div>
#     </div>
#   )
# }
#
# export default ClusteringDemo
# ```
#   ❌ Error processing file: create_implementation_prompt() missing 1 required positional argument: 'concept_response'
#   ⏱️ Time taken: 0m 25s
#
# 📝 Processing file 8/10: interpretability.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Interpretability
#
#   ⌛ Stage 1: Generating conceptual understanding for Interpretability...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react"
# import { Brain, Eye, HeartPulse, Building2, Scale, Lock, AlertCircle, Check, X } from "lucide-react"
#
# interface Decision {
#   id: number
#   context: string
#   explanation: string
#   icon: JSX.Element
#   correct: boolean
# }
#
# const DECISIONS: Decision[] = [
#   {
#     id: 1,
#     context: "Healthcare: Patient Diagnosis",
#     explanation: "High fever and cough detected. Recommended COVID-19 test based on symptom pattern analysis.",
#     icon: <HeartPulse className="w-6 h-6" />,
#     correct: true
#   },
#   {
#     id: 2,
#     context: "Finance: Loan Application",
#     explanation: "Application denied due to irregular income patterns in last 6 months.",
#     icon: <Building2 className="w-6 h-6" />,
#     correct: false
#   },
#   {
#     id: 3,
#     context: "Legal: Risk Assessment",
#     explanation: "Low recidivism risk predicted based on behavioral history and support system.",
#     icon: <Scale className="w-6 h-6" />,
#     correct: true
#   }
# ]
#
# export default function InterpretabilityDemo() {
#   const [currentDecision, setCurrentDecision] = useState<number>(0)
#   const [isExplaining, setIsExplaining] = useState<boolean>(false)
#   const [showFeedback, setShowFeedback] = useState<boolean>(false)
#
#   useEffect(() => {
#     const timer = setInterval(() => {
#       setCurrentDecision((prev) => (prev + 1) % DECISIONS.length)
#       setIsExplaining(false)
#       setShowFeedback(false)
#     }, 5000)
#
#     return () => clearInterval(timer)
#   }, [])
#
#   const handleExplainClick = () => {
#     setIsExplaining(true)
#     setShowFeedback(true)
#   }
#
#   return (
#     <div className="min-h-screen bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-900 dark:to-gray-800 p-8 flex items-center justify-center">
#       <div className="max-w-2xl w-full bg-white dark:bg-gray-800 rounded-xl shadow-xl p-8 transition-all duration-500">
#         <div className="flex items-center justify-center gap-4 mb-8">
#           <Brain className="w-8 h-8 text-blue-500" />
#           <h1 className="text-3xl font-bold text-gray-800 dark:text-white">AI Interpretability Explorer</h1>
#         </div>
#
#         <div className="relative overflow-hidden rounded-lg bg-gray-50 dark:bg-gray-700 p-6 mb-6">
#           <div className="flex items-center gap-4 mb-4">
#             {DECISIONS[currentDecision].icon}
#             <h2 className="text-xl font-semibold text-gray-700 dark:text-gray-200">
#               {DECISIONS[currentDecision].context}
#             </h2>
#           </div>
#
#           <div className="flex items-center gap-2 mb-4">
#             <AlertCircle className="w-5 h-5 text-yellow-500" />
#             <p className="text-gray-600 dark:text-gray-300">AI has made a decision. Want to understand why?</p>
#           </div>
#
#           {!isExplaining && (
#             <button
#               onClick={handleExplainClick}
#               className="flex items-center gap-2 bg-blue-500 hover:bg-blue-600 text-white px-4 py-2 rounded-lg transition-colors duration-300"
#             >
#               <Eye className="w-5 h-5" />
#               Explain Decision
#             </button>
#           )}
#
#           {isExplaining && (
#             <div className="animate-fade-in space-y-4">
#               <div className="flex items-start gap-2">
#                 <Lock className="w-5 h-5 text-blue-500 mt-1" />
#                 <p className="text-gray-700 dark:text-gray-200">{DECISIONS[currentDecision].explanation}</p>
#               </div>
#
#               {showFeedback && (
#                 <div className="flex items-center gap-2 mt-4">
#                   {DECISIONS[currentDecision].correct ? (
#                     <Check className="w-5 h-5 text-green-500" />
#                   ) : (
#                     <X className="w-5 h-5 text-red-500" />
#                   )}
#                   <p className="text-sm text-gray-600 dark:text-gray-300">
#                     {DECISIONS[currentDecision].correct
#                       ? "This explanation helps build trust in the AI system"
#                       : "This decision requires human review"}
#                   </p>
#                 </div>
#               )}
#             </div>
#           )}
#         </div>
#
#         <div className="flex justify-center gap-2">
#           {DECISIONS.map((_, index) => (
#             <div
#               key={index}
#               className={`w-2 h-2 rounded-full transition-all duration-300 ${
#                 currentDecision === index
#                   ? "bg-blue-500 scale-125"
#                   : "bg-gray-300 dark:bg-gray-600"
#               }`}
#             />
#           ))}
#         </div>
#       </div>
#     </div>
#   )
# }
#   ❌ Error processing file: create_implementation_prompt() missing 1 required positional argument: 'concept_response'
#   ⏱️ Time taken: 0m 24s
#
# 📝 Processing file 9/10: matrix-multiplication.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Matrix Multiplication
#
#   ⌛ Stage 1: Generating conceptual understanding for Matrix Multiplication...
#
#   💬 Stage 1 response: ```typescript
# "use client"
# import { useState, useEffect } from "react"
# import { Grid, Play, Pause, RotateCcw } from "lucide-react"
#
# interface MatrixMultiplicationProps {}
#
# type Cell = {
#   value: number
#   highlighted: boolean
# }
#
# const MatrixMultiplicationDemo: React.FC<MatrixMultiplicationProps> = () => {
#   const [isPlaying, setIsPlaying] = useState<boolean>(false)
#   const [step, setStep] = useState<number>(0)
#   const [matrixA, setMatrixA] = useState<Cell[][]>([
#     [{value: 1, highlighted: false}, {value: 2, highlighted: false}],
#     [{value: 3, highlighted: false}, {value: 4, highlighted: false}]
#   ])
#   const [matrixB, setMatrixB] = useState<Cell[][]>([
#     [{value: 5, highlighted: false}, {value: 6, highlighted: false}],
#     [{value: 7, highlighted: false}, {value: 8, highlighted: false}]
#   ])
#   const [result, setResult] = useState<Cell[][]>([
#     [{value: 0, highlighted: false}, {value: 0, highlighted: false}],
#     [{value: 0, highlighted: false}, {value: 0, highlighted: false}]
#   ])
#
#   const resetHighlights = () => {
#     setMatrixA(prev => prev.map(row => row.map(cell => ({...cell, highlighted: false}))))
#     setMatrixB(prev => prev.map(row => row.map(cell => ({...cell, highlighted: false}))))
#     setResult(prev => prev.map(row => row.map(cell => ({...cell, highlighted: false}))))
#   }
#
#   useEffect(() => {
#     if (!isPlaying) return
#
#     const interval = setInterval(() => {
#       setStep(prev => {
#         if (prev >= 7) {
#           setIsPlaying(false)
#           return 0
#         }
#         return prev + 1
#       })
#     }, 1500)
#
#     return () => clearInterval(interval)
#   }, [isPlaying])
#
#   useEffect(() => {
#     resetHighlights()
#
#     const row = Math.floor(step / 4)
#     const col = Math.floor((step % 4) / 2)
#     const subStep = step % 2
#
#     if (step < 8) {
#       const newMatrixA = [...matrixA]
#       const newMatrixB = [...matrixB]
#       const newResult = [...result]
#
#       // Highlight current calculation cells
#       newMatrixA[row][0].highlighted = subStep === 0
#       newMatrixA[row][1].highlighted = subStep === 1
#       newMatrixB[0][col].highlighted = subStep === 0
#       newMatrixB[1][col].highlighted = subStep === 1
#
#       if (subStep === 1) {
#         newResult[row][col].highlighted = true
#         newResult[row][col].value =
#           matrixA[row][0].value * matrixB[0][col].value +
#           matrixA[row][1].value * matrixB[1][col].value
#       }
#
#       setMatrixA(newMatrixA)
#       setMatrixB(newMatrixB)
#       setResult(newResult)
#     }
#   }, [step])
#
#   const handleReset = () => {
#     setIsPlaying(false)
#     setStep(0)
#     resetHighlights()
#     setResult([
#       [{value: 0, highlighted: false}, {value: 0, highlighted: false}],
#       [{value: 0, highlighted: false}, {value: 0, highlighted: false}]
#     ])
#   }
#
#   return (
#     <div className="flex flex-col items-center justify-center min-h-screen bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-900 dark:to-gray-800 p-8">
#       <div className="bg-white dark:bg-gray-800 rounded-xl shadow-xl p-8 space-y-8">
#         <h2 className="text-3xl font-bold text-center text-gray-800 dark:text-gray-100">
#           Matrix Multiplication
#         </h2>
#
#         <div className="flex items-center justify-center space-x-4">
#           <div className="matrix-container">
#             {matrixA.map((row, i) => (
#               <div key={i} className="flex">
#                 {row.map((cell, j) => (
#                   <div
#                     key={j}
#                     className={`w-16 h-16 flex items-center justify-center text-xl font-semibold border border-gray-200 dark:border-gray-700 transition-all duration-300
#                       ${cell.highlighted ? 'bg-blue-500 text-white scale-110' : 'bg-white dark:bg-gray-800 text-gray-800 dark:text-gray-100'}`}
#                   >
#                     {cell.value}
#                   </div>
#                 ))}
#               </div>
#             ))}
#           </div>
#
#           <Grid className="w-8 h-8 text-gray-400" />
#
#           <div className="matrix-container">
#             {matrixB.map((row, i) => (
#               <div key={i} className="flex">
#                 {row.map((cell, j) => (
#                   <div
#                     key={j}
#                     className={`w-16 h-16 flex items-center justify-center text-xl font-semibold border border-gray-200 dark:border-gray-700 transition-all duration-300
#                       ${cell.highlighted ? 'bg-blue-500 text-white scale-110' : 'bg-white dark:bg-gray-800 text-gray-800 dark:text-gray-100'}`}
#                   >
#                     {cell.value}
#                   </div>
#                 ))}
#               </div>
#             ))}
#           </div>
#
#           <div className="text-2xl text-gray-600 dark:text-gray-300">=</div>
#
#           <div className="matrix-container">
#             {result.map((row, i) => (
#               <div key={i} className="flex">
#                 {row.map((cell, j) => (
#                   <div
#                     key={j}
#                     className={`w-16 h-16 flex items-center justify-center text-xl font-semibold border border-gray-200 dark:border-gray-700 transition-all duration-300
#                       ${cell.highlighted ? 'bg-green-500 text-white scale-110' : 'bg-white dark:bg-gray-800 text-gray-800 dark:text-gray-100'}`}
#                   >
#                     {cell.value}
#                   </div>
#                 ))}
#               </div>
#             ))}
#           </div>
#         </div>
#
#         <div className="flex justify-center space-x-4">
#           <button
#             onClick={() => setIsPlaying(!isPlaying)}
#             className="flex items-center space-x-2 px-6 py-3 bg-blue-500 hover:bg-blue-600 text-white rounded-lg transition duration-300"
#           >
#             {isPlaying ? <Pause className="w-5 h-5" /> : <Play className="w-5 h-5" />}
#             <span>{isPlaying ? 'Pause' : 'Play'}</span>
#           </button>
#
#           <button
#             onClick={handleReset}
#             className="flex items-center space-x-2 px-6 py-3 bg-gray-500 hover:bg-gray-600 text-white rounded-lg transition duration-300"
#           >
#             <RotateCcw className="w-5 h-5" />
#             <span>Reset</span>
#           </button>
#         </div>
#       </div>
#
#   ❌ Error processing file: create_implementation_prompt() missing 1 required positional argument: 'concept_response'
#   ⏱️ Time taken: 0m 30s
#
# 📝 Processing file 10/10: connectionist-ai.md
#   ⌛ Reading file...
#   ⌛ Extracting metadata...
#   ⌛ Creating prompts for: Connectionist AI
#
#   ⌛ Stage 1: Generating conceptual understanding for Connectionist AI...
#
#   💬 Stage 1 response: "use client"
# import { useState, useEffect } from "react"
# import { Brain, Zap, Network, ArrowRight, ArrowLeft } from "lucide-react"
#
# interface NeuronState {
#   id: number
#   active: boolean
#   x: number
#   y: number
# }
#
# const ConnectionistAIDemo = () => {
#   const [neurons, setNeurons] = useState<NeuronState[]>([])
#   const [isProcessing, setIsProcessing] = useState(false)
#   const [step, setStep] = useState(0)
#
#   useEffect(() => {
#     const initialNeurons = Array.from({ length: 12 }, (_, i) => ({
#       id: i,
#       active: false,
#       x: Math.cos(((2 * Math.PI) / 12) * i) * 150 + 200,
#       y: Math.sin(((2 * Math.PI) / 12) * i) * 150 + 200,
#     }))
#     setNeurons(initialNeurons)
#
#     return () => setNeurons([])
#   }, [])
#
#   const activateNetwork = () => {
#     if (isProcessing) return
#     setIsProcessing(true)
#
#     const activationSequence = async () => {
#       for (let i = 0; i < neurons.length; i++) {
#         setNeurons(prev =>
#           prev.map((n, idx) => ({
#             ...n,
#             active: idx <= i
#           }))
#         )
#         await new Promise(r => setTimeout(r, 300))
#       }
#       await new Promise(r => setTimeout(r, 500))
#       setNeurons(prev => prev.map(n => ({ ...n, active: false })))
#       setIsProcessing(false)
#     }
#
#     activationSequence()
#   }
#
#   const steps = [
#     "Connectionist AI simulates the human brain's neural network",
#     "Information flows through connected artificial neurons",
#     "Neurons activate and strengthen connections through learning",
#     "The network adapts to recognize patterns in data"
#   ]
#
#   return (
#     <div className="min-h-screen bg-gradient-to-br from-gray-50 to-gray-100 dark:from-gray-900 dark:to-gray-800 p-8 flex flex-col items-center justify-center">
#       <div className="max-w-4xl w-full space-y-8">
#         <div className="text-center space-y-4">
#           <h1 className="text-4xl font-bold text-gray-800 dark:text-white flex items-center justify-center gap-3">
#             <Brain className="w-10 h-10 text-blue-500" />
#             Connectionist AI
#           </h1>
#           <p className="text-gray-600 dark:text-gray-300 text-xl">
#             {steps[step]}
#           </p>
#         </div>
#
#         <div className="relative h-[400px] w-full bg-white dark:bg-gray-800 rounded-xl shadow-lg overflow-hidden">
#           <svg className="absolute inset-0 w-full h-full">
#             {neurons.map((n1, i) =>
#               neurons.map((n2, j) => {
#                 if (j <= i) return null
#                 return (
#                   <line
#                     key={`${i}-${j}`}
#                     x1={n1.x}
#                     y1={n1.y}
#                     x2={n2.x}
#                     y2={n2.y}
#                     stroke={n1.active && n2.active ? "#3B82F6" : "#E5E7EB"}
#                     strokeWidth="2"
#                     className="transition-colors duration-300"
#                   />
#                 )
#               })
#             )}
#           </svg>
#
#           {neurons.map((neuron) => (
#             <div
#               key={neuron.id}
#               style={{
#                 left: neuron.x,
#                 top: neuron.y,
#               }}
#               className={`absolute w-6 h-6 -ml-3 -mt-3 rounded-full transition-all duration-300 flex items-center justify-center
#                 ${
#                   neuron.active
#                     ? "bg-blue-500 scale-110 shadow-lg shadow-blue-500/50"
#                     : "bg-gray-200 dark:bg-gray-600"
#                 }`}
#             >
#               <Zap
#                 className={`w-3 h-3 ${
#                   neuron.active ? "text-white" : "text-gray-400"
#                 }`}
#               />
#             </div>
#           ))}
#         </div>
#
#         <div className="flex justify-between items-center">
#           <button
#             onClick={() => setStep((s) => (s > 0 ? s - 1 : s))}
#             className="p-2 rounded-full hover:bg-gray-200 dark:hover:bg-gray-700 transition-colors duration-300"
#             disabled={step === 0}
#           >
#             <ArrowLeft className="w-6 h-6 text-gray-600 dark:text-gray-300" />
#           </button>
#
#           <button
#             onClick={activateNetwork}
#             disabled={isProcessing}
#             className="px-6 py-3 bg-blue-500 hover:bg-blue-600 text-white rounded-full flex items-center gap-2 transition-colors duration-300 disabled:opacity-50"
#           >
#             <Network className="w-5 h-5" />
#             Activate Network
#           </button>
#
#           <button
#             onClick={() => setStep((s) => (s < steps.length - 1 ? s + 1 : s))}
#             className="p-2 rounded-full hover:bg-gray-200 dark:hover:bg-gray-700 transition-colors duration-300"
#             disabled={step === steps.length - 1}
#           >
#             <ArrowRight className="w-6 h-6 text-gray-600 dark:text-gray-300" />
#           </button>
#         </div>
#       </div>
#     </div>
#   )
# }
#
# export default ConnectionistAIDemo
#   ❌ Error processing file: create_implementation_prompt() missing 1 required positional argument: 'concept_response'
#   ⏱️ Time taken: 0m 24s
#
# ====== Summary ======
# ✅ Successfully processed: 0
# ❌ Failed: 10
# ⏱️ Total time: 3m 58s
#
# ✨ Process completed!
